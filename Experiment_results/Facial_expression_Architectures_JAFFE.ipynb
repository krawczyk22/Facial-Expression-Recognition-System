# %%
from google.colab import drive
import tarfile
import os, cv2
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
from keras.utils import np_utils
drive.mount('/content/drive'),
# Out:
# Mounted at /content/drive
# (None,)

# %%
data_path = '/content/drive/MyDrive/facial_expression/jaffe'
data_dir_list = os.listdir(data_path)

img_si=128
img_siAlexNet=227
img_siAlexGoogLeNet=224
num_channel=1

num_epoch=10

img_data_listAlexNet=[]
img_data_listGoogLeNet=[]


for dataset in data_dir_list:
    img_list=os.listdir(data_path+'/'+ dataset)
    print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
    for img in img_list:
        input_img=cv2.imread(data_path + '/'+ dataset + '/'+ img )
        #input_img=cv2.cvtColor(input_img, cv2.COLOR_BGR2GRAY)
        input_img_resizeAlexNet=cv2.resize(input_img,(img_siAlexNet,img_siAlexNet))
        input_img_resizeGoogLeNet=cv2.resize(input_img,(img_siAlexGoogLeNet,img_siAlexGoogLeNet))
        img_data_listAlexNet.append(input_img_resizeAlexNet)
        img_data_listGoogLeNet.append(input_img_resizeGoogLeNet)
        
img_dataAlexNet = np.array(img_data_listAlexNet)
img_dataGoogLeNet = np.array(img_data_listGoogLeNet)
img_dataAlexNet = img_dataAlexNet.astype('float32')
img_dataGoogLeNet = img_dataGoogLeNet.astype('float32')
img_dataAlexNet = img_dataAlexNet/255
img_dataGoogLeNet = img_dataGoogLeNet/255
img_dataAlexNet.shape
img_dataGoogLeNet.shape
# Out:
# Loaded the images of dataset-ANGRY
#
# Loaded the images of dataset-DISGUST
#
# Loaded the images of dataset-FEAR
#
# Loaded the images of dataset-NEUTRAL
#
# Loaded the images of dataset-HAPPY
#
# Loaded the images of dataset-SAD
#
# Loaded the images of dataset-SURPRISE
# (213, 224, 224, 3)

# %%
num_classes = 7

num_of_samples = img_dataGoogLeNet.shape[0]
labels = np.ones((num_of_samples,),dtype='int64')

labels[0:29]=0 #30
labels[30:58]=1 #29
labels[59:90]=2 #32
labels[91:121]=3 #31
labels[122:151]=4 #30
labels[152:182]=5 #31
labels[183:]=6 #30

names = ['ANGRY','DISGUST','FEAR','HAPPY','NEUTRAL','SAD','SURPRISE']

def getLabel(id):
    return ['ANGRY','DISGUST','FEAR','HAPPY','NEUTRAL','SAD','SURPRISE'][id]

# %%
Y = np_utils.to_categorical(labels, num_classes)
#Shuffle the dataset
x,y = shuffle(img_dataGoogLeNet,Y, random_state=2)
xA,yA = shuffle(img_dataAlexNet,Y, random_state=2)
# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)
X_trainA, X_testA, y_trainA, y_testA = train_test_split(xA, yA, test_size=0.2, random_state=2)
x_test=X_test
x_testA=X_testA
#X_train=X_train.reshape(X_train.shape[0],128,128,1)
#X_test=X_test.reshape(X_test.shape[0],128,128,1)
x_test.shape
# Out:
# (43, 224, 224, 3)

# %%
from keras.models import Sequential
from keras.layers import Dense , Activation , Dropout ,Flatten, BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D, AveragePooling2D
from keras.metrics import categorical_accuracy
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
from keras.optimizers import *
from keras.layers.normalization import BatchNormalization
from tensorflow.keras.layers import Input, Concatenate
from tensorflow.keras import regularizers

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, ZeroPadding2D
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD

# %%
modelVGG = tf.keras.applications.VGG19(
    include_top=True,
    weights=None,
    input_tensor=None,
    input_shape=None,
    pooling="max",
    classes=7,
    classifier_activation="softmax",
)

# %%
modelResNet = tf.keras.applications.ResNet101(
    include_top=True,
    weights=None,
    input_tensor=None,
    input_shape=None,
    pooling="max",
    classes=7,
)

# %%
modelAlexNet = tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(filters=96, kernel_size=(11,11), strides=(4,4), activation='relu', input_shape=(227,227,3)),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    tf.keras.layers.Conv2D(filters=256, kernel_size=(5,5), strides=(1,1), activation='relu', padding="same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    tf.keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters=384, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.Conv2D(filters=256, kernel_size=(3,3), strides=(1,1), activation='relu', padding="same"),
    tf.keras.layers.BatchNormalization(),
    tf.keras.layers.MaxPool2D(pool_size=(3,3), strides=(2,2)),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(4096, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(4096, activation='relu'),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(7, activation='softmax')
])

# %%
CLASS_NUM = 7
IMAGE_SHAPE = (224, 224, 3)

def inception(x, filters):
    # 1x1
    path1 = Conv2D(filters=filters[0], kernel_size=(1,1), strides=1, padding='same', activation='relu')(x)

    # 1x1->3x3
    path2 = Conv2D(filters=filters[1][0], kernel_size=(1,1), strides=1, padding='same', activation='relu')(x)
    path2 = Conv2D(filters=filters[1][1], kernel_size=(3,3), strides=1, padding='same', activation='relu')(path2)
    
    # 1x1->5x5
    path3 = Conv2D(filters=filters[2][0], kernel_size=(1,1), strides=1, padding='same', activation='relu')(x)
    path3 = Conv2D(filters=filters[2][1], kernel_size=(5,5), strides=1, padding='same', activation='relu')(path3)

    # 3x3->1x1
    path4 = MaxPooling2D(pool_size=(3,3), strides=1, padding='same')(x)
    path4 = Conv2D(filters=filters[3], kernel_size=(1,1), strides=1, padding='same', activation='relu')(path4)

    return Concatenate(axis=-1)([path1,path2,path3,path4])


def auxiliary(x, name=None):
    layer = AveragePooling2D(pool_size=(5,5), strides=3, padding='valid')(x)
    layer = Conv2D(filters=128, kernel_size=(1,1), strides=1, padding='same', activation='relu')(layer)
    layer = Flatten()(layer)
    layer = Dense(units=256, activation='relu')(layer)
    layer = Dropout(0.4)(layer)
    layer = Dense(units=CLASS_NUM, activation='softmax', name=name)(layer)
    return layer


def googlenet():
    layer_in = Input(shape=IMAGE_SHAPE)
    
    # stage-1
    layer = Conv2D(filters=64, kernel_size=(7,7), strides=2, padding='same', activation='relu')(layer_in)
    layer = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(layer)
    layer = BatchNormalization()(layer)

    # stage-2
    layer = Conv2D(filters=64, kernel_size=(1,1), strides=1, padding='same', activation='relu')(layer)
    layer = Conv2D(filters=192, kernel_size=(3,3), strides=1, padding='same', activation='relu')(layer)
    layer = BatchNormalization()(layer)
    layer = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(layer)

    # stage-3
    layer = inception(layer, [ 64,  (96,128), (16,32), 32]) #3a
    layer = inception(layer, [128, (128,192), (32,96), 64]) #3b
    layer = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(layer)
    
    # stage-4
    layer = inception(layer, [192,  (96,208),  (16,48),  64]) #4a
    aux1  = auxiliary(layer, name='aux1')
    layer = inception(layer, [160, (112,224),  (24,64),  64]) #4b
    layer = inception(layer, [128, (128,256),  (24,64),  64]) #4c
    layer = inception(layer, [112, (144,288),  (32,64),  64]) #4d
    aux2  = auxiliary(layer, name='aux2')
    layer = inception(layer, [256, (160,320), (32,128), 128]) #4e
    layer = MaxPooling2D(pool_size=(3,3), strides=2, padding='same')(layer)
    
    # stage-5
    layer = inception(layer, [256, (160,320), (32,128), 128]) #5a
    layer = inception(layer, [384, (192,384), (48,128), 128]) #5b
    layer = AveragePooling2D(pool_size=(7,7), strides=1, padding='valid')(layer)
    
    # stage-6
    layer = Flatten()(layer)
    layer = Dropout(0.4)(layer)
    layer = Dense(units=256, activation='linear')(layer)
    main = Dense(units=CLASS_NUM, activation='softmax', name='main')(layer)
    
    model = Model(inputs=layer_in, outputs=[main, aux1, aux2])
    
    return model

# train model
modelGoogLeNet = googlenet()

# %%
modelVGG.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), metrics=["accuracy"])

# %%
modelResNet.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), metrics=["accuracy"])

# %%
modelAlexNet.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), metrics=["accuracy"])

# %%
modelGoogLeNet.compile(loss='categorical_crossentropy', loss_weights={'main': 1.0, 'aux1': 0.3, 'aux2': 0.3}, optimizer=tf.keras.optimizers.Adam(learning_rate=0.0001), metrics=["accuracy"])

# %%
from keras import callbacks
filename1='modelVGG_train_new.csv'
filename4='modelResNet_train_new.csv'
filename16='model1AlexNet_train_new.csv'
filename32='modelGoogLeNet_train_new.csv'

filepath1 = os.path.join('checkpoint', filename1)
filepath4 = os.path.join('checkpoint', filename4)
filepath16 = os.path.join('checkpoint', filename16)
filepath32 = os.path.join('checkpoint', filename32)

checkpoint1 = callbacks.ModelCheckpoint(filepath1, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint4 = callbacks.ModelCheckpoint(filepath4, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint16 = callbacks.ModelCheckpoint(filepath16, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint32 = callbacks.ModelCheckpoint(filepath32, monitor='val_main_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')

# %%
checkpoint1 = callbacks.ModelCheckpoint(filepath1, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')

# %%
hist1 = modelVGG.fit(X_train, y_train, batch_size=7, epochs=30, verbose=1, validation_data=(X_test, y_test),callbacks=checkpoint1)
# Out:
# Epoch 1/30
# 25/25 [==============================] - 41s 322ms/step - loss: 1.9472 - accuracy: 0.1412 - val_loss: 1.9483 - val_accuracy: 0.0465
#
# Epoch 00001: val_accuracy improved from -inf to 0.04651, saving model to checkpoint/modelVGG_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelVGG_train_new.csv/assets
# Epoch 2/30
# 25/25 [==============================] - 6s 229ms/step - loss: 1.9460 - accuracy: 0.1647 - val_loss: 1.9545 - val_accuracy: 0.0465
#
# Epoch 00002: val_accuracy did not improve from 0.04651
# Epoch 3/30
# 25/25 [==============================] - 6s 229ms/step - loss: 1.9449 - accuracy: 0.1647 - val_loss: 1.9574 - val_accuracy: 0.0465
#
# Epoch 00003: val_accuracy did not improve from 0.04651
# Epoch 4/30
# 25/25 [==============================] - 6s 231ms/step - loss: 1.9436 - accuracy: 0.1647 - val_loss: 1.9634 - val_accuracy: 0.0465
#
# Epoch 00004: val_accuracy did not improve from 0.04651
# Epoch 5/30
# 25/25 [==============================] - 6s 230ms/step - loss: 1.9500 - accuracy: 0.1647 - val_loss: 1.9617 - val_accuracy: 0.0465
#
# Epoch 00005: val_accuracy did not improve from 0.04651
# Epoch 6/30
# 25/25 [==============================] - 6s 240ms/step - loss: 1.9434 - accuracy: 0.1647 - val_loss: 1.9604 - val_accuracy: 0.0465
#
# Epoch 00006: val_accuracy did not improve from 0.04651
# Epoch 7/30
# 25/25 [==============================] - 6s 231ms/step - loss: 1.9426 - accuracy: 0.1647 - val_loss: 1.9680 - val_accuracy: 0.0465
#
# Epoch 00007: val_accuracy did not improve from 0.04651
# Epoch 8/30
# 25/25 [==============================] - 6s 231ms/step - loss: 1.9434 - accuracy: 0.1647 - val_loss: 1.9725 - val_accuracy: 0.0465
#
# Epoch 00008: val_accuracy did not improve from 0.04651
# Epoch 9/30
# 25/25 [==============================] - 6s 230ms/step - loss: 1.9421 - accuracy: 0.1647 - val_loss: 1.9828 - val_accuracy: 0.0465
#
# Epoch 00009: val_accuracy did not improve from 0.04651
# Epoch 10/30
# 25/25 [==============================] - 6s 231ms/step - loss: 1.9418 - accuracy: 0.1647 - val_loss: 1.9809 - val_accuracy: 0.0465
#
# Epoch 00010: val_accuracy did not improve from 0.04651
# Epoch 11/30
# 25/25 [==============================] - 6s 232ms/step - loss: 1.9416 - accuracy: 0.1647 - val_loss: 1.9811 - val_accuracy: 0.0465
#
# Epoch 00011: val_accuracy did not improve from 0.04651
# Epoch 12/30
# 25/25 [==============================] - 6s 232ms/step - loss: 1.9419 - accuracy: 0.1647 - val_loss: 1.9784 - val_accuracy: 0.0465
#
# Epoch 00012: val_accuracy did not improve from 0.04651
# Epoch 13/30
# 25/25 [==============================] - 6s 233ms/step - loss: 1.9414 - accuracy: 0.1647 - val_loss: 1.9761 - val_accuracy: 0.0465
#
# Epoch 00013: val_accuracy did not improve from 0.04651
# Epoch 14/30
# 25/25 [==============================] - 6s 233ms/step - loss: 1.9414 - accuracy: 0.1647 - val_loss: 1.9819 - val_accuracy: 0.0465
#
# Epoch 00014: val_accuracy did not improve from 0.04651
# Epoch 15/30
# 25/25 [==============================] - 6s 233ms/step - loss: 1.9419 - accuracy: 0.1647 - val_loss: 1.9852 - val_accuracy: 0.0465
#
# Epoch 00015: val_accuracy did not improve from 0.04651
# Epoch 16/30
# 25/25 [==============================] - 6s 235ms/step - loss: 1.9412 - accuracy: 0.1647 - val_loss: 1.9864 - val_accuracy: 0.0465
#
# Epoch 00016: val_accuracy did not improve from 0.04651
# Epoch 17/30
# 25/25 [==============================] - 6s 235ms/step - loss: 1.9426 - accuracy: 0.1647 - val_loss: 1.9935 - val_accuracy: 0.0465
#
# Epoch 00017: val_accuracy did not improve from 0.04651
# Epoch 18/30
# 25/25 [==============================] - 6s 235ms/step - loss: 1.9416 - accuracy: 0.1647 - val_loss: 1.9831 - val_accuracy: 0.0465
#
# Epoch 00018: val_accuracy did not improve from 0.04651
# Epoch 19/30
# 25/25 [==============================] - 6s 237ms/step - loss: 1.9428 - accuracy: 0.1647 - val_loss: 1.9895 - val_accuracy: 0.0465
#
# Epoch 00019: val_accuracy did not improve from 0.04651
# Epoch 20/30
# 25/25 [==============================] - 6s 234ms/step - loss: 1.9414 - accuracy: 0.1647 - val_loss: 1.9813 - val_accuracy: 0.0465
#
# Epoch 00020: val_accuracy did not improve from 0.04651
# Epoch 21/30
# 25/25 [==============================] - 6s 237ms/step - loss: 1.9415 - accuracy: 0.1647 - val_loss: 1.9860 - val_accuracy: 0.0465
#
# Epoch 00021: val_accuracy did not improve from 0.04651
# Epoch 22/30
# 25/25 [==============================] - 6s 237ms/step - loss: 1.9415 - accuracy: 0.1647 - val_loss: 1.9825 - val_accuracy: 0.0465
#
# Epoch 00022: val_accuracy did not improve from 0.04651
# Epoch 23/30
# 25/25 [==============================] - 6s 237ms/step - loss: 1.9414 - accuracy: 0.1647 - val_loss: 1.9878 - val_accuracy: 0.0465
#
# Epoch 00023: val_accuracy did not improve from 0.04651
# Epoch 24/30
# 25/25 [==============================] - 6s 238ms/step - loss: 1.9426 - accuracy: 0.1647 - val_loss: 1.9789 - val_accuracy: 0.0465
#
# Epoch 00024: val_accuracy did not improve from 0.04651
# Epoch 25/30
# 25/25 [==============================] - 6s 237ms/step - loss: 1.9414 - accuracy: 0.1647 - val_loss: 1.9777 - val_accuracy: 0.0465
#
# Epoch 00025: val_accuracy did not improve from 0.04651
# Epoch 26/30
# 25/25 [==============================] - 6s 239ms/step - loss: 1.9416 - accuracy: 0.1647 - val_loss: 1.9802 - val_accuracy: 0.0465
#
# Epoch 00026: val_accuracy did not improve from 0.04651
# Epoch 27/30
# 25/25 [==============================] - 6s 240ms/step - loss: 1.9412 - accuracy: 0.1647 - val_loss: 1.9790 - val_accuracy: 0.0465
#
# Epoch 00027: val_accuracy did not improve from 0.04651
# Epoch 28/30
# 25/25 [==============================] - 6s 240ms/step - loss: 1.9411 - accuracy: 0.1647 - val_loss: 1.9823 - val_accuracy: 0.0465
#
# Epoch 00028: val_accuracy did not improve from 0.04651
# Epoch 29/30
# 25/25 [==============================] - 6s 240ms/step - loss: 1.9410 - accuracy: 0.1647 - val_loss: 1.9853 - val_accuracy: 0.0465
#
# Epoch 00029: val_accuracy did not improve from 0.04651
# Epoch 30/30
# 25/25 [==============================] - 6s 241ms/step - loss: 1.9408 - accuracy: 0.1647 - val_loss: 1.9856 - val_accuracy: 0.0465
#
# Epoch 00030: val_accuracy did not improve from 0.04651

# %%
hist2 = modelResNet.fit(X_train, y_train, batch_size=7, epochs=30, verbose=1, validation_data=(X_test, y_test),callbacks=checkpoint4)
# Out:
# Epoch 1/30
# 25/25 [==============================] - 19s 366ms/step - loss: 2.5423 - accuracy: 0.1647 - val_loss: 1.9403 - val_accuracy: 0.2093
#
# Epoch 00001: val_accuracy improved from -inf to 0.20930, saving model to checkpoint/modelResNet_train_new.csv
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# INFO:tensorflow:Assets written to: checkpoint/modelResNet_train_new.csv/assets
# Epoch 2/30
# 25/25 [==============================] - 6s 224ms/step - loss: 2.1534 - accuracy: 0.1706 - val_loss: 1.9823 - val_accuracy: 0.2093
#
# Epoch 00002: val_accuracy did not improve from 0.20930
# Epoch 3/30
# 25/25 [==============================] - 6s 234ms/step - loss: 2.0119 - accuracy: 0.2000 - val_loss: 2.0295 - val_accuracy: 0.1163
#
# Epoch 00003: val_accuracy did not improve from 0.20930
# Epoch 4/30
# 25/25 [==============================] - 6s 223ms/step - loss: 1.9223 - accuracy: 0.2294 - val_loss: 2.3993 - val_accuracy: 0.1163
#
# Epoch 00004: val_accuracy did not improve from 0.20930
# Epoch 5/30
# 25/25 [==============================] - 6s 225ms/step - loss: 1.9715 - accuracy: 0.2294 - val_loss: 2.9301 - val_accuracy: 0.0465
#
# Epoch 00005: val_accuracy did not improve from 0.20930
# Epoch 6/30
# 25/25 [==============================] - 6s 228ms/step - loss: 1.7674 - accuracy: 0.2882 - val_loss: 5.6607 - val_accuracy: 0.0465
#
# Epoch 00006: val_accuracy did not improve from 0.20930
# Epoch 7/30
# 25/25 [==============================] - 6s 227ms/step - loss: 1.9744 - accuracy: 0.2000 - val_loss: 6.8397 - val_accuracy: 0.0465
#
# Epoch 00007: val_accuracy did not improve from 0.20930
# Epoch 8/30
# 25/25 [==============================] - 6s 237ms/step - loss: 1.6770 - accuracy: 0.3353 - val_loss: 8.6186 - val_accuracy: 0.0465
#
# Epoch 00008: val_accuracy did not improve from 0.20930
# Epoch 9/30
# 25/25 [==============================] - 6s 228ms/step - loss: 1.7800 - accuracy: 0.3294 - val_loss: 7.9663 - val_accuracy: 0.0465
#
# Epoch 00009: val_accuracy did not improve from 0.20930
# Epoch 10/30
# 25/25 [==============================] - 6s 236ms/step - loss: 1.7093 - accuracy: 0.3294 - val_loss: 9.3989 - val_accuracy: 0.0930
#
# Epoch 00010: val_accuracy did not improve from 0.20930
# Epoch 11/30
# 25/25 [==============================] - 6s 226ms/step - loss: 1.5841 - accuracy: 0.4235 - val_loss: 4.7195 - val_accuracy: 0.1163
#
# Epoch 00011: val_accuracy did not improve from 0.20930
# Epoch 12/30
# 25/25 [==============================] - 6s 227ms/step - loss: 1.3550 - accuracy: 0.5176 - val_loss: 9.9999 - val_accuracy: 0.0930
#
# Epoch 00012: val_accuracy did not improve from 0.20930
# Epoch 13/30
# 25/25 [==============================] - 6s 227ms/step - loss: 1.3858 - accuracy: 0.4882 - val_loss: 6.8685 - val_accuracy: 0.1163
#
# Epoch 00013: val_accuracy did not improve from 0.20930
# Epoch 14/30
# 25/25 [==============================] - 6s 228ms/step - loss: 1.1539 - accuracy: 0.5588 - val_loss: 13.6275 - val_accuracy: 0.0930
#
# Epoch 00014: val_accuracy did not improve from 0.20930
# Epoch 15/30
# 25/25 [==============================] - 6s 228ms/step - loss: 1.2738 - accuracy: 0.5353 - val_loss: 6.8373 - val_accuracy: 0.0930
#
# Epoch 00015: val_accuracy did not improve from 0.20930
# Epoch 16/30
# 25/25 [==============================] - 6s 239ms/step - loss: 1.4519 - accuracy: 0.4765 - val_loss: 6.7468 - val_accuracy: 0.0930
#
# Epoch 00016: val_accuracy did not improve from 0.20930
# Epoch 17/30
# 25/25 [==============================] - 6s 229ms/step - loss: 1.3020 - accuracy: 0.4882 - val_loss: 7.9227 - val_accuracy: 0.1163
#
# Epoch 00017: val_accuracy did not improve from 0.20930
# Epoch 18/30
# 25/25 [==============================] - 6s 230ms/step - loss: 1.1146 - accuracy: 0.6118 - val_loss: 6.1845 - val_accuracy: 0.2326
#
# Epoch 00018: val_accuracy improved from 0.20930 to 0.23256, saving model to checkpoint/modelResNet_train_new.csv
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# INFO:tensorflow:Assets written to: checkpoint/modelResNet_train_new.csv/assets
# Epoch 19/30
# 25/25 [==============================] - 6s 226ms/step - loss: 1.1718 - accuracy: 0.5706 - val_loss: 10.0126 - val_accuracy: 0.0930
#
# Epoch 00019: val_accuracy did not improve from 0.23256
# Epoch 20/30
# 25/25 [==============================] - 6s 226ms/step - loss: 1.0484 - accuracy: 0.6059 - val_loss: 4.0800 - val_accuracy: 0.1163
#
# Epoch 00020: val_accuracy did not improve from 0.23256
# Epoch 21/30
# 25/25 [==============================] - 6s 236ms/step - loss: 0.9994 - accuracy: 0.6118 - val_loss: 5.6734 - val_accuracy: 0.1860
#
# Epoch 00021: val_accuracy did not improve from 0.23256
# Epoch 22/30
# 25/25 [==============================] - 6s 228ms/step - loss: 0.8903 - accuracy: 0.7059 - val_loss: 6.7907 - val_accuracy: 0.2326
#
# Epoch 00022: val_accuracy did not improve from 0.23256
# Epoch 23/30
# 25/25 [==============================] - 6s 229ms/step - loss: 0.7717 - accuracy: 0.6824 - val_loss: 6.0397 - val_accuracy: 0.2326
#
# Epoch 00023: val_accuracy did not improve from 0.23256
# Epoch 24/30
# 25/25 [==============================] - 6s 229ms/step - loss: 0.5235 - accuracy: 0.8059 - val_loss: 5.8709 - val_accuracy: 0.1395
#
# Epoch 00024: val_accuracy did not improve from 0.23256
# Epoch 25/30
# 25/25 [==============================] - 6s 228ms/step - loss: 0.5240 - accuracy: 0.8059 - val_loss: 7.1508 - val_accuracy: 0.1860
#
# Epoch 00025: val_accuracy did not improve from 0.23256
# Epoch 26/30
# 25/25 [==============================] - 6s 230ms/step - loss: 0.6368 - accuracy: 0.8000 - val_loss: 4.4803 - val_accuracy: 0.2093
#
# Epoch 00026: val_accuracy did not improve from 0.23256
# Epoch 27/30
# 25/25 [==============================] - 6s 229ms/step - loss: 0.7000 - accuracy: 0.7412 - val_loss: 5.3187 - val_accuracy: 0.1395
#
# Epoch 00027: val_accuracy did not improve from 0.23256
# Epoch 28/30
# 25/25 [==============================] - 6s 239ms/step - loss: 0.5860 - accuracy: 0.7765 - val_loss: 6.1331 - val_accuracy: 0.2791
#
# Epoch 00028: val_accuracy improved from 0.23256 to 0.27907, saving model to checkpoint/modelResNet_train_new.csv
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# INFO:tensorflow:Assets written to: checkpoint/modelResNet_train_new.csv/assets
# Epoch 29/30
# 25/25 [==============================] - 6s 225ms/step - loss: 0.6984 - accuracy: 0.7588 - val_loss: 3.4896 - val_accuracy: 0.3023
#
# Epoch 00029: val_accuracy improved from 0.27907 to 0.30233, saving model to checkpoint/modelResNet_train_new.csv
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/utils/generic_utils.py:497: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   category=CustomMaskWarning)
# INFO:tensorflow:Assets written to: checkpoint/modelResNet_train_new.csv/assets
# Epoch 30/30
# 25/25 [==============================] - 6s 224ms/step - loss: 0.4855 - accuracy: 0.8176 - val_loss: 5.9629 - val_accuracy: 0.2326
#
# Epoch 00030: val_accuracy did not improve from 0.30233

# %%
hist3 = modelAlexNet.fit(X_trainA, y_trainA, batch_size=7, epochs=30, verbose=1, validation_data=(X_testA, y_testA),callbacks=checkpoint16)
# Out:
# Epoch 1/30
# 25/25 [==============================] - 3s 69ms/step - loss: 7.4755 - accuracy: 0.1059 - val_loss: 1.9690 - val_accuracy: 0.2093
#
# Epoch 00001: val_accuracy improved from -inf to 0.20930, saving model to checkpoint/model1AlexNet_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1AlexNet_train_new.csv/assets
# Epoch 2/30
# 25/25 [==============================] - 1s 43ms/step - loss: 8.4081 - accuracy: 0.1412 - val_loss: 1.9685 - val_accuracy: 0.2093
#
# Epoch 00002: val_accuracy did not improve from 0.20930
# Epoch 3/30
# 25/25 [==============================] - 1s 42ms/step - loss: 6.0649 - accuracy: 0.1824 - val_loss: 2.1243 - val_accuracy: 0.0930
#
# Epoch 00003: val_accuracy did not improve from 0.20930
# Epoch 4/30
# 25/25 [==============================] - 1s 42ms/step - loss: 4.7022 - accuracy: 0.2529 - val_loss: 2.0705 - val_accuracy: 0.2093
#
# Epoch 00004: val_accuracy did not improve from 0.20930
# Epoch 5/30
# 25/25 [==============================] - 1s 43ms/step - loss: 4.9498 - accuracy: 0.1529 - val_loss: 2.7702 - val_accuracy: 0.2093
#
# Epoch 00005: val_accuracy did not improve from 0.20930
# Epoch 6/30
# 25/25 [==============================] - 1s 43ms/step - loss: 4.2229 - accuracy: 0.2059 - val_loss: 2.5361 - val_accuracy: 0.2093
#
# Epoch 00006: val_accuracy did not improve from 0.20930
# Epoch 7/30
# 25/25 [==============================] - 1s 42ms/step - loss: 3.6059 - accuracy: 0.1706 - val_loss: 3.3330 - val_accuracy: 0.2093
#
# Epoch 00007: val_accuracy did not improve from 0.20930
# Epoch 8/30
# 25/25 [==============================] - 1s 43ms/step - loss: 3.5876 - accuracy: 0.1882 - val_loss: 2.6512 - val_accuracy: 0.2093
#
# Epoch 00008: val_accuracy did not improve from 0.20930
# Epoch 9/30
# 25/25 [==============================] - 1s 45ms/step - loss: 2.8898 - accuracy: 0.2647 - val_loss: 2.1133 - val_accuracy: 0.2093
#
# Epoch 00009: val_accuracy did not improve from 0.20930
# Epoch 10/30
# 25/25 [==============================] - 1s 45ms/step - loss: 2.8935 - accuracy: 0.2059 - val_loss: 2.3648 - val_accuracy: 0.2093
#
# Epoch 00010: val_accuracy did not improve from 0.20930
# Epoch 11/30
# 25/25 [==============================] - 1s 42ms/step - loss: 2.5253 - accuracy: 0.2647 - val_loss: 2.5391 - val_accuracy: 0.2093
#
# Epoch 00011: val_accuracy did not improve from 0.20930
# Epoch 12/30
# 25/25 [==============================] - 1s 42ms/step - loss: 2.3727 - accuracy: 0.2412 - val_loss: 2.6139 - val_accuracy: 0.2093
#
# Epoch 00012: val_accuracy did not improve from 0.20930
# Epoch 13/30
# 25/25 [==============================] - 1s 43ms/step - loss: 1.9558 - accuracy: 0.3588 - val_loss: 2.7213 - val_accuracy: 0.2326
#
# Epoch 00013: val_accuracy improved from 0.20930 to 0.23256, saving model to checkpoint/model1AlexNet_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1AlexNet_train_new.csv/assets
# Epoch 14/30
# 25/25 [==============================] - 1s 43ms/step - loss: 1.9934 - accuracy: 0.3294 - val_loss: 3.0521 - val_accuracy: 0.2093
#
# Epoch 00014: val_accuracy did not improve from 0.23256
# Epoch 15/30
# 25/25 [==============================] - 1s 43ms/step - loss: 1.9248 - accuracy: 0.3412 - val_loss: 3.5354 - val_accuracy: 0.2558
#
# Epoch 00015: val_accuracy improved from 0.23256 to 0.25581, saving model to checkpoint/model1AlexNet_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1AlexNet_train_new.csv/assets
# Epoch 16/30
# 25/25 [==============================] - 1s 46ms/step - loss: 1.6977 - accuracy: 0.4647 - val_loss: 4.1084 - val_accuracy: 0.0465
#
# Epoch 00016: val_accuracy did not improve from 0.25581
# Epoch 17/30
# 25/25 [==============================] - 1s 43ms/step - loss: 1.5544 - accuracy: 0.4471 - val_loss: 3.9256 - val_accuracy: 0.2093
#
# Epoch 00017: val_accuracy did not improve from 0.25581
# Epoch 18/30
# 25/25 [==============================] - 1s 42ms/step - loss: 1.4731 - accuracy: 0.5000 - val_loss: 4.1774 - val_accuracy: 0.1395
#
# Epoch 00018: val_accuracy did not improve from 0.25581
# Epoch 19/30
# 25/25 [==============================] - 1s 46ms/step - loss: 1.5072 - accuracy: 0.4235 - val_loss: 3.9278 - val_accuracy: 0.2093
#
# Epoch 00019: val_accuracy did not improve from 0.25581
# Epoch 20/30
# 25/25 [==============================] - 1s 43ms/step - loss: 1.2635 - accuracy: 0.5824 - val_loss: 3.0793 - val_accuracy: 0.3488
#
# Epoch 00020: val_accuracy improved from 0.25581 to 0.34884, saving model to checkpoint/model1AlexNet_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1AlexNet_train_new.csv/assets
# Epoch 21/30
# 25/25 [==============================] - 1s 43ms/step - loss: 1.5680 - accuracy: 0.4765 - val_loss: 3.4717 - val_accuracy: 0.1628
#
# Epoch 00021: val_accuracy did not improve from 0.34884
# Epoch 22/30
# 25/25 [==============================] - 1s 42ms/step - loss: 1.2762 - accuracy: 0.5529 - val_loss: 2.4404 - val_accuracy: 0.1860
#
# Epoch 00022: val_accuracy did not improve from 0.34884
# Epoch 23/30
# 25/25 [==============================] - 1s 43ms/step - loss: 1.1106 - accuracy: 0.6353 - val_loss: 4.2752 - val_accuracy: 0.1860
#
# Epoch 00023: val_accuracy did not improve from 0.34884
# Epoch 24/30
# 25/25 [==============================] - 1s 43ms/step - loss: 1.0063 - accuracy: 0.6235 - val_loss: 3.3217 - val_accuracy: 0.2791
#
# Epoch 00024: val_accuracy did not improve from 0.34884
# Epoch 25/30
# 25/25 [==============================] - 1s 42ms/step - loss: 1.0993 - accuracy: 0.6000 - val_loss: 4.7186 - val_accuracy: 0.1395
#
# Epoch 00025: val_accuracy did not improve from 0.34884
# Epoch 26/30
# 25/25 [==============================] - 1s 42ms/step - loss: 0.9080 - accuracy: 0.6412 - val_loss: 1.6578 - val_accuracy: 0.3721
#
# Epoch 00026: val_accuracy improved from 0.34884 to 0.37209, saving model to checkpoint/model1AlexNet_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1AlexNet_train_new.csv/assets
# Epoch 27/30
# 25/25 [==============================] - 1s 43ms/step - loss: 0.9846 - accuracy: 0.6765 - val_loss: 3.8940 - val_accuracy: 0.3721
#
# Epoch 00027: val_accuracy did not improve from 0.37209
# Epoch 28/30
# 25/25 [==============================] - 1s 42ms/step - loss: 0.8341 - accuracy: 0.7176 - val_loss: 2.8771 - val_accuracy: 0.1860
#
# Epoch 00028: val_accuracy did not improve from 0.37209
# Epoch 29/30
# 25/25 [==============================] - 1s 42ms/step - loss: 0.8576 - accuracy: 0.6706 - val_loss: 2.6473 - val_accuracy: 0.2558
#
# Epoch 00029: val_accuracy did not improve from 0.37209
# Epoch 30/30
# 25/25 [==============================] - 1s 43ms/step - loss: 0.7605 - accuracy: 0.7353 - val_loss: 0.9057 - val_accuracy: 0.7674
#
# Epoch 00030: val_accuracy improved from 0.37209 to 0.76744, saving model to checkpoint/model1AlexNet_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1AlexNet_train_new.csv/assets

# %%
hist4 = modelGoogLeNet.fit(X_train, y_train, batch_size=7, epochs=30, verbose=1, validation_data=(X_test, y_test),callbacks=checkpoint32)
# Out:
# Epoch 1/30
# 25/25 [==============================] - 9s 156ms/step - loss: 3.2291 - main_loss: 1.9879 - aux1_loss: 2.1688 - aux2_loss: 1.9685 - main_accuracy: 0.1765 - aux1_accuracy: 0.1647 - aux2_accuracy: 0.1000 - val_loss: 3.1123 - val_main_loss: 1.9443 - val_aux1_loss: 1.9466 - val_aux2_loss: 1.9467 - val_main_accuracy: 0.2093 - val_aux1_accuracy: 0.2093 - val_aux2_accuracy: 0.0930
#
# Epoch 00001: val_main_accuracy improved from -inf to 0.20930, saving model to checkpoint/modelGoogLeNet_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelGoogLeNet_train_new.csv/assets
# Epoch 2/30
# 25/25 [==============================] - 2s 66ms/step - loss: 3.1566 - main_loss: 1.9790 - aux1_loss: 1.9669 - aux2_loss: 1.9583 - main_accuracy: 0.1176 - aux1_accuracy: 0.1294 - aux2_accuracy: 0.1588 - val_loss: 3.1159 - val_main_loss: 1.9470 - val_aux1_loss: 1.9493 - val_aux2_loss: 1.9472 - val_main_accuracy: 0.2093 - val_aux1_accuracy: 0.0465 - val_aux2_accuracy: 0.0698
#
# Epoch 00002: val_main_accuracy did not improve from 0.20930
# Epoch 3/30
# 25/25 [==============================] - 2s 64ms/step - loss: 3.1113 - main_loss: 1.9465 - aux1_loss: 1.9369 - aux2_loss: 1.9458 - main_accuracy: 0.1353 - aux1_accuracy: 0.1941 - aux2_accuracy: 0.2118 - val_loss: 3.1177 - val_main_loss: 1.9495 - val_aux1_loss: 1.9455 - val_aux2_loss: 1.9486 - val_main_accuracy: 0.0465 - val_aux1_accuracy: 0.2093 - val_aux2_accuracy: 0.0465
#
# Epoch 00003: val_main_accuracy did not improve from 0.20930
# Epoch 4/30
# 25/25 [==============================] - 2s 63ms/step - loss: 3.1098 - main_loss: 1.9521 - aux1_loss: 1.9178 - aux2_loss: 1.9412 - main_accuracy: 0.1588 - aux1_accuracy: 0.2000 - aux2_accuracy: 0.1588 - val_loss: 3.1191 - val_main_loss: 1.9502 - val_aux1_loss: 1.9467 - val_aux2_loss: 1.9498 - val_main_accuracy: 0.0465 - val_aux1_accuracy: 0.2093 - val_aux2_accuracy: 0.0465
#
# Epoch 00004: val_main_accuracy did not improve from 0.20930
# Epoch 5/30
# 25/25 [==============================] - 2s 63ms/step - loss: 3.0936 - main_loss: 1.9430 - aux1_loss: 1.9027 - aux2_loss: 1.9326 - main_accuracy: 0.1412 - aux1_accuracy: 0.2176 - aux2_accuracy: 0.2000 - val_loss: 3.1182 - val_main_loss: 1.9486 - val_aux1_loss: 1.9494 - val_aux2_loss: 1.9493 - val_main_accuracy: 0.2093 - val_aux1_accuracy: 0.0698 - val_aux2_accuracy: 0.1395
#
# Epoch 00005: val_main_accuracy did not improve from 0.20930
# Epoch 6/30
# 25/25 [==============================] - 2s 63ms/step - loss: 3.0816 - main_loss: 1.9386 - aux1_loss: 1.8977 - aux2_loss: 1.9126 - main_accuracy: 0.1588 - aux1_accuracy: 0.2235 - aux2_accuracy: 0.1824 - val_loss: 3.1224 - val_main_loss: 1.9523 - val_aux1_loss: 1.9488 - val_aux2_loss: 1.9516 - val_main_accuracy: 0.0930 - val_aux1_accuracy: 0.1628 - val_aux2_accuracy: 0.0698
#
# Epoch 00006: val_main_accuracy did not improve from 0.20930
# Epoch 7/30
# 25/25 [==============================] - 2s 63ms/step - loss: 3.0016 - main_loss: 1.8944 - aux1_loss: 1.8086 - aux2_loss: 1.8821 - main_accuracy: 0.2647 - aux1_accuracy: 0.3294 - aux2_accuracy: 0.2235 - val_loss: 3.1161 - val_main_loss: 1.9494 - val_aux1_loss: 1.9390 - val_aux2_loss: 1.9499 - val_main_accuracy: 0.0930 - val_aux1_accuracy: 0.2791 - val_aux2_accuracy: 0.2093
#
# Epoch 00007: val_main_accuracy did not improve from 0.20930
# Epoch 8/30
# 25/25 [==============================] - 2s 63ms/step - loss: 2.7930 - main_loss: 1.7448 - aux1_loss: 1.7543 - aux2_loss: 1.7397 - main_accuracy: 0.2706 - aux1_accuracy: 0.3118 - aux2_accuracy: 0.2765 - val_loss: 3.0969 - val_main_loss: 1.9366 - val_aux1_loss: 1.9301 - val_aux2_loss: 1.9374 - val_main_accuracy: 0.0930 - val_aux1_accuracy: 0.3256 - val_aux2_accuracy: 0.0930
#
# Epoch 00008: val_main_accuracy did not improve from 0.20930
# Epoch 9/30
# 25/25 [==============================] - 2s 62ms/step - loss: 2.6926 - main_loss: 1.6981 - aux1_loss: 1.6421 - aux2_loss: 1.6732 - main_accuracy: 0.2941 - aux1_accuracy: 0.3353 - aux2_accuracy: 0.3059 - val_loss: 3.0827 - val_main_loss: 1.9290 - val_aux1_loss: 1.9148 - val_aux2_loss: 1.9308 - val_main_accuracy: 0.2093 - val_aux1_accuracy: 0.3256 - val_aux2_accuracy: 0.2093
#
# Epoch 00009: val_main_accuracy did not improve from 0.20930
# Epoch 10/30
# 25/25 [==============================] - 2s 63ms/step - loss: 2.3403 - main_loss: 1.4709 - aux1_loss: 1.4801 - aux2_loss: 1.4177 - main_accuracy: 0.3471 - aux1_accuracy: 0.4235 - aux2_accuracy: 0.4059 - val_loss: 3.0628 - val_main_loss: 1.9155 - val_aux1_loss: 1.9089 - val_aux2_loss: 1.9153 - val_main_accuracy: 0.2093 - val_aux1_accuracy: 0.3721 - val_aux2_accuracy: 0.2093
#
# Epoch 00010: val_main_accuracy did not improve from 0.20930
# Epoch 11/30
# 25/25 [==============================] - 2s 62ms/step - loss: 2.2295 - main_loss: 1.3895 - aux1_loss: 1.3704 - aux2_loss: 1.4295 - main_accuracy: 0.3765 - aux1_accuracy: 0.4588 - aux2_accuracy: 0.3765 - val_loss: 3.0530 - val_main_loss: 1.9101 - val_aux1_loss: 1.8922 - val_aux2_loss: 1.9173 - val_main_accuracy: 0.2093 - val_aux1_accuracy: 0.3953 - val_aux2_accuracy: 0.1163
#
# Epoch 00011: val_main_accuracy did not improve from 0.20930
# Epoch 12/30
# 25/25 [==============================] - 2s 63ms/step - loss: 2.1316 - main_loss: 1.3622 - aux1_loss: 1.2372 - aux2_loss: 1.3275 - main_accuracy: 0.4000 - aux1_accuracy: 0.5235 - aux2_accuracy: 0.4118 - val_loss: 3.0408 - val_main_loss: 1.9068 - val_aux1_loss: 1.8753 - val_aux2_loss: 1.9044 - val_main_accuracy: 0.0930 - val_aux1_accuracy: 0.3721 - val_aux2_accuracy: 0.2093
#
# Epoch 00012: val_main_accuracy did not improve from 0.20930
# Epoch 13/30
# 25/25 [==============================] - 2s 64ms/step - loss: 2.1529 - main_loss: 1.3728 - aux1_loss: 1.2947 - aux2_loss: 1.3055 - main_accuracy: 0.3765 - aux1_accuracy: 0.4588 - aux2_accuracy: 0.4765 - val_loss: 3.0450 - val_main_loss: 1.9107 - val_aux1_loss: 1.8740 - val_aux2_loss: 1.9070 - val_main_accuracy: 0.0930 - val_aux1_accuracy: 0.0930 - val_aux2_accuracy: 0.0930
#
# Epoch 00013: val_main_accuracy did not improve from 0.20930
# Epoch 14/30
# 25/25 [==============================] - 2s 63ms/step - loss: 1.7279 - main_loss: 1.0702 - aux1_loss: 1.0564 - aux2_loss: 1.1357 - main_accuracy: 0.4647 - aux1_accuracy: 0.6118 - aux2_accuracy: 0.5000 - val_loss: 3.0660 - val_main_loss: 1.9382 - val_aux1_loss: 1.8553 - val_aux2_loss: 1.9041 - val_main_accuracy: 0.1860 - val_aux1_accuracy: 0.1860 - val_aux2_accuracy: 0.0930
#
# Epoch 00014: val_main_accuracy did not improve from 0.20930
# Epoch 15/30
# 25/25 [==============================] - 2s 63ms/step - loss: 1.6839 - main_loss: 1.0770 - aux1_loss: 0.9919 - aux2_loss: 1.0312 - main_accuracy: 0.5235 - aux1_accuracy: 0.5941 - aux2_accuracy: 0.5353 - val_loss: 3.0323 - val_main_loss: 1.9229 - val_aux1_loss: 1.8160 - val_aux2_loss: 1.8820 - val_main_accuracy: 0.0930 - val_aux1_accuracy: 0.1628 - val_aux2_accuracy: 0.2326
#
# Epoch 00015: val_main_accuracy did not improve from 0.20930
# Epoch 16/30
# 25/25 [==============================] - 2s 63ms/step - loss: 1.9263 - main_loss: 1.2817 - aux1_loss: 1.0154 - aux2_loss: 1.1333 - main_accuracy: 0.4353 - aux1_accuracy: 0.6176 - aux2_accuracy: 0.5471 - val_loss: 3.0334 - val_main_loss: 1.9074 - val_aux1_loss: 1.8404 - val_aux2_loss: 1.9131 - val_main_accuracy: 0.0930 - val_aux1_accuracy: 0.1163 - val_aux2_accuracy: 0.0930
#
# Epoch 00016: val_main_accuracy did not improve from 0.20930
# Epoch 17/30
# 25/25 [==============================] - 2s 63ms/step - loss: 1.8975 - main_loss: 1.2394 - aux1_loss: 1.0270 - aux2_loss: 1.1667 - main_accuracy: 0.4471 - aux1_accuracy: 0.5882 - aux2_accuracy: 0.5294 - val_loss: 3.0076 - val_main_loss: 1.9014 - val_aux1_loss: 1.8016 - val_aux2_loss: 1.8857 - val_main_accuracy: 0.0930 - val_aux1_accuracy: 0.3256 - val_aux2_accuracy: 0.0930
#
# Epoch 00017: val_main_accuracy did not improve from 0.20930
# Epoch 18/30
# 25/25 [==============================] - 2s 63ms/step - loss: 1.4116 - main_loss: 0.9157 - aux1_loss: 0.8163 - aux2_loss: 0.8366 - main_accuracy: 0.5647 - aux1_accuracy: 0.7118 - aux2_accuracy: 0.6412 - val_loss: 2.7955 - val_main_loss: 1.7655 - val_aux1_loss: 1.6805 - val_aux2_loss: 1.7529 - val_main_accuracy: 0.2558 - val_aux1_accuracy: 0.3023 - val_aux2_accuracy: 0.3023
#
# Epoch 00018: val_main_accuracy improved from 0.20930 to 0.25581, saving model to checkpoint/modelGoogLeNet_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelGoogLeNet_train_new.csv/assets
# Epoch 19/30
# 25/25 [==============================] - 2s 63ms/step - loss: 1.2379 - main_loss: 0.8117 - aux1_loss: 0.7063 - aux2_loss: 0.7145 - main_accuracy: 0.6294 - aux1_accuracy: 0.7353 - aux2_accuracy: 0.7000 - val_loss: 2.7954 - val_main_loss: 1.8080 - val_aux1_loss: 1.5967 - val_aux2_loss: 1.6949 - val_main_accuracy: 0.2791 - val_aux1_accuracy: 0.3488 - val_aux2_accuracy: 0.2093
#
# Epoch 00019: val_main_accuracy improved from 0.25581 to 0.27907, saving model to checkpoint/modelGoogLeNet_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelGoogLeNet_train_new.csv/assets
# Epoch 20/30
# 25/25 [==============================] - 2s 65ms/step - loss: 1.2948 - main_loss: 0.8818 - aux1_loss: 0.6957 - aux2_loss: 0.6811 - main_accuracy: 0.6118 - aux1_accuracy: 0.7235 - aux2_accuracy: 0.7235 - val_loss: 2.4326 - val_main_loss: 1.5329 - val_aux1_loss: 1.4586 - val_aux2_loss: 1.5406 - val_main_accuracy: 0.3953 - val_aux1_accuracy: 0.3953 - val_aux2_accuracy: 0.3256
#
# Epoch 00020: val_main_accuracy improved from 0.27907 to 0.39535, saving model to checkpoint/modelGoogLeNet_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelGoogLeNet_train_new.csv/assets
# Epoch 21/30
# 25/25 [==============================] - 2s 64ms/step - loss: 1.0512 - main_loss: 0.6993 - aux1_loss: 0.5816 - aux2_loss: 0.5913 - main_accuracy: 0.7176 - aux1_accuracy: 0.7882 - aux2_accuracy: 0.7882 - val_loss: 2.3392 - val_main_loss: 1.4588 - val_aux1_loss: 1.4716 - val_aux2_loss: 1.4631 - val_main_accuracy: 0.3953 - val_aux1_accuracy: 0.3488 - val_aux2_accuracy: 0.3488
#
# Epoch 00021: val_main_accuracy did not improve from 0.39535
# Epoch 22/30
# 25/25 [==============================] - 2s 62ms/step - loss: 1.3889 - main_loss: 0.9714 - aux1_loss: 0.6641 - aux2_loss: 0.7275 - main_accuracy: 0.6294 - aux1_accuracy: 0.7647 - aux2_accuracy: 0.7000 - val_loss: 2.6583 - val_main_loss: 1.6980 - val_aux1_loss: 1.5757 - val_aux2_loss: 1.6252 - val_main_accuracy: 0.2791 - val_aux1_accuracy: 0.2093 - val_aux2_accuracy: 0.1860
#
# Epoch 00022: val_main_accuracy did not improve from 0.39535
# Epoch 23/30
# 25/25 [==============================] - 2s 63ms/step - loss: 1.3612 - main_loss: 0.9309 - aux1_loss: 0.6543 - aux2_loss: 0.7799 - main_accuracy: 0.6000 - aux1_accuracy: 0.7647 - aux2_accuracy: 0.6529 - val_loss: 1.9762 - val_main_loss: 1.2163 - val_aux1_loss: 1.2527 - val_aux2_loss: 1.2804 - val_main_accuracy: 0.6279 - val_aux1_accuracy: 0.6279 - val_aux2_accuracy: 0.5581
#
# Epoch 00023: val_main_accuracy improved from 0.39535 to 0.62791, saving model to checkpoint/modelGoogLeNet_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelGoogLeNet_train_new.csv/assets
# Epoch 24/30
# 25/25 [==============================] - 2s 62ms/step - loss: 0.8038 - main_loss: 0.5303 - aux1_loss: 0.4619 - aux2_loss: 0.4498 - main_accuracy: 0.8176 - aux1_accuracy: 0.8647 - aux2_accuracy: 0.8529 - val_loss: 2.1140 - val_main_loss: 1.3395 - val_aux1_loss: 1.3461 - val_aux2_loss: 1.2356 - val_main_accuracy: 0.4651 - val_aux1_accuracy: 0.4651 - val_aux2_accuracy: 0.5116
#
# Epoch 00024: val_main_accuracy did not improve from 0.62791
# Epoch 25/30
# 25/25 [==============================] - 2s 63ms/step - loss: 0.5237 - main_loss: 0.3294 - aux1_loss: 0.3634 - aux2_loss: 0.2842 - main_accuracy: 0.8824 - aux1_accuracy: 0.8588 - aux2_accuracy: 0.8941 - val_loss: 1.8856 - val_main_loss: 1.1978 - val_aux1_loss: 1.0919 - val_aux2_loss: 1.2009 - val_main_accuracy: 0.5581 - val_aux1_accuracy: 0.6744 - val_aux2_accuracy: 0.5349
#
# Epoch 00025: val_main_accuracy did not improve from 0.62791
# Epoch 26/30
# 25/25 [==============================] - 2s 62ms/step - loss: 0.4273 - main_loss: 0.2800 - aux1_loss: 0.2921 - aux2_loss: 0.1991 - main_accuracy: 0.9059 - aux1_accuracy: 0.9176 - aux2_accuracy: 0.9471 - val_loss: 2.5678 - val_main_loss: 1.7259 - val_aux1_loss: 1.1926 - val_aux2_loss: 1.6137 - val_main_accuracy: 0.5116 - val_aux1_accuracy: 0.6047 - val_aux2_accuracy: 0.5581
#
# Epoch 00026: val_main_accuracy did not improve from 0.62791
# Epoch 27/30
# 25/25 [==============================] - 2s 62ms/step - loss: 0.5808 - main_loss: 0.3847 - aux1_loss: 0.3420 - aux2_loss: 0.3114 - main_accuracy: 0.8471 - aux1_accuracy: 0.8882 - aux2_accuracy: 0.9118 - val_loss: 1.6461 - val_main_loss: 1.0020 - val_aux1_loss: 1.1028 - val_aux2_loss: 1.0440 - val_main_accuracy: 0.6512 - val_aux1_accuracy: 0.5814 - val_aux2_accuracy: 0.6744
#
# Epoch 00027: val_main_accuracy improved from 0.62791 to 0.65116, saving model to checkpoint/modelGoogLeNet_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelGoogLeNet_train_new.csv/assets
# Epoch 28/30
# 25/25 [==============================] - 2s 64ms/step - loss: 0.6432 - main_loss: 0.4454 - aux1_loss: 0.3105 - aux2_loss: 0.3489 - main_accuracy: 0.8765 - aux1_accuracy: 0.9000 - aux2_accuracy: 0.8882 - val_loss: 2.5590 - val_main_loss: 1.6650 - val_aux1_loss: 1.3218 - val_aux2_loss: 1.6582 - val_main_accuracy: 0.4419 - val_aux1_accuracy: 0.4651 - val_aux2_accuracy: 0.4186
#
# Epoch 00028: val_main_accuracy did not improve from 0.65116
# Epoch 29/30
# 25/25 [==============================] - 2s 62ms/step - loss: 1.0587 - main_loss: 0.7464 - aux1_loss: 0.4922 - aux2_loss: 0.5489 - main_accuracy: 0.7059 - aux1_accuracy: 0.8353 - aux2_accuracy: 0.7824 - val_loss: 3.8613 - val_main_loss: 2.5149 - val_aux1_loss: 2.1194 - val_aux2_loss: 2.3688 - val_main_accuracy: 0.3256 - val_aux1_accuracy: 0.3488 - val_aux2_accuracy: 0.3256
#
# Epoch 00029: val_main_accuracy did not improve from 0.65116
# Epoch 30/30
# 25/25 [==============================] - 2s 62ms/step - loss: 0.5418 - main_loss: 0.3682 - aux1_loss: 0.3126 - aux2_loss: 0.2660 - main_accuracy: 0.8588 - aux1_accuracy: 0.9059 - aux2_accuracy: 0.9294 - val_loss: 1.9264 - val_main_loss: 1.2335 - val_aux1_loss: 1.1205 - val_aux2_loss: 1.1892 - val_main_accuracy: 0.5814 - val_aux1_accuracy: 0.6512 - val_aux2_accuracy: 0.6512
#
# Epoch 00030: val_main_accuracy did not improve from 0.65116

# %%
train_loss=hist1.history['loss']
val_loss=hist1.history['val_loss']
train_acc=hist1.history['accuracy']

val_acc=hist1.history['val_accuracy']
bval_acc=hist2.history['val_accuracy']
cval_acc=hist3.history['val_accuracy']
dval_acc=hist4.history['val_main_accuracy']

epochs = range(len(train_acc))

pyplot.plot(epochs,val_acc,'r', label='VGG')
pyplot.plot(epochs,bval_acc,'b', label='ResNet')
pyplot.plot(epochs,cval_acc,'g', label='AlexNet')
pyplot.plot(epochs,dval_acc,'m', label='GoogLeNet')
pyplot.title('Activations')
pyplot.ylabel('Accuracy')
pyplot.xlabel('Epochs')
pyplot.legend()
pyplot.figure()

labels = ['VGG', 'ResNet', 'AlexNet', 'GoogLeNet']
accuracy = [np.amax(hist1.history['accuracy']),
             np.amax(hist2.history['accuracy']),
             np.amax(hist3.history['accuracy']),
             np.amax(hist4.history['main_accuracy'])]
                       
val_accuracy = [np.amax(hist1.history['val_accuracy']),
             np.amax(hist2.history['val_accuracy']),
             np.amax(hist3.history['val_accuracy']),
             np.amax(hist4.history['val_main_accuracy'])]

x = np.arange(len(labels))  # the label locations
width = 0.40  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, accuracy, width, label='accuracy')
rects2 = ax.bar(x + width/2, val_accuracy, width, label='val_accuracy')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy')
ax.set_title('Architectures on JAFFE dataset')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

fig.tight_layout()

plt.show()
