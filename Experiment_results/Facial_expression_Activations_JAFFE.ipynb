# %%
from google.colab import drive
import tarfile
import os, cv2
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
from keras.utils import np_utils
drive.mount('/content/drive'),
# Out:
# Mounted at /content/drive
# (None,)

# %%
data_path = '/content/drive/MyDrive/facial_expression/jaffe'
data_dir_list = os.listdir(data_path)

img_si=128
num_channel=1

num_epoch=10

img_data_list=[]


for dataset in data_dir_list:
    img_list=os.listdir(data_path+'/'+ dataset)
    print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
    for img in img_list:
        input_img=cv2.imread(data_path + '/'+ dataset + '/'+ img )
        #input_img=cv2.cvtColor(input_img, cv2.COLOR_BGR2GRAY)
        input_img_resize=cv2.resize(input_img,(img_si,img_si))
        img_data_list.append(input_img_resize)
        
img_data = np.array(img_data_list)
img_data = img_data.astype('float32')
img_data = img_data/255
img_data.shape
# Out:
# Loaded the images of dataset-ANGRY
#
# Loaded the images of dataset-DISGUST
#
# Loaded the images of dataset-FEAR
#
# Loaded the images of dataset-NEUTRAL
#
# Loaded the images of dataset-HAPPY
#
# Loaded the images of dataset-SAD
#
# Loaded the images of dataset-SURPRISE
# (213, 128, 128, 3)

# %%
num_classes = 7

num_of_samples = img_data.shape[0]
labels = np.ones((num_of_samples,),dtype='int64')

labels[0:29]=0 #30
labels[30:58]=1 #29
labels[59:90]=2 #32
labels[91:121]=3 #31
labels[122:151]=4 #30
labels[152:182]=5 #31
labels[183:]=6 #30

names = ['ANGRY','DISGUST','FEAR','HAPPY','NEUTRAL','SAD','SURPRISE']

def getLabel(id):
    return ['ANGRY','DISGUST','FEAR','HAPPY','NEUTRAL','SAD','SURPRISE'][id]

# %%
Y = np_utils.to_categorical(labels, num_classes)
#Shuffle the dataset
x,y = shuffle(img_data,Y, random_state=2)
# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)
x_test=X_test
#X_train=X_train.reshape(X_train.shape[0],128,128,1)
#X_test=X_test.reshape(X_test.shape[0],128,128,1)
x_test.shape
# Out:
# (43, 128, 128, 3)

# %%
from keras.models import Sequential
from keras.layers import Dense , Activation , Dropout ,Flatten, BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D, AveragePooling2D
from keras.metrics import categorical_accuracy
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
from keras.optimizers import *
from keras.layers.normalization import BatchNormalization

# %%
input_shape=(img_si,img_si,3)

model1 = Sequential()
model1.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model1.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model1.add(Dropout(0.25))
model1.add(MaxPooling2D(pool_size=(2, 2)))

model1.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model1.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model1.add(Dropout(0.25))
model1.add(MaxPooling2D(pool_size=(2, 2)))

model1.add(Flatten())
model1.add(Dense(256, activation = 'relu'))
model1.add(Dropout(0.5))
model1.add(Dense(7, activation = 'softmax'))

# %%
input_shape=(img_si,img_si,3)

model4 = Sequential()
model4.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'tanh'))
model4.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'tanh'))
model4.add(Dropout(0.25))
model4.add(MaxPooling2D(pool_size=(2, 2)))

model4.add(Conv2D(64, (3, 3), padding='same', activation = 'tanh'))
model4.add(Conv2D(64, (3, 3), padding='same', activation = 'tanh'))
model4.add(Dropout(0.25))
model4.add(MaxPooling2D(pool_size=(2, 2)))

model4.add(Flatten())
model4.add(Dense(256, activation = 'tanh'))
model4.add(Dropout(0.5))
model4.add(Dense(7, activation = 'softmax'))

# %%
input_shape=(img_si,img_si,3)

model16 = Sequential()
model16.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'sigmoid'))
model16.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'sigmoid'))
model16.add(Dropout(0.25))
model16.add(MaxPooling2D(pool_size=(2, 2)))

model16.add(Conv2D(64, (3, 3), padding='same', activation = 'sigmoid'))
model16.add(Conv2D(64, (3, 3), padding='same', activation = 'sigmoid'))
model16.add(Dropout(0.25))
model16.add(MaxPooling2D(pool_size=(2, 2)))

model16.add(Flatten())
model16.add(Dense(256, activation = 'sigmoid'))
model16.add(Dropout(0.5))
model16.add(Dense(7, activation = 'softmax'))

# %%
model1.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

# %%
model4.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

# %%
model16.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

# %%
from keras import callbacks
filename1='model1_train_new.csv'
filename4='model4_train_new.csv'
filename16='model16_train_new.csv'
filename32='model32_train_new.csv'
filename64='model64_train_new.csv'

filepath1 = os.path.join('checkpoint', filename1)
filepath4 = os.path.join('checkpoint', filename4)
filepath16 = os.path.join('checkpoint', filename16)
filepath32 = os.path.join('checkpoint', filename32)
filepath64 = os.path.join('checkpoint', filename64)

checkpoint1 = callbacks.ModelCheckpoint(filepath1, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint4 = callbacks.ModelCheckpoint(filepath4, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint16 = callbacks.ModelCheckpoint(filepath16, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint32 = callbacks.ModelCheckpoint(filepath32, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint64 = callbacks.ModelCheckpoint(filepath64, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')

# %%
hist1 = model1.fit(X_train, y_train, batch_size=7, epochs=30, verbose=1, validation_data=(X_test, y_test),callbacks=checkpoint1)
# Out:
# Epoch 1/30
# 25/25 [==============================] - 34s 735ms/step - loss: 2.5602 - accuracy: 0.2365 - val_loss: 1.9474 - val_accuracy: 0.0930
#
# Epoch 00001: val_accuracy improved from -inf to 0.09302, saving model to checkpoint/model1_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1_train_new.csv/assets
# Epoch 2/30
# 25/25 [==============================] - 18s 708ms/step - loss: 1.9455 - accuracy: 0.0993 - val_loss: 1.9469 - val_accuracy: 0.0698
#
# Epoch 00002: val_accuracy did not improve from 0.09302
# Epoch 3/30
# 25/25 [==============================] - 18s 707ms/step - loss: 1.9175 - accuracy: 0.2024 - val_loss: 1.8972 - val_accuracy: 0.2791
#
# Epoch 00003: val_accuracy improved from 0.09302 to 0.27907, saving model to checkpoint/model1_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1_train_new.csv/assets
# Epoch 4/30
# 25/25 [==============================] - 18s 713ms/step - loss: 1.8319 - accuracy: 0.2952 - val_loss: 1.8054 - val_accuracy: 0.3023
#
# Epoch 00004: val_accuracy improved from 0.27907 to 0.30233, saving model to checkpoint/model1_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1_train_new.csv/assets
# Epoch 5/30
# 25/25 [==============================] - 18s 712ms/step - loss: 1.5890 - accuracy: 0.3666 - val_loss: 1.5073 - val_accuracy: 0.3488
#
# Epoch 00005: val_accuracy improved from 0.30233 to 0.34884, saving model to checkpoint/model1_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1_train_new.csv/assets
# Epoch 6/30
# 25/25 [==============================] - 18s 710ms/step - loss: 1.3759 - accuracy: 0.4842 - val_loss: 1.4183 - val_accuracy: 0.4651
#
# Epoch 00006: val_accuracy improved from 0.34884 to 0.46512, saving model to checkpoint/model1_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1_train_new.csv/assets
# Epoch 7/30
# 25/25 [==============================] - 18s 707ms/step - loss: 1.1298 - accuracy: 0.5839 - val_loss: 1.3199 - val_accuracy: 0.4651
#
# Epoch 00007: val_accuracy did not improve from 0.46512
# Epoch 8/30
# 25/25 [==============================] - 18s 702ms/step - loss: 0.9896 - accuracy: 0.6435 - val_loss: 1.2615 - val_accuracy: 0.4884
#
# Epoch 00008: val_accuracy improved from 0.46512 to 0.48837, saving model to checkpoint/model1_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1_train_new.csv/assets
# Epoch 9/30
# 25/25 [==============================] - 18s 705ms/step - loss: 0.8398 - accuracy: 0.6752 - val_loss: 0.9957 - val_accuracy: 0.6744
#
# Epoch 00009: val_accuracy improved from 0.48837 to 0.67442, saving model to checkpoint/model1_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1_train_new.csv/assets
# Epoch 10/30
# 25/25 [==============================] - 18s 715ms/step - loss: 0.5933 - accuracy: 0.7951 - val_loss: 0.8434 - val_accuracy: 0.7442
#
# Epoch 00010: val_accuracy improved from 0.67442 to 0.74419, saving model to checkpoint/model1_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1_train_new.csv/assets
# Epoch 11/30
# 25/25 [==============================] - 18s 716ms/step - loss: 0.4620 - accuracy: 0.8420 - val_loss: 0.7627 - val_accuracy: 0.6744
#
# Epoch 00011: val_accuracy did not improve from 0.74419
# Epoch 12/30
# 25/25 [==============================] - 18s 717ms/step - loss: 0.4087 - accuracy: 0.8471 - val_loss: 0.7146 - val_accuracy: 0.7209
#
# Epoch 00012: val_accuracy did not improve from 0.74419
# Epoch 13/30
# 25/25 [==============================] - 18s 712ms/step - loss: 0.3382 - accuracy: 0.8897 - val_loss: 0.5927 - val_accuracy: 0.8140
#
# Epoch 00013: val_accuracy improved from 0.74419 to 0.81395, saving model to checkpoint/model1_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1_train_new.csv/assets
# Epoch 14/30
# 25/25 [==============================] - 18s 716ms/step - loss: 0.1662 - accuracy: 0.9250 - val_loss: 0.7125 - val_accuracy: 0.7209
#
# Epoch 00014: val_accuracy did not improve from 0.81395
# Epoch 15/30
# 25/25 [==============================] - 18s 717ms/step - loss: 0.1949 - accuracy: 0.9443 - val_loss: 0.7864 - val_accuracy: 0.6977
#
# Epoch 00015: val_accuracy did not improve from 0.81395
# Epoch 16/30
# 25/25 [==============================] - 18s 717ms/step - loss: 0.3493 - accuracy: 0.8721 - val_loss: 0.7127 - val_accuracy: 0.6977
#
# Epoch 00016: val_accuracy did not improve from 0.81395
# Epoch 17/30
# 25/25 [==============================] - 18s 717ms/step - loss: 0.2028 - accuracy: 0.9282 - val_loss: 0.7879 - val_accuracy: 0.6279
#
# Epoch 00017: val_accuracy did not improve from 0.81395
# Epoch 18/30
# 25/25 [==============================] - 18s 721ms/step - loss: 0.2030 - accuracy: 0.9480 - val_loss: 0.7667 - val_accuracy: 0.6744
#
# Epoch 00018: val_accuracy did not improve from 0.81395
# Epoch 19/30
# 25/25 [==============================] - 18s 718ms/step - loss: 0.1060 - accuracy: 0.9658 - val_loss: 0.6152 - val_accuracy: 0.7442
#
# Epoch 00019: val_accuracy did not improve from 0.81395
# Epoch 20/30
# 25/25 [==============================] - 18s 715ms/step - loss: 0.3018 - accuracy: 0.9268 - val_loss: 0.7159 - val_accuracy: 0.7442
#
# Epoch 00020: val_accuracy did not improve from 0.81395
# Epoch 21/30
# 25/25 [==============================] - 18s 716ms/step - loss: 0.1004 - accuracy: 0.9839 - val_loss: 0.7450 - val_accuracy: 0.7907
#
# Epoch 00021: val_accuracy did not improve from 0.81395
# Epoch 22/30
# 25/25 [==============================] - 18s 716ms/step - loss: 0.0835 - accuracy: 0.9664 - val_loss: 0.7310 - val_accuracy: 0.7674
#
# Epoch 00022: val_accuracy did not improve from 0.81395
# Epoch 23/30
# 25/25 [==============================] - 18s 717ms/step - loss: 0.1377 - accuracy: 0.9690 - val_loss: 0.7302 - val_accuracy: 0.7674
#
# Epoch 00023: val_accuracy did not improve from 0.81395
# Epoch 24/30
# 25/25 [==============================] - 18s 717ms/step - loss: 0.1352 - accuracy: 0.9696 - val_loss: 0.7326 - val_accuracy: 0.7442
#
# Epoch 00024: val_accuracy did not improve from 0.81395
# Epoch 25/30
# 25/25 [==============================] - 18s 713ms/step - loss: 0.1471 - accuracy: 0.9737 - val_loss: 0.7146 - val_accuracy: 0.7442
#
# Epoch 00025: val_accuracy did not improve from 0.81395
# Epoch 26/30
# 25/25 [==============================] - 18s 714ms/step - loss: 0.0741 - accuracy: 0.9813 - val_loss: 0.7942 - val_accuracy: 0.6977
#
# Epoch 00026: val_accuracy did not improve from 0.81395
# Epoch 27/30
# 25/25 [==============================] - 18s 715ms/step - loss: 0.1127 - accuracy: 0.9766 - val_loss: 0.6247 - val_accuracy: 0.8140
#
# Epoch 00027: val_accuracy did not improve from 0.81395
# Epoch 28/30
# 25/25 [==============================] - 18s 711ms/step - loss: 0.0764 - accuracy: 0.9755 - val_loss: 0.6943 - val_accuracy: 0.7442
#
# Epoch 00028: val_accuracy did not improve from 0.81395
# Epoch 29/30
# 25/25 [==============================] - 18s 714ms/step - loss: 0.0217 - accuracy: 0.9925 - val_loss: 0.9001 - val_accuracy: 0.6977
#
# Epoch 00029: val_accuracy did not improve from 0.81395
# Epoch 30/30
# 25/25 [==============================] - 18s 714ms/step - loss: 0.0216 - accuracy: 0.9930 - val_loss: 0.6805 - val_accuracy: 0.7209
#
# Epoch 00030: val_accuracy did not improve from 0.81395

# %%
hist4 = model4.fit(X_train, y_train, batch_size=7, epochs=30, verbose=1, validation_data=(X_test, y_test),callbacks=checkpoint4)
# Out:
# Epoch 1/30
# 25/25 [==============================] - 20s 747ms/step - loss: 5.0397 - accuracy: 0.1445 - val_loss: 2.5167 - val_accuracy: 0.2326
#
# Epoch 00001: val_accuracy improved from -inf to 0.23256, saving model to checkpoint/model4_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model4_train_new.csv/assets
# Epoch 2/30
# 25/25 [==============================] - 18s 729ms/step - loss: 3.0928 - accuracy: 0.1656 - val_loss: 1.9504 - val_accuracy: 0.2093
#
# Epoch 00002: val_accuracy did not improve from 0.23256
# Epoch 3/30
# 25/25 [==============================] - 18s 720ms/step - loss: 2.5744 - accuracy: 0.1283 - val_loss: 2.0209 - val_accuracy: 0.0930
#
# Epoch 00003: val_accuracy did not improve from 0.23256
# Epoch 4/30
# 25/25 [==============================] - 18s 719ms/step - loss: 2.5895 - accuracy: 0.1358 - val_loss: 2.0503 - val_accuracy: 0.0930
#
# Epoch 00004: val_accuracy did not improve from 0.23256
# Epoch 5/30
# 25/25 [==============================] - 18s 717ms/step - loss: 2.4924 - accuracy: 0.1632 - val_loss: 2.1010 - val_accuracy: 0.0930
#
# Epoch 00005: val_accuracy did not improve from 0.23256
# Epoch 6/30
# 25/25 [==============================] - 18s 728ms/step - loss: 2.5864 - accuracy: 0.1180 - val_loss: 2.0583 - val_accuracy: 0.0930
#
# Epoch 00006: val_accuracy did not improve from 0.23256
# Epoch 7/30
# 25/25 [==============================] - 18s 726ms/step - loss: 2.5225 - accuracy: 0.1225 - val_loss: 2.1067 - val_accuracy: 0.0930
#
# Epoch 00007: val_accuracy did not improve from 0.23256
# Epoch 8/30
# 25/25 [==============================] - 18s 728ms/step - loss: 2.4501 - accuracy: 0.2119 - val_loss: 1.9322 - val_accuracy: 0.0698
#
# Epoch 00008: val_accuracy did not improve from 0.23256
# Epoch 9/30
# 25/25 [==============================] - 18s 728ms/step - loss: 2.5139 - accuracy: 0.1672 - val_loss: 2.1607 - val_accuracy: 0.0930
#
# Epoch 00009: val_accuracy did not improve from 0.23256
# Epoch 10/30
# 25/25 [==============================] - 18s 720ms/step - loss: 2.3979 - accuracy: 0.2037 - val_loss: 2.0318 - val_accuracy: 0.0930
#
# Epoch 00010: val_accuracy did not improve from 0.23256
# Epoch 11/30
# 25/25 [==============================] - 18s 727ms/step - loss: 2.3728 - accuracy: 0.1560 - val_loss: 2.0769 - val_accuracy: 0.0930
#
# Epoch 00011: val_accuracy did not improve from 0.23256
# Epoch 12/30
# 25/25 [==============================] - 18s 727ms/step - loss: 2.5119 - accuracy: 0.1545 - val_loss: 2.0031 - val_accuracy: 0.0930
#
# Epoch 00012: val_accuracy did not improve from 0.23256
# Epoch 13/30
# 25/25 [==============================] - 18s 722ms/step - loss: 2.3701 - accuracy: 0.1776 - val_loss: 2.0993 - val_accuracy: 0.0930
#
# Epoch 00013: val_accuracy did not improve from 0.23256
# Epoch 14/30
# 25/25 [==============================] - 18s 725ms/step - loss: 2.5574 - accuracy: 0.2010 - val_loss: 1.9574 - val_accuracy: 0.2326
#
# Epoch 00014: val_accuracy did not improve from 0.23256
# Epoch 15/30
# 25/25 [==============================] - 18s 725ms/step - loss: 2.5299 - accuracy: 0.1566 - val_loss: 1.9738 - val_accuracy: 0.0930
#
# Epoch 00015: val_accuracy did not improve from 0.23256
# Epoch 16/30
# 25/25 [==============================] - 18s 723ms/step - loss: 2.6149 - accuracy: 0.1306 - val_loss: 2.0306 - val_accuracy: 0.0930
#
# Epoch 00016: val_accuracy did not improve from 0.23256
# Epoch 17/30
# 25/25 [==============================] - 18s 713ms/step - loss: 2.6769 - accuracy: 0.1193 - val_loss: 1.9858 - val_accuracy: 0.1860
#
# Epoch 00017: val_accuracy did not improve from 0.23256
# Epoch 18/30
# 25/25 [==============================] - 18s 718ms/step - loss: 2.4225 - accuracy: 0.1365 - val_loss: 2.0672 - val_accuracy: 0.0930
#
# Epoch 00018: val_accuracy did not improve from 0.23256
# Epoch 19/30
# 25/25 [==============================] - 18s 731ms/step - loss: 2.5086 - accuracy: 0.0667 - val_loss: 1.9711 - val_accuracy: 0.0698
#
# Epoch 00019: val_accuracy did not improve from 0.23256
# Epoch 20/30
# 25/25 [==============================] - 18s 732ms/step - loss: 2.3414 - accuracy: 0.1751 - val_loss: 2.0426 - val_accuracy: 0.0930
#
# Epoch 00020: val_accuracy did not improve from 0.23256
# Epoch 21/30
# 25/25 [==============================] - 18s 731ms/step - loss: 2.3713 - accuracy: 0.1453 - val_loss: 2.0327 - val_accuracy: 0.0930
#
# Epoch 00021: val_accuracy did not improve from 0.23256
# Epoch 22/30
# 25/25 [==============================] - 18s 730ms/step - loss: 2.4539 - accuracy: 0.1555 - val_loss: 2.0019 - val_accuracy: 0.0930
#
# Epoch 00022: val_accuracy did not improve from 0.23256
# Epoch 23/30
# 25/25 [==============================] - 19s 756ms/step - loss: 2.2256 - accuracy: 0.2559 - val_loss: 2.0567 - val_accuracy: 0.0930
#
# Epoch 00023: val_accuracy did not improve from 0.23256
# Epoch 24/30
# 25/25 [==============================] - 18s 737ms/step - loss: 2.2383 - accuracy: 0.1706 - val_loss: 2.0103 - val_accuracy: 0.0930
#
# Epoch 00024: val_accuracy did not improve from 0.23256
# Epoch 25/30
# 25/25 [==============================] - 18s 730ms/step - loss: 2.3902 - accuracy: 0.0737 - val_loss: 2.1075 - val_accuracy: 0.0930
#
# Epoch 00025: val_accuracy did not improve from 0.23256
# Epoch 26/30
# 25/25 [==============================] - 18s 733ms/step - loss: 2.6710 - accuracy: 0.1037 - val_loss: 2.0130 - val_accuracy: 0.2093
#
# Epoch 00026: val_accuracy did not improve from 0.23256
# Epoch 27/30
# 25/25 [==============================] - 18s 731ms/step - loss: 2.5120 - accuracy: 0.1083 - val_loss: 2.0119 - val_accuracy: 0.0930
#
# Epoch 00027: val_accuracy did not improve from 0.23256
# Epoch 28/30
# 25/25 [==============================] - 18s 728ms/step - loss: 2.4828 - accuracy: 0.1262 - val_loss: 2.0830 - val_accuracy: 0.0930
#
# Epoch 00028: val_accuracy did not improve from 0.23256
# Epoch 29/30
# 25/25 [==============================] - 18s 727ms/step - loss: 2.4154 - accuracy: 0.1529 - val_loss: 2.0122 - val_accuracy: 0.0930
#
# Epoch 00029: val_accuracy did not improve from 0.23256
# Epoch 30/30
# 25/25 [==============================] - 18s 721ms/step - loss: 2.2261 - accuracy: 0.1500 - val_loss: 2.0460 - val_accuracy: 0.0930
#
# Epoch 00030: val_accuracy did not improve from 0.23256

# %%
hist16 = model16.fit(X_train, y_train, batch_size=7, epochs=30, verbose=1, validation_data=(X_test, y_test),callbacks=checkpoint16)
# Out:
# Epoch 1/30
# 25/25 [==============================] - 20s 741ms/step - loss: 3.4755 - accuracy: 0.0872 - val_loss: 2.8731 - val_accuracy: 0.2093
#
# Epoch 00001: val_accuracy improved from -inf to 0.20930, saving model to checkpoint/model16_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model16_train_new.csv/assets
# Epoch 2/30
# 25/25 [==============================] - 18s 729ms/step - loss: 2.7852 - accuracy: 0.1278 - val_loss: 2.4952 - val_accuracy: 0.2093
#
# Epoch 00002: val_accuracy did not improve from 0.20930
# Epoch 3/30
# 25/25 [==============================] - 18s 723ms/step - loss: 2.4055 - accuracy: 0.1449 - val_loss: 2.2354 - val_accuracy: 0.0465
#
# Epoch 00003: val_accuracy did not improve from 0.20930
# Epoch 4/30
# 25/25 [==============================] - 18s 726ms/step - loss: 2.3340 - accuracy: 0.1266 - val_loss: 2.0416 - val_accuracy: 0.2093
#
# Epoch 00004: val_accuracy did not improve from 0.20930
# Epoch 5/30
# 25/25 [==============================] - 18s 727ms/step - loss: 2.2895 - accuracy: 0.1197 - val_loss: 2.0045 - val_accuracy: 0.1163
#
# Epoch 00005: val_accuracy did not improve from 0.20930
# Epoch 6/30
# 25/25 [==============================] - 18s 728ms/step - loss: 2.1887 - accuracy: 0.0915 - val_loss: 1.9834 - val_accuracy: 0.0465
#
# Epoch 00006: val_accuracy did not improve from 0.20930
# Epoch 7/30
# 25/25 [==============================] - 18s 725ms/step - loss: 2.4008 - accuracy: 0.1216 - val_loss: 2.0026 - val_accuracy: 0.0465
#
# Epoch 00007: val_accuracy did not improve from 0.20930
# Epoch 8/30
# 25/25 [==============================] - 18s 720ms/step - loss: 2.1697 - accuracy: 0.1231 - val_loss: 2.0227 - val_accuracy: 0.0930
#
# Epoch 00008: val_accuracy did not improve from 0.20930
# Epoch 9/30
# 25/25 [==============================] - 18s 727ms/step - loss: 2.2115 - accuracy: 0.1504 - val_loss: 2.0068 - val_accuracy: 0.1163
#
# Epoch 00009: val_accuracy did not improve from 0.20930
# Epoch 10/30
# 25/25 [==============================] - 18s 727ms/step - loss: 2.3297 - accuracy: 0.1264 - val_loss: 2.0067 - val_accuracy: 0.0930
#
# Epoch 00010: val_accuracy did not improve from 0.20930
# Epoch 11/30
# 25/25 [==============================] - 18s 724ms/step - loss: 2.1754 - accuracy: 0.1143 - val_loss: 1.9827 - val_accuracy: 0.0930
#
# Epoch 00011: val_accuracy did not improve from 0.20930
# Epoch 12/30
# 25/25 [==============================] - 18s 724ms/step - loss: 2.1790 - accuracy: 0.1616 - val_loss: 2.0115 - val_accuracy: 0.0465
#
# Epoch 00012: val_accuracy did not improve from 0.20930
# Epoch 13/30
# 25/25 [==============================] - 18s 720ms/step - loss: 2.1390 - accuracy: 0.1879 - val_loss: 2.0098 - val_accuracy: 0.2093
#
# Epoch 00013: val_accuracy did not improve from 0.20930
# Epoch 14/30
# 25/25 [==============================] - 18s 725ms/step - loss: 2.2287 - accuracy: 0.0983 - val_loss: 1.9947 - val_accuracy: 0.0465
#
# Epoch 00014: val_accuracy did not improve from 0.20930
# Epoch 15/30
# 25/25 [==============================] - 18s 733ms/step - loss: 2.0323 - accuracy: 0.1210 - val_loss: 2.0138 - val_accuracy: 0.1163
#
# Epoch 00015: val_accuracy did not improve from 0.20930
# Epoch 16/30
# 25/25 [==============================] - 19s 764ms/step - loss: 2.1744 - accuracy: 0.1185 - val_loss: 2.0105 - val_accuracy: 0.0930
#
# Epoch 00016: val_accuracy did not improve from 0.20930
# Epoch 17/30
# 25/25 [==============================] - 18s 737ms/step - loss: 2.1196 - accuracy: 0.1990 - val_loss: 2.0067 - val_accuracy: 0.0930
#
# Epoch 00017: val_accuracy did not improve from 0.20930
# Epoch 18/30
# 25/25 [==============================] - 18s 736ms/step - loss: 1.9830 - accuracy: 0.1635 - val_loss: 2.0128 - val_accuracy: 0.0930
#
# Epoch 00018: val_accuracy did not improve from 0.20930
# Epoch 19/30
# 25/25 [==============================] - 18s 736ms/step - loss: 2.1494 - accuracy: 0.1544 - val_loss: 2.0192 - val_accuracy: 0.0930
#
# Epoch 00019: val_accuracy did not improve from 0.20930
# Epoch 20/30
# 25/25 [==============================] - 18s 734ms/step - loss: 2.1576 - accuracy: 0.1892 - val_loss: 1.9920 - val_accuracy: 0.2093
#
# Epoch 00020: val_accuracy did not improve from 0.20930
# Epoch 21/30
# 25/25 [==============================] - 18s 729ms/step - loss: 2.1376 - accuracy: 0.1204 - val_loss: 2.0704 - val_accuracy: 0.0465
#
# Epoch 00021: val_accuracy did not improve from 0.20930
# Epoch 22/30
# 25/25 [==============================] - 18s 732ms/step - loss: 2.0959 - accuracy: 0.1416 - val_loss: 2.0001 - val_accuracy: 0.0930
#
# Epoch 00022: val_accuracy did not improve from 0.20930
# Epoch 23/30
# 25/25 [==============================] - 18s 729ms/step - loss: 2.1676 - accuracy: 0.1365 - val_loss: 2.0149 - val_accuracy: 0.0465
#
# Epoch 00023: val_accuracy did not improve from 0.20930
# Epoch 24/30
# 25/25 [==============================] - 18s 725ms/step - loss: 2.1219 - accuracy: 0.1477 - val_loss: 1.9804 - val_accuracy: 0.1163
#
# Epoch 00024: val_accuracy did not improve from 0.20930
# Epoch 25/30
# 25/25 [==============================] - 18s 725ms/step - loss: 2.0990 - accuracy: 0.1488 - val_loss: 2.0137 - val_accuracy: 0.0930
#
# Epoch 00025: val_accuracy did not improve from 0.20930
# Epoch 26/30
# 25/25 [==============================] - 18s 726ms/step - loss: 2.0861 - accuracy: 0.1791 - val_loss: 2.0229 - val_accuracy: 0.0465
#
# Epoch 00026: val_accuracy did not improve from 0.20930
# Epoch 27/30
# 25/25 [==============================] - 18s 728ms/step - loss: 2.0932 - accuracy: 0.1417 - val_loss: 2.0138 - val_accuracy: 0.0930
#
# Epoch 00027: val_accuracy did not improve from 0.20930
# Epoch 28/30
# 25/25 [==============================] - 18s 733ms/step - loss: 1.9887 - accuracy: 0.1903 - val_loss: 2.0092 - val_accuracy: 0.0465
#
# Epoch 00028: val_accuracy did not improve from 0.20930
# Epoch 29/30
# 25/25 [==============================] - 18s 740ms/step - loss: 2.0798 - accuracy: 0.1575 - val_loss: 2.0408 - val_accuracy: 0.0465
#
# Epoch 00029: val_accuracy did not improve from 0.20930
# Epoch 30/30
# 25/25 [==============================] - 18s 737ms/step - loss: 2.0972 - accuracy: 0.1488 - val_loss: 1.9742 - val_accuracy: 0.2093
#
# Epoch 00030: val_accuracy did not improve from 0.20930

# %%
train_loss=hist1.history['loss']
val_loss=hist1.history['val_loss']
train_acc=hist1.history['accuracy']

val_acc=hist1.history['val_accuracy']
bval_acc=hist4.history['val_accuracy']
cval_acc=hist16.history['val_accuracy']

epochs = range(len(train_acc))

pyplot.plot(epochs,train_loss,'r', label='train_loss')
pyplot.plot(epochs,val_loss,'b', label='val_loss')
pyplot.title('train_loss vs val_loss')
pyplot.legend()
pyplot.figure()

pyplot.plot(epochs,val_acc,'r', label='ReLU')
pyplot.plot(epochs,bval_acc,'b', label='Tanh')
pyplot.plot(epochs,cval_acc,'g', label='Sigmoid')
pyplot.title('Activations')
pyplot.ylabel('Accuracy')
pyplot.xlabel('Epochs')
pyplot.legend()
pyplot.figure()
