# %%
from google.colab import drive
import tarfile
import os, cv2
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
from keras.utils import np_utils
drive.mount('/content/drive'),
# Out:
# Mounted at /content/drive
# (None,)

# %%
data_path = '/content/drive/MyDrive/facial_expression/jaffe'
data_dir_list = os.listdir(data_path)

img_si=64
num_channel=1
img_data_list=[]

for dataset in data_dir_list:
    img_list=os.listdir(data_path+'/'+ dataset)
    print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
    for img in img_list:
        input_img=cv2.imread(data_path + '/'+ dataset + '/'+ img )
        #input_img=cv2.cvtColor(input_img, cv2.COLOR_BGR2GRAY)
        input_img_resize=cv2.resize(input_img,(img_si,img_si))
        img_data_list.append(input_img_resize)
        
img_data = np.array(img_data_list)
img_data = img_data.astype('float32')
img_data = img_data/255
img_data.shape
# Out:
# Loaded the images of dataset-ANGRY
#
# Loaded the images of dataset-DISGUST
#
# Loaded the images of dataset-FEAR
#
# Loaded the images of dataset-NEUTRAL
#
# Loaded the images of dataset-HAPPY
#
# Loaded the images of dataset-SAD
#
# Loaded the images of dataset-SURPRISE
# (213, 64, 64, 3)

# %%
num_classes = 7

num_of_samples = img_data.shape[0]
labels = np.ones((num_of_samples,),dtype='int64')

labels[0:29]=0 #30
labels[30:58]=1 #29
labels[59:90]=2 #32
labels[91:121]=3 #31
labels[122:151]=4 #30
labels[152:182]=5 #31
labels[183:]=6 #30

names = ['ANGRY','DISGUST','FEAR','HAPPY','NEUTRAL','SAD','SURPRISE']

def getLabel(id):
    return ['ANGRY','DISGUST','FEAR','HAPPY','NEUTRAL','SAD','SURPRISE'][id]

# %%
Y = np_utils.to_categorical(labels, num_classes)
#Shuffle the dataset
x,y = shuffle(img_data,Y, random_state=2)
# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)
x_test=X_test
#X_train=X_train.reshape(X_train.shape[0],128,128,1)
#X_test=X_test.reshape(X_test.shape[0],128,128,1)
x_test.shape
# Out:
# (43, 64, 64, 3)

# %%
from keras.models import Sequential
from keras.layers import Dense , Activation , Dropout ,Flatten, BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D, AveragePooling2D
from keras.metrics import categorical_accuracy
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
from keras.optimizers import *
from keras.layers.normalization import BatchNormalization
from tensorflow.keras.layers import Input, Concatenate
from tensorflow.keras import regularizers

# %%
import os
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow.keras import regularizers
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Input, Flatten, Dense, Dropout, BatchNormalization
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, ZeroPadding2D
from tensorflow.keras.layers import Concatenate
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam, SGD

# %%
input_shape=(img_si,img_si,3)

model = Sequential()
model.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model.add(Dropout(0.25))
model.add(MaxPooling2D(pool_size=(2, 2)))

model.add(Flatten())
model.add(Dense(256, activation = 'relu'))
model.add(Dropout(0.5))
model.add(Dense(7, activation = 'softmax'))

# %%
model.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

# %%
from keras import callbacks
filename1='modelNorm_train_new.csv'
filename4='modelCentering_train_new.csv'
filename16='modelWhitening_train_new.csv'
filename64='modelNone_train_new.csv'

filepath1 = os.path.join('checkpoint', filename1)
filepath4 = os.path.join('checkpoint', filename4)
filepath16 = os.path.join('checkpoint', filename16)
filepath64 = os.path.join('checkpoint', filename64)

checkpoint1 = callbacks.ModelCheckpoint(filepath1, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint4 = callbacks.ModelCheckpoint(filepath4, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint16 = callbacks.ModelCheckpoint(filepath16, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint64 = callbacks.ModelCheckpoint(filepath64, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')

# %%
from sklearn.decomposition import PCA

dataNorm = tf.keras.preprocessing.image.ImageDataGenerator(
    featurewise_std_normalization=True,
    validation_split=0.2)

dataCentering = tf.keras.preprocessing.image.ImageDataGenerator(
    samplewise_center=True,
    validation_split=0.2)

dataWhitening = tf.keras.preprocessing.image.ImageDataGenerator(
    zca_whitening=True,
    validation_split=0.2)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:349: UserWarning: This ImageDataGenerator specifies `featurewise_std_normalization`, which overrides setting of `featurewise_center`.
#   warnings.warn('This ImageDataGenerator specifies '
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:337: UserWarning: This ImageDataGenerator specifies `zca_whitening`, which overrides setting of `featurewise_center`.
#   warnings.warn('This ImageDataGenerator specifies '

# %%
dataNorm.fit(X_train)
hist1 = model.fit(dataNorm.flow(X_train, y_train, batch_size=7, subset='training'),
                  validation_data=dataNorm.flow(X_train, y_train, batch_size=7, subset='validation'), epochs=60, callbacks=checkpoint1)
# Out:
# Epoch 1/60
# 20/20 [==============================] - 5s 223ms/step - loss: 2.0408 - accuracy: 0.1691 - val_loss: 1.9391 - val_accuracy: 0.1765
#
# Epoch 00001: val_accuracy improved from -inf to 0.17647, saving model to checkpoint/modelNorm_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelNorm_train_new.csv/assets
# Epoch 2/60
# 20/20 [==============================] - 4s 214ms/step - loss: 1.9312 - accuracy: 0.1765 - val_loss: 1.9342 - val_accuracy: 0.1765
#
# Epoch 00002: val_accuracy did not improve from 0.17647
# Epoch 3/60
# 20/20 [==============================] - 4s 213ms/step - loss: 1.8963 - accuracy: 0.2574 - val_loss: 1.9549 - val_accuracy: 0.2059
#
# Epoch 00003: val_accuracy improved from 0.17647 to 0.20588, saving model to checkpoint/modelNorm_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelNorm_train_new.csv/assets
# Epoch 4/60
# 20/20 [==============================] - 4s 214ms/step - loss: 1.8106 - accuracy: 0.2941 - val_loss: 1.8704 - val_accuracy: 0.2059
#
# Epoch 00004: val_accuracy did not improve from 0.20588
# Epoch 5/60
# 20/20 [==============================] - 4s 213ms/step - loss: 1.7342 - accuracy: 0.3456 - val_loss: 1.7321 - val_accuracy: 0.3824
#
# Epoch 00005: val_accuracy improved from 0.20588 to 0.38235, saving model to checkpoint/modelNorm_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelNorm_train_new.csv/assets
# Epoch 6/60
# 20/20 [==============================] - 4s 221ms/step - loss: 1.5530 - accuracy: 0.4118 - val_loss: 1.6214 - val_accuracy: 0.2941
#
# Epoch 00006: val_accuracy did not improve from 0.38235
# Epoch 7/60
# 20/20 [==============================] - 4s 217ms/step - loss: 1.2919 - accuracy: 0.5662 - val_loss: 1.4827 - val_accuracy: 0.4412
#
# Epoch 00007: val_accuracy improved from 0.38235 to 0.44118, saving model to checkpoint/modelNorm_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelNorm_train_new.csv/assets
# Epoch 8/60
# 20/20 [==============================] - 4s 220ms/step - loss: 1.0554 - accuracy: 0.5588 - val_loss: 1.3440 - val_accuracy: 0.4118
#
# Epoch 00008: val_accuracy did not improve from 0.44118
# Epoch 9/60
# 20/20 [==============================] - 4s 215ms/step - loss: 1.0847 - accuracy: 0.5882 - val_loss: 0.9601 - val_accuracy: 0.6471
#
# Epoch 00009: val_accuracy improved from 0.44118 to 0.64706, saving model to checkpoint/modelNorm_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelNorm_train_new.csv/assets
# Epoch 10/60
# 20/20 [==============================] - 4s 223ms/step - loss: 0.7464 - accuracy: 0.7426 - val_loss: 0.9143 - val_accuracy: 0.6176
#
# Epoch 00010: val_accuracy did not improve from 0.64706
# Epoch 11/60
# 20/20 [==============================] - 4s 217ms/step - loss: 0.6688 - accuracy: 0.7426 - val_loss: 0.9189 - val_accuracy: 0.6471
#
# Epoch 00011: val_accuracy did not improve from 0.64706
# Epoch 12/60
# 20/20 [==============================] - 4s 217ms/step - loss: 0.4854 - accuracy: 0.8750 - val_loss: 0.9145 - val_accuracy: 0.6176
#
# Epoch 00012: val_accuracy did not improve from 0.64706
# Epoch 13/60
# 20/20 [==============================] - 4s 217ms/step - loss: 0.5266 - accuracy: 0.8162 - val_loss: 0.7725 - val_accuracy: 0.7353
#
# Epoch 00013: val_accuracy improved from 0.64706 to 0.73529, saving model to checkpoint/modelNorm_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelNorm_train_new.csv/assets
# Epoch 14/60
# 20/20 [==============================] - 4s 216ms/step - loss: 0.4594 - accuracy: 0.8529 - val_loss: 0.6064 - val_accuracy: 0.8235
#
# Epoch 00014: val_accuracy improved from 0.73529 to 0.82353, saving model to checkpoint/modelNorm_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelNorm_train_new.csv/assets
# Epoch 15/60
# 20/20 [==============================] - 4s 219ms/step - loss: 0.3530 - accuracy: 0.8824 - val_loss: 0.4392 - val_accuracy: 0.9412
#
# Epoch 00015: val_accuracy improved from 0.82353 to 0.94118, saving model to checkpoint/modelNorm_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelNorm_train_new.csv/assets
# Epoch 16/60
# 20/20 [==============================] - 4s 216ms/step - loss: 0.2988 - accuracy: 0.8824 - val_loss: 0.4362 - val_accuracy: 0.8529
#
# Epoch 00016: val_accuracy did not improve from 0.94118
# Epoch 17/60
# 20/20 [==============================] - 4s 216ms/step - loss: 0.3235 - accuracy: 0.8750 - val_loss: 0.6237 - val_accuracy: 0.7059
#
# Epoch 00017: val_accuracy did not improve from 0.94118
# Epoch 18/60
# 20/20 [==============================] - 4s 216ms/step - loss: 0.2163 - accuracy: 0.9191 - val_loss: 0.2539 - val_accuracy: 0.9412
#
# Epoch 00018: val_accuracy did not improve from 0.94118
# Epoch 19/60
# 20/20 [==============================] - 4s 215ms/step - loss: 0.2608 - accuracy: 0.8971 - val_loss: 0.4403 - val_accuracy: 0.8824
#
# Epoch 00019: val_accuracy did not improve from 0.94118
# Epoch 20/60
# 20/20 [==============================] - 4s 217ms/step - loss: 0.3289 - accuracy: 0.8897 - val_loss: 0.3683 - val_accuracy: 0.9118
#
# Epoch 00020: val_accuracy did not improve from 0.94118
# Epoch 21/60
# 20/20 [==============================] - 4s 217ms/step - loss: 0.2586 - accuracy: 0.9191 - val_loss: 0.4132 - val_accuracy: 0.8824
#
# Epoch 00021: val_accuracy did not improve from 0.94118
# Epoch 22/60
# 20/20 [==============================] - 4s 220ms/step - loss: 0.2241 - accuracy: 0.9118 - val_loss: 0.3056 - val_accuracy: 0.8824
#
# Epoch 00022: val_accuracy did not improve from 0.94118
# Epoch 23/60
# 20/20 [==============================] - 4s 218ms/step - loss: 0.1205 - accuracy: 0.9632 - val_loss: 0.3478 - val_accuracy: 0.9118
#
# Epoch 00023: val_accuracy did not improve from 0.94118
# Epoch 24/60
# 20/20 [==============================] - 4s 217ms/step - loss: 0.2031 - accuracy: 0.9559 - val_loss: 0.2232 - val_accuracy: 0.9412
#
# Epoch 00024: val_accuracy did not improve from 0.94118
# Epoch 25/60
# 20/20 [==============================] - 4s 217ms/step - loss: 0.0511 - accuracy: 0.9926 - val_loss: 0.1824 - val_accuracy: 0.9412
#
# Epoch 00025: val_accuracy did not improve from 0.94118
# Epoch 26/60
# 20/20 [==============================] - 4s 217ms/step - loss: 0.1017 - accuracy: 0.9559 - val_loss: 0.1117 - val_accuracy: 1.0000
#
# Epoch 00026: val_accuracy improved from 0.94118 to 1.00000, saving model to checkpoint/modelNorm_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelNorm_train_new.csv/assets
# Epoch 27/60
# 20/20 [==============================] - 4s 218ms/step - loss: 0.0922 - accuracy: 0.9632 - val_loss: 0.1600 - val_accuracy: 0.9412
#
# Epoch 00027: val_accuracy did not improve from 1.00000
# Epoch 28/60
# 20/20 [==============================] - 4s 214ms/step - loss: 0.1049 - accuracy: 0.9779 - val_loss: 0.2283 - val_accuracy: 0.9412
#
# Epoch 00028: val_accuracy did not improve from 1.00000
# Epoch 29/60
# 20/20 [==============================] - 4s 215ms/step - loss: 0.0895 - accuracy: 0.9632 - val_loss: 0.2448 - val_accuracy: 0.9118
#
# Epoch 00029: val_accuracy did not improve from 1.00000
# Epoch 30/60
# 20/20 [==============================] - 4s 215ms/step - loss: 0.1720 - accuracy: 0.9559 - val_loss: 0.1743 - val_accuracy: 0.9706
#
# Epoch 00030: val_accuracy did not improve from 1.00000
# Epoch 31/60
# 20/20 [==============================] - 4s 215ms/step - loss: 0.0815 - accuracy: 0.9779 - val_loss: 0.1605 - val_accuracy: 1.0000
#
# Epoch 00031: val_accuracy did not improve from 1.00000
# Epoch 32/60
# 20/20 [==============================] - 4s 222ms/step - loss: 0.0900 - accuracy: 0.9779 - val_loss: 0.1702 - val_accuracy: 0.9706
#
# Epoch 00032: val_accuracy did not improve from 1.00000
# Epoch 33/60
# 20/20 [==============================] - 4s 215ms/step - loss: 0.0671 - accuracy: 0.9706 - val_loss: 0.3396 - val_accuracy: 0.8529
#
# Epoch 00033: val_accuracy did not improve from 1.00000
# Epoch 34/60
# 20/20 [==============================] - 4s 214ms/step - loss: 0.0591 - accuracy: 0.9926 - val_loss: 0.2406 - val_accuracy: 0.8824
#
# Epoch 00034: val_accuracy did not improve from 1.00000
# Epoch 35/60
# 20/20 [==============================] - 4s 213ms/step - loss: 0.0558 - accuracy: 0.9926 - val_loss: 0.1874 - val_accuracy: 0.9706
#
# Epoch 00035: val_accuracy did not improve from 1.00000
# Epoch 36/60
# 20/20 [==============================] - 4s 218ms/step - loss: 0.0271 - accuracy: 0.9926 - val_loss: 0.2249 - val_accuracy: 0.9706
#
# Epoch 00036: val_accuracy did not improve from 1.00000
# Epoch 37/60
# 20/20 [==============================] - 4s 213ms/step - loss: 0.0230 - accuracy: 0.9926 - val_loss: 0.2053 - val_accuracy: 0.9412
#
# Epoch 00037: val_accuracy did not improve from 1.00000
# Epoch 38/60
# 20/20 [==============================] - 4s 214ms/step - loss: 0.0149 - accuracy: 1.0000 - val_loss: 0.1951 - val_accuracy: 0.8824
#
# Epoch 00038: val_accuracy did not improve from 1.00000
# Epoch 39/60
# 20/20 [==============================] - 4s 214ms/step - loss: 0.0656 - accuracy: 0.9853 - val_loss: 0.3074 - val_accuracy: 0.8529
#
# Epoch 00039: val_accuracy did not improve from 1.00000
# Epoch 40/60
# 20/20 [==============================] - 4s 213ms/step - loss: 0.0253 - accuracy: 1.0000 - val_loss: 0.1909 - val_accuracy: 0.9706
#
# Epoch 00040: val_accuracy did not improve from 1.00000
# Epoch 41/60
# 20/20 [==============================] - 4s 214ms/step - loss: 0.0194 - accuracy: 1.0000 - val_loss: 0.2215 - val_accuracy: 0.9412
#
# Epoch 00041: val_accuracy did not improve from 1.00000
# Epoch 42/60
# 20/20 [==============================] - 4s 213ms/step - loss: 0.1316 - accuracy: 0.9559 - val_loss: 0.3972 - val_accuracy: 0.8529
#
# Epoch 00042: val_accuracy did not improve from 1.00000
# Epoch 43/60
# 20/20 [==============================] - 4s 215ms/step - loss: 0.1198 - accuracy: 0.9632 - val_loss: 0.2646 - val_accuracy: 0.9706
#
# Epoch 00043: val_accuracy did not improve from 1.00000
# Epoch 44/60
# 20/20 [==============================] - 4s 213ms/step - loss: 0.1987 - accuracy: 0.9559 - val_loss: 0.1953 - val_accuracy: 0.9706
#
# Epoch 00044: val_accuracy did not improve from 1.00000
# Epoch 45/60
# 20/20 [==============================] - 4s 213ms/step - loss: 0.0675 - accuracy: 0.9779 - val_loss: 0.2282 - val_accuracy: 0.9118
#
# Epoch 00045: val_accuracy did not improve from 1.00000
# Epoch 46/60
# 20/20 [==============================] - 4s 216ms/step - loss: 0.0569 - accuracy: 0.9779 - val_loss: 0.1901 - val_accuracy: 0.9118
#
# Epoch 00046: val_accuracy did not improve from 1.00000
# Epoch 47/60
# 20/20 [==============================] - 4s 214ms/step - loss: 0.0633 - accuracy: 0.9706 - val_loss: 0.1293 - val_accuracy: 0.9412
#
# Epoch 00047: val_accuracy did not improve from 1.00000
# Epoch 48/60
# 20/20 [==============================] - 4s 214ms/step - loss: 0.0386 - accuracy: 0.9853 - val_loss: 0.1372 - val_accuracy: 0.9412
#
# Epoch 00048: val_accuracy did not improve from 1.00000
# Epoch 49/60
# 20/20 [==============================] - 4s 214ms/step - loss: 0.0961 - accuracy: 0.9559 - val_loss: 0.2679 - val_accuracy: 0.8824
#
# Epoch 00049: val_accuracy did not improve from 1.00000
# Epoch 50/60
# 20/20 [==============================] - 4s 217ms/step - loss: 0.0632 - accuracy: 0.9779 - val_loss: 0.2970 - val_accuracy: 0.8529
#
# Epoch 00050: val_accuracy did not improve from 1.00000
# Epoch 51/60
# 20/20 [==============================] - 4s 220ms/step - loss: 0.1017 - accuracy: 0.9779 - val_loss: 0.3737 - val_accuracy: 0.8529
#
# Epoch 00051: val_accuracy did not improve from 1.00000
# Epoch 52/60
# 20/20 [==============================] - 4s 218ms/step - loss: 0.0501 - accuracy: 0.9853 - val_loss: 0.2668 - val_accuracy: 0.9118
#
# Epoch 00052: val_accuracy did not improve from 1.00000
# Epoch 53/60
# 20/20 [==============================] - 4s 218ms/step - loss: 0.0380 - accuracy: 0.9853 - val_loss: 0.3074 - val_accuracy: 0.8824
#
# Epoch 00053: val_accuracy did not improve from 1.00000
# Epoch 54/60
# 20/20 [==============================] - 4s 218ms/step - loss: 0.0486 - accuracy: 0.9706 - val_loss: 0.3336 - val_accuracy: 0.8824
#
# Epoch 00054: val_accuracy did not improve from 1.00000
# Epoch 55/60
# 20/20 [==============================] - 4s 217ms/step - loss: 0.0406 - accuracy: 0.9779 - val_loss: 0.1778 - val_accuracy: 0.9412
#
# Epoch 00055: val_accuracy did not improve from 1.00000
# Epoch 56/60
# 20/20 [==============================] - 4s 220ms/step - loss: 0.0141 - accuracy: 0.9926 - val_loss: 0.1092 - val_accuracy: 0.9412
#
# Epoch 00056: val_accuracy did not improve from 1.00000
# Epoch 57/60
# 20/20 [==============================] - 4s 221ms/step - loss: 0.0450 - accuracy: 0.9779 - val_loss: 0.2418 - val_accuracy: 0.9412
#
# Epoch 00057: val_accuracy did not improve from 1.00000
# Epoch 58/60
# 20/20 [==============================] - 4s 220ms/step - loss: 0.0154 - accuracy: 0.9926 - val_loss: 0.2063 - val_accuracy: 0.9412
#
# Epoch 00058: val_accuracy did not improve from 1.00000
# Epoch 59/60
# 20/20 [==============================] - 4s 219ms/step - loss: 0.0202 - accuracy: 0.9926 - val_loss: 0.2153 - val_accuracy: 0.9118
#
# Epoch 00059: val_accuracy did not improve from 1.00000
# Epoch 60/60
# 20/20 [==============================] - 4s 225ms/step - loss: 0.0434 - accuracy: 0.9779 - val_loss: 0.2350 - val_accuracy: 0.8529
#
# Epoch 00060: val_accuracy did not improve from 1.00000

# %%
dataCentering.fit(X_train)
hist2 = model.fit(dataCentering.flow(X_train, y_train, batch_size=7, subset='training'),
                  validation_data=dataCentering.flow(X_train, y_train, batch_size=7, subset='validation'), epochs=60, callbacks=checkpoint4)
# Out:
# Epoch 1/60
# 20/20 [==============================] - 4s 223ms/step - loss: 0.2097 - accuracy: 0.9706 - val_loss: 0.3441 - val_accuracy: 0.8824
#
# Epoch 00001: val_accuracy improved from -inf to 0.88235, saving model to checkpoint/modelCentering_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelCentering_train_new.csv/assets
# Epoch 2/60
# 20/20 [==============================] - 4s 221ms/step - loss: 0.0865 - accuracy: 0.9853 - val_loss: 0.2733 - val_accuracy: 0.8824
#
# Epoch 00002: val_accuracy did not improve from 0.88235
# Epoch 3/60
# 20/20 [==============================] - 4s 221ms/step - loss: 0.0570 - accuracy: 0.9853 - val_loss: 0.2289 - val_accuracy: 0.9706
#
# Epoch 00003: val_accuracy improved from 0.88235 to 0.97059, saving model to checkpoint/modelCentering_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelCentering_train_new.csv/assets
# Epoch 4/60
# 20/20 [==============================] - 4s 220ms/step - loss: 0.0593 - accuracy: 0.9853 - val_loss: 0.2165 - val_accuracy: 0.9412
#
# Epoch 00004: val_accuracy did not improve from 0.97059
# Epoch 5/60
# 20/20 [==============================] - 4s 216ms/step - loss: 0.0204 - accuracy: 1.0000 - val_loss: 0.2670 - val_accuracy: 0.8529
#
# Epoch 00005: val_accuracy did not improve from 0.97059
# Epoch 6/60
# 20/20 [==============================] - 4s 219ms/step - loss: 0.0700 - accuracy: 0.9779 - val_loss: 0.1925 - val_accuracy: 0.9412
#
# Epoch 00006: val_accuracy did not improve from 0.97059
# Epoch 7/60
# 20/20 [==============================] - 4s 217ms/step - loss: 0.0490 - accuracy: 0.9926 - val_loss: 0.1283 - val_accuracy: 1.0000
#
# Epoch 00007: val_accuracy improved from 0.97059 to 1.00000, saving model to checkpoint/modelCentering_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelCentering_train_new.csv/assets
# Epoch 8/60
# 20/20 [==============================] - 4s 219ms/step - loss: 0.0319 - accuracy: 0.9926 - val_loss: 0.2011 - val_accuracy: 0.9706
#
# Epoch 00008: val_accuracy did not improve from 1.00000
# Epoch 9/60
# 20/20 [==============================] - 4s 218ms/step - loss: 0.0349 - accuracy: 0.9853 - val_loss: 0.1436 - val_accuracy: 0.9706
#
# Epoch 00009: val_accuracy did not improve from 1.00000
# Epoch 10/60
# 20/20 [==============================] - 4s 219ms/step - loss: 0.0450 - accuracy: 0.9853 - val_loss: 0.1426 - val_accuracy: 0.9706
#
# Epoch 00010: val_accuracy did not improve from 1.00000
# Epoch 11/60
# 20/20 [==============================] - 4s 218ms/step - loss: 0.0196 - accuracy: 0.9926 - val_loss: 0.0981 - val_accuracy: 1.0000
#
# Epoch 00011: val_accuracy did not improve from 1.00000
# Epoch 12/60
# 20/20 [==============================] - 4s 218ms/step - loss: 0.0378 - accuracy: 0.9853 - val_loss: 0.1088 - val_accuracy: 1.0000
#
# Epoch 00012: val_accuracy did not improve from 1.00000
# Epoch 13/60
# 20/20 [==============================] - 4s 216ms/step - loss: 0.0319 - accuracy: 0.9853 - val_loss: 0.1037 - val_accuracy: 0.9706
#
# Epoch 00013: val_accuracy did not improve from 1.00000
# Epoch 14/60
# 20/20 [==============================] - 4s 215ms/step - loss: 0.0146 - accuracy: 1.0000 - val_loss: 0.1013 - val_accuracy: 0.9706
#
# Epoch 00014: val_accuracy did not improve from 1.00000
# Epoch 15/60
# 20/20 [==============================] - 4s 215ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.1021 - val_accuracy: 0.9706
#
# Epoch 00015: val_accuracy did not improve from 1.00000
# Epoch 16/60
# 20/20 [==============================] - 4s 220ms/step - loss: 0.0298 - accuracy: 0.9926 - val_loss: 0.1345 - val_accuracy: 0.9412
#
# Epoch 00016: val_accuracy did not improve from 1.00000
# Epoch 17/60
# 20/20 [==============================] - 4s 216ms/step - loss: 0.0156 - accuracy: 1.0000 - val_loss: 0.1816 - val_accuracy: 0.9412
#
# Epoch 00017: val_accuracy did not improve from 1.00000
# Epoch 18/60
# 20/20 [==============================] - 4s 221ms/step - loss: 0.0139 - accuracy: 1.0000 - val_loss: 0.1207 - val_accuracy: 1.0000
#
# Epoch 00018: val_accuracy did not improve from 1.00000
# Epoch 19/60
# 20/20 [==============================] - 4s 217ms/step - loss: 0.0308 - accuracy: 0.9853 - val_loss: 0.1458 - val_accuracy: 0.9706
#
# Epoch 00019: val_accuracy did not improve from 1.00000
# Epoch 20/60
# 20/20 [==============================] - 4s 217ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.1127 - val_accuracy: 0.9706
#
# Epoch 00020: val_accuracy did not improve from 1.00000
# Epoch 21/60
# 20/20 [==============================] - 4s 217ms/step - loss: 0.0310 - accuracy: 0.9926 - val_loss: 0.0839 - val_accuracy: 0.9706
#
# Epoch 00021: val_accuracy did not improve from 1.00000
# Epoch 22/60
# 20/20 [==============================] - 4s 217ms/step - loss: 0.0141 - accuracy: 0.9926 - val_loss: 0.0967 - val_accuracy: 0.9412
#
# Epoch 00022: val_accuracy did not improve from 1.00000
# Epoch 23/60
# 20/20 [==============================] - 4s 220ms/step - loss: 0.0069 - accuracy: 1.0000 - val_loss: 0.1482 - val_accuracy: 0.9412
#
# Epoch 00023: val_accuracy did not improve from 1.00000
# Epoch 24/60
# 20/20 [==============================] - 4s 218ms/step - loss: 0.0255 - accuracy: 0.9853 - val_loss: 0.1016 - val_accuracy: 0.9706
#
# Epoch 00024: val_accuracy did not improve from 1.00000
# Epoch 25/60
# 20/20 [==============================] - 4s 218ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.0677 - val_accuracy: 1.0000
#
# Epoch 00025: val_accuracy did not improve from 1.00000
# Epoch 26/60
# 20/20 [==============================] - 4s 216ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0498 - val_accuracy: 1.0000
#
# Epoch 00026: val_accuracy did not improve from 1.00000
# Epoch 27/60
# 20/20 [==============================] - 4s 218ms/step - loss: 0.0165 - accuracy: 0.9926 - val_loss: 0.0684 - val_accuracy: 1.0000
#
# Epoch 00027: val_accuracy did not improve from 1.00000
# Epoch 28/60
# 20/20 [==============================] - 4s 218ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 0.0914 - val_accuracy: 1.0000
#
# Epoch 00028: val_accuracy did not improve from 1.00000
# Epoch 29/60
# 20/20 [==============================] - 4s 220ms/step - loss: 0.0204 - accuracy: 0.9926 - val_loss: 0.0727 - val_accuracy: 1.0000
#
# Epoch 00029: val_accuracy did not improve from 1.00000
# Epoch 30/60
# 20/20 [==============================] - 4s 218ms/step - loss: 0.0212 - accuracy: 0.9926 - val_loss: 0.0959 - val_accuracy: 0.9706
#
# Epoch 00030: val_accuracy did not improve from 1.00000
# Epoch 31/60
# 20/20 [==============================] - 4s 218ms/step - loss: 0.0287 - accuracy: 0.9779 - val_loss: 0.1514 - val_accuracy: 0.9118
#
# Epoch 00031: val_accuracy did not improve from 1.00000
# Epoch 32/60
# 20/20 [==============================] - 4s 215ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.1524 - val_accuracy: 0.9118
#
# Epoch 00032: val_accuracy did not improve from 1.00000
# Epoch 33/60
# 20/20 [==============================] - 4s 217ms/step - loss: 0.0261 - accuracy: 0.9926 - val_loss: 0.1478 - val_accuracy: 0.9118
#
# Epoch 00033: val_accuracy did not improve from 1.00000
# Epoch 34/60
# 20/20 [==============================] - 4s 219ms/step - loss: 0.0454 - accuracy: 0.9926 - val_loss: 0.2079 - val_accuracy: 0.9412
#
# Epoch 00034: val_accuracy did not improve from 1.00000
# Epoch 35/60
# 20/20 [==============================] - 4s 216ms/step - loss: 0.0543 - accuracy: 0.9706 - val_loss: 0.1470 - val_accuracy: 0.9706
#
# Epoch 00035: val_accuracy did not improve from 1.00000
# Epoch 36/60
# 20/20 [==============================] - 4s 218ms/step - loss: 0.1058 - accuracy: 0.9559 - val_loss: 0.2229 - val_accuracy: 0.9412
#
# Epoch 00036: val_accuracy did not improve from 1.00000
# Epoch 37/60
# 20/20 [==============================] - 4s 218ms/step - loss: 0.0984 - accuracy: 0.9779 - val_loss: 0.2013 - val_accuracy: 0.9412
#
# Epoch 00037: val_accuracy did not improve from 1.00000
# Epoch 38/60
# 20/20 [==============================] - 4s 217ms/step - loss: 0.0124 - accuracy: 0.9926 - val_loss: 0.1559 - val_accuracy: 0.9412
#
# Epoch 00038: val_accuracy did not improve from 1.00000
# Epoch 39/60
# 20/20 [==============================] - 4s 218ms/step - loss: 0.0589 - accuracy: 0.9706 - val_loss: 0.1018 - val_accuracy: 0.9412
#
# Epoch 00039: val_accuracy did not improve from 1.00000
# Epoch 40/60
# 20/20 [==============================] - 4s 218ms/step - loss: 0.0219 - accuracy: 0.9926 - val_loss: 0.0727 - val_accuracy: 1.0000
#
# Epoch 00040: val_accuracy did not improve from 1.00000
# Epoch 41/60
# 20/20 [==============================] - 4s 219ms/step - loss: 0.0824 - accuracy: 0.9779 - val_loss: 0.1319 - val_accuracy: 0.9706
#
# Epoch 00041: val_accuracy did not improve from 1.00000
# Epoch 42/60
# 20/20 [==============================] - 4s 216ms/step - loss: 0.0412 - accuracy: 0.9853 - val_loss: 0.1587 - val_accuracy: 0.9118
#
# Epoch 00042: val_accuracy did not improve from 1.00000
# Epoch 43/60
# 20/20 [==============================] - 4s 217ms/step - loss: 0.1009 - accuracy: 0.9706 - val_loss: 0.2688 - val_accuracy: 0.8824
#
# Epoch 00043: val_accuracy did not improve from 1.00000
# Epoch 44/60
# 20/20 [==============================] - 4s 214ms/step - loss: 0.0328 - accuracy: 1.0000 - val_loss: 0.3243 - val_accuracy: 0.9118
#
# Epoch 00044: val_accuracy did not improve from 1.00000
# Epoch 45/60
# 20/20 [==============================] - 4s 216ms/step - loss: 0.0604 - accuracy: 0.9853 - val_loss: 0.0968 - val_accuracy: 1.0000
#
# Epoch 00045: val_accuracy did not improve from 1.00000
# Epoch 46/60
# 20/20 [==============================] - 4s 216ms/step - loss: 0.0210 - accuracy: 0.9926 - val_loss: 0.0711 - val_accuracy: 1.0000
#
# Epoch 00046: val_accuracy did not improve from 1.00000
# Epoch 47/60
# 20/20 [==============================] - 4s 216ms/step - loss: 0.0125 - accuracy: 1.0000 - val_loss: 0.0517 - val_accuracy: 1.0000
#
# Epoch 00047: val_accuracy did not improve from 1.00000
# Epoch 48/60
# 20/20 [==============================] - 4s 219ms/step - loss: 0.0065 - accuracy: 1.0000 - val_loss: 0.0391 - val_accuracy: 1.0000
#
# Epoch 00048: val_accuracy did not improve from 1.00000
# Epoch 49/60
# 20/20 [==============================] - 4s 219ms/step - loss: 0.0213 - accuracy: 0.9853 - val_loss: 0.0514 - val_accuracy: 1.0000
#
# Epoch 00049: val_accuracy did not improve from 1.00000
# Epoch 50/60
# 20/20 [==============================] - 4s 221ms/step - loss: 0.0158 - accuracy: 0.9926 - val_loss: 0.1088 - val_accuracy: 0.9706
#
# Epoch 00050: val_accuracy did not improve from 1.00000
# Epoch 51/60
# 20/20 [==============================] - 4s 220ms/step - loss: 0.0212 - accuracy: 0.9926 - val_loss: 0.0334 - val_accuracy: 1.0000
#
# Epoch 00051: val_accuracy did not improve from 1.00000
# Epoch 52/60
# 20/20 [==============================] - 4s 220ms/step - loss: 0.0107 - accuracy: 0.9926 - val_loss: 0.0470 - val_accuracy: 1.0000
#
# Epoch 00052: val_accuracy did not improve from 1.00000
# Epoch 53/60
# 20/20 [==============================] - 4s 220ms/step - loss: 0.0238 - accuracy: 0.9853 - val_loss: 0.1431 - val_accuracy: 0.9412
#
# Epoch 00053: val_accuracy did not improve from 1.00000
# Epoch 54/60
# 20/20 [==============================] - 4s 218ms/step - loss: 0.0089 - accuracy: 0.9926 - val_loss: 0.0983 - val_accuracy: 0.9412
#
# Epoch 00054: val_accuracy did not improve from 1.00000
# Epoch 55/60
# 20/20 [==============================] - 4s 219ms/step - loss: 0.0113 - accuracy: 1.0000 - val_loss: 0.2109 - val_accuracy: 0.9706
#
# Epoch 00055: val_accuracy did not improve from 1.00000
# Epoch 56/60
# 20/20 [==============================] - 4s 220ms/step - loss: 0.0279 - accuracy: 0.9926 - val_loss: 0.1832 - val_accuracy: 0.8824
#
# Epoch 00056: val_accuracy did not improve from 1.00000
# Epoch 57/60
# 20/20 [==============================] - 4s 220ms/step - loss: 0.0270 - accuracy: 0.9926 - val_loss: 0.1859 - val_accuracy: 0.9118
#
# Epoch 00057: val_accuracy did not improve from 1.00000
# Epoch 58/60
# 20/20 [==============================] - 4s 220ms/step - loss: 0.0476 - accuracy: 0.9853 - val_loss: 0.1179 - val_accuracy: 0.9706
#
# Epoch 00058: val_accuracy did not improve from 1.00000
# Epoch 59/60
# 20/20 [==============================] - 4s 216ms/step - loss: 0.0177 - accuracy: 0.9926 - val_loss: 0.0698 - val_accuracy: 1.0000
#
# Epoch 00059: val_accuracy did not improve from 1.00000
# Epoch 60/60
# 20/20 [==============================] - 4s 220ms/step - loss: 0.0053 - accuracy: 1.0000 - val_loss: 0.1335 - val_accuracy: 0.9412
#
# Epoch 00060: val_accuracy did not improve from 1.00000

# %%
dataWhitening.fit(X_train)
hist3 = model.fit(dataWhitening.flow(X_train, y_train, batch_size=7, subset='training'),
                  validation_data=dataWhitening.flow(X_train, y_train, batch_size=7, subset='validation'), epochs=60, callbacks=checkpoint16)
# Out:
# Epoch 1/60
# 20/20 [==============================] - 16s 770ms/step - loss: 1.0284 - accuracy: 0.7059 - val_loss: 1.1343 - val_accuracy: 0.5882
#
# Epoch 00001: val_accuracy improved from -inf to 0.58824, saving model to checkpoint/modelWhitening_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelWhitening_train_new.csv/assets
# Epoch 2/60
# 20/20 [==============================] - 13s 663ms/step - loss: 0.2291 - accuracy: 0.9191 - val_loss: 1.9398 - val_accuracy: 0.4412
#
# Epoch 00002: val_accuracy did not improve from 0.58824
# Epoch 3/60
# 20/20 [==============================] - 14s 663ms/step - loss: 0.1948 - accuracy: 0.9412 - val_loss: 1.3502 - val_accuracy: 0.6176
#
# Epoch 00003: val_accuracy improved from 0.58824 to 0.61765, saving model to checkpoint/modelWhitening_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelWhitening_train_new.csv/assets
# Epoch 4/60
# 20/20 [==============================] - 13s 662ms/step - loss: 0.1341 - accuracy: 0.9706 - val_loss: 1.4907 - val_accuracy: 0.6176
#
# Epoch 00004: val_accuracy did not improve from 0.61765
# Epoch 5/60
# 20/20 [==============================] - 13s 667ms/step - loss: 0.1435 - accuracy: 0.9338 - val_loss: 1.1228 - val_accuracy: 0.6765
#
# Epoch 00005: val_accuracy improved from 0.61765 to 0.67647, saving model to checkpoint/modelWhitening_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelWhitening_train_new.csv/assets
# Epoch 6/60
# 20/20 [==============================] - 13s 641ms/step - loss: 0.0579 - accuracy: 0.9853 - val_loss: 1.2506 - val_accuracy: 0.5882
#
# Epoch 00006: val_accuracy did not improve from 0.67647
# Epoch 7/60
# 20/20 [==============================] - 13s 652ms/step - loss: 0.0528 - accuracy: 0.9779 - val_loss: 1.0327 - val_accuracy: 0.6471
#
# Epoch 00007: val_accuracy did not improve from 0.67647
# Epoch 8/60
# 20/20 [==============================] - 13s 655ms/step - loss: 0.0823 - accuracy: 0.9706 - val_loss: 1.3235 - val_accuracy: 0.6471
#
# Epoch 00008: val_accuracy did not improve from 0.67647
# Epoch 9/60
# 20/20 [==============================] - 13s 652ms/step - loss: 0.0507 - accuracy: 0.9853 - val_loss: 1.5535 - val_accuracy: 0.5588
#
# Epoch 00009: val_accuracy did not improve from 0.67647
# Epoch 10/60
# 20/20 [==============================] - 13s 652ms/step - loss: 0.0355 - accuracy: 0.9926 - val_loss: 1.1479 - val_accuracy: 0.5882
#
# Epoch 00010: val_accuracy did not improve from 0.67647
# Epoch 11/60
# 20/20 [==============================] - 13s 656ms/step - loss: 0.0410 - accuracy: 0.9779 - val_loss: 1.0490 - val_accuracy: 0.5882
#
# Epoch 00011: val_accuracy did not improve from 0.67647
# Epoch 12/60
# 20/20 [==============================] - 13s 675ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.1077 - val_accuracy: 0.6765
#
# Epoch 00012: val_accuracy did not improve from 0.67647
# Epoch 13/60
# 20/20 [==============================] - 13s 665ms/step - loss: 0.0070 - accuracy: 1.0000 - val_loss: 1.1239 - val_accuracy: 0.6765
#
# Epoch 00013: val_accuracy did not improve from 0.67647
# Epoch 14/60
# 20/20 [==============================] - 13s 681ms/step - loss: 0.0123 - accuracy: 0.9926 - val_loss: 1.1418 - val_accuracy: 0.6471
#
# Epoch 00014: val_accuracy did not improve from 0.67647
# Epoch 15/60
# 20/20 [==============================] - 13s 657ms/step - loss: 0.0077 - accuracy: 1.0000 - val_loss: 1.8977 - val_accuracy: 0.5882
#
# Epoch 00015: val_accuracy did not improve from 0.67647
# Epoch 16/60
# 20/20 [==============================] - 13s 653ms/step - loss: 0.0203 - accuracy: 0.9926 - val_loss: 1.4624 - val_accuracy: 0.6471
#
# Epoch 00016: val_accuracy did not improve from 0.67647
# Epoch 17/60
# 20/20 [==============================] - 13s 658ms/step - loss: 0.0174 - accuracy: 0.9926 - val_loss: 1.2062 - val_accuracy: 0.7059
#
# Epoch 00017: val_accuracy improved from 0.67647 to 0.70588, saving model to checkpoint/modelWhitening_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelWhitening_train_new.csv/assets
# Epoch 18/60
# 20/20 [==============================] - 14s 665ms/step - loss: 0.0205 - accuracy: 0.9926 - val_loss: 1.5449 - val_accuracy: 0.6176
#
# Epoch 00018: val_accuracy did not improve from 0.70588
# Epoch 19/60
# 20/20 [==============================] - 13s 679ms/step - loss: 0.0146 - accuracy: 0.9853 - val_loss: 1.3412 - val_accuracy: 0.6765
#
# Epoch 00019: val_accuracy did not improve from 0.70588
# Epoch 20/60
# 20/20 [==============================] - 13s 683ms/step - loss: 0.0142 - accuracy: 0.9926 - val_loss: 1.0691 - val_accuracy: 0.6765
#
# Epoch 00020: val_accuracy did not improve from 0.70588
# Epoch 21/60
# 20/20 [==============================] - 14s 668ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 1.0655 - val_accuracy: 0.6765
#
# Epoch 00021: val_accuracy did not improve from 0.70588
# Epoch 22/60
# 20/20 [==============================] - 14s 664ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.0318 - val_accuracy: 0.6765
#
# Epoch 00022: val_accuracy did not improve from 0.70588
# Epoch 23/60
# 20/20 [==============================] - 13s 654ms/step - loss: 0.0052 - accuracy: 1.0000 - val_loss: 1.1270 - val_accuracy: 0.7647
#
# Epoch 00023: val_accuracy improved from 0.70588 to 0.76471, saving model to checkpoint/modelWhitening_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelWhitening_train_new.csv/assets
# Epoch 24/60
# 20/20 [==============================] - 13s 660ms/step - loss: 0.0038 - accuracy: 1.0000 - val_loss: 1.0519 - val_accuracy: 0.6765
#
# Epoch 00024: val_accuracy did not improve from 0.76471
# Epoch 25/60
# 20/20 [==============================] - 13s 653ms/step - loss: 0.0029 - accuracy: 1.0000 - val_loss: 1.0790 - val_accuracy: 0.6765
#
# Epoch 00025: val_accuracy did not improve from 0.76471
# Epoch 26/60
# 20/20 [==============================] - 13s 655ms/step - loss: 8.6950e-04 - accuracy: 1.0000 - val_loss: 1.2131 - val_accuracy: 0.7059
#
# Epoch 00026: val_accuracy did not improve from 0.76471
# Epoch 27/60
# 20/20 [==============================] - 13s 644ms/step - loss: 8.8137e-04 - accuracy: 1.0000 - val_loss: 1.3126 - val_accuracy: 0.7059
#
# Epoch 00027: val_accuracy did not improve from 0.76471
# Epoch 28/60
# 20/20 [==============================] - 13s 655ms/step - loss: 2.2322e-04 - accuracy: 1.0000 - val_loss: 1.3457 - val_accuracy: 0.7059
#
# Epoch 00028: val_accuracy did not improve from 0.76471
# Epoch 29/60
# 20/20 [==============================] - 13s 649ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 1.2818 - val_accuracy: 0.6471
#
# Epoch 00029: val_accuracy did not improve from 0.76471
# Epoch 30/60
# 20/20 [==============================] - 13s 662ms/step - loss: 0.0159 - accuracy: 0.9926 - val_loss: 1.2837 - val_accuracy: 0.6471
#
# Epoch 00030: val_accuracy did not improve from 0.76471
# Epoch 31/60
# 20/20 [==============================] - 13s 647ms/step - loss: 0.0175 - accuracy: 0.9926 - val_loss: 1.3575 - val_accuracy: 0.6176
#
# Epoch 00031: val_accuracy did not improve from 0.76471
# Epoch 32/60
# 20/20 [==============================] - 13s 652ms/step - loss: 0.0103 - accuracy: 0.9926 - val_loss: 1.4844 - val_accuracy: 0.7059
#
# Epoch 00032: val_accuracy did not improve from 0.76471
# Epoch 33/60
# 20/20 [==============================] - 13s 656ms/step - loss: 0.0156 - accuracy: 0.9926 - val_loss: 1.1149 - val_accuracy: 0.6765
#
# Epoch 00033: val_accuracy did not improve from 0.76471
# Epoch 34/60
# 20/20 [==============================] - 13s 653ms/step - loss: 0.0473 - accuracy: 0.9853 - val_loss: 1.1786 - val_accuracy: 0.5882
#
# Epoch 00034: val_accuracy did not improve from 0.76471
# Epoch 35/60
# 20/20 [==============================] - 13s 661ms/step - loss: 0.0107 - accuracy: 0.9926 - val_loss: 1.2720 - val_accuracy: 0.6471
#
# Epoch 00035: val_accuracy did not improve from 0.76471
# Epoch 36/60
# 20/20 [==============================] - 14s 664ms/step - loss: 0.0088 - accuracy: 1.0000 - val_loss: 1.3298 - val_accuracy: 0.5882
#
# Epoch 00036: val_accuracy did not improve from 0.76471
# Epoch 37/60
# 20/20 [==============================] - 13s 669ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 1.3092 - val_accuracy: 0.6471
#
# Epoch 00037: val_accuracy did not improve from 0.76471
# Epoch 38/60
# 20/20 [==============================] - 13s 656ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 1.1896 - val_accuracy: 0.6471
#
# Epoch 00038: val_accuracy did not improve from 0.76471
# Epoch 39/60
# 20/20 [==============================] - 13s 659ms/step - loss: 5.0950e-04 - accuracy: 1.0000 - val_loss: 1.1698 - val_accuracy: 0.6765
#
# Epoch 00039: val_accuracy did not improve from 0.76471
# Epoch 40/60
# 20/20 [==============================] - 13s 653ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 1.2296 - val_accuracy: 0.6471
#
# Epoch 00040: val_accuracy did not improve from 0.76471
# Epoch 41/60
# 20/20 [==============================] - 13s 656ms/step - loss: 0.0224 - accuracy: 0.9926 - val_loss: 0.8883 - val_accuracy: 0.6471
#
# Epoch 00041: val_accuracy did not improve from 0.76471
# Epoch 42/60
# 20/20 [==============================] - 13s 654ms/step - loss: 0.0148 - accuracy: 0.9926 - val_loss: 1.1550 - val_accuracy: 0.7059
#
# Epoch 00042: val_accuracy did not improve from 0.76471
# Epoch 43/60
# 20/20 [==============================] - 13s 650ms/step - loss: 2.5534e-04 - accuracy: 1.0000 - val_loss: 1.3843 - val_accuracy: 0.7059
#
# Epoch 00043: val_accuracy did not improve from 0.76471
# Epoch 44/60
# 20/20 [==============================] - 13s 660ms/step - loss: 3.6429e-04 - accuracy: 1.0000 - val_loss: 1.4240 - val_accuracy: 0.7353
#
# Epoch 00044: val_accuracy did not improve from 0.76471
# Epoch 45/60
# 20/20 [==============================] - 13s 650ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 1.2847 - val_accuracy: 0.7059
#
# Epoch 00045: val_accuracy did not improve from 0.76471
# Epoch 46/60
# 20/20 [==============================] - 13s 653ms/step - loss: 0.0168 - accuracy: 0.9926 - val_loss: 1.8483 - val_accuracy: 0.7059
#
# Epoch 00046: val_accuracy did not improve from 0.76471
# Epoch 47/60
# 20/20 [==============================] - 13s 658ms/step - loss: 0.0478 - accuracy: 0.9853 - val_loss: 1.2422 - val_accuracy: 0.7059
#
# Epoch 00047: val_accuracy did not improve from 0.76471
# Epoch 48/60
# 20/20 [==============================] - 14s 672ms/step - loss: 0.0406 - accuracy: 0.9853 - val_loss: 2.0974 - val_accuracy: 0.6471
#
# Epoch 00048: val_accuracy did not improve from 0.76471
# Epoch 49/60
# 20/20 [==============================] - 14s 667ms/step - loss: 0.0962 - accuracy: 0.9853 - val_loss: 1.4484 - val_accuracy: 0.6765
#
# Epoch 00049: val_accuracy did not improve from 0.76471
# Epoch 50/60
# 20/20 [==============================] - 13s 656ms/step - loss: 0.0505 - accuracy: 0.9853 - val_loss: 1.5487 - val_accuracy: 0.7647
#
# Epoch 00050: val_accuracy did not improve from 0.76471
# Epoch 51/60
# 20/20 [==============================] - 14s 666ms/step - loss: 0.1618 - accuracy: 0.9706 - val_loss: 1.5067 - val_accuracy: 0.7647
#
# Epoch 00051: val_accuracy did not improve from 0.76471
# Epoch 52/60
# 20/20 [==============================] - 13s 658ms/step - loss: 0.0153 - accuracy: 0.9926 - val_loss: 1.5321 - val_accuracy: 0.7353
#
# Epoch 00052: val_accuracy did not improve from 0.76471
# Epoch 53/60
# 20/20 [==============================] - 14s 668ms/step - loss: 0.0294 - accuracy: 0.9926 - val_loss: 1.2897 - val_accuracy: 0.7353
#
# Epoch 00053: val_accuracy did not improve from 0.76471
# Epoch 54/60
# 20/20 [==============================] - 13s 658ms/step - loss: 0.0153 - accuracy: 1.0000 - val_loss: 1.6137 - val_accuracy: 0.7059
#
# Epoch 00054: val_accuracy did not improve from 0.76471
# Epoch 55/60
# 20/20 [==============================] - 13s 655ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 1.6421 - val_accuracy: 0.6765
#
# Epoch 00055: val_accuracy did not improve from 0.76471
# Epoch 56/60
# 20/20 [==============================] - 13s 645ms/step - loss: 0.0180 - accuracy: 0.9926 - val_loss: 1.1024 - val_accuracy: 0.7647
#
# Epoch 00056: val_accuracy did not improve from 0.76471
# Epoch 57/60
# 20/20 [==============================] - 13s 648ms/step - loss: 0.0233 - accuracy: 0.9853 - val_loss: 0.9902 - val_accuracy: 0.7941
#
# Epoch 00057: val_accuracy improved from 0.76471 to 0.79412, saving model to checkpoint/modelWhitening_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelWhitening_train_new.csv/assets
# Epoch 58/60
# 20/20 [==============================] - 13s 661ms/step - loss: 0.0034 - accuracy: 1.0000 - val_loss: 1.1423 - val_accuracy: 0.7353
#
# Epoch 00058: val_accuracy did not improve from 0.79412
# Epoch 59/60
# 20/20 [==============================] - 13s 658ms/step - loss: 3.8829e-04 - accuracy: 1.0000 - val_loss: 1.1586 - val_accuracy: 0.7059
#
# Epoch 00059: val_accuracy did not improve from 0.79412
# Epoch 60/60
# 20/20 [==============================] - 13s 652ms/step - loss: 0.0074 - accuracy: 1.0000 - val_loss: 1.4217 - val_accuracy: 0.7059
#
# Epoch 00060: val_accuracy did not improve from 0.79412

# %%
hist5 = model.fit(X_train, y_train, batch_size=7, epochs=60, verbose=1, validation_data=(X_test, y_test), callbacks=checkpoint64)
# Out:
# Epoch 1/60
# 25/25 [==============================] - 6s 222ms/step - loss: 1.1057 - accuracy: 0.6412 - val_loss: 0.9742 - val_accuracy: 0.6744
#
# Epoch 00001: val_accuracy improved from -inf to 0.67442, saving model to checkpoint/modelNone_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelNone_train_new.csv/assets
# Epoch 2/60
# 25/25 [==============================] - 5s 213ms/step - loss: 0.3054 - accuracy: 0.8941 - val_loss: 0.6990 - val_accuracy: 0.7907
#
# Epoch 00002: val_accuracy improved from 0.67442 to 0.79070, saving model to checkpoint/modelNone_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelNone_train_new.csv/assets
# Epoch 3/60
# 25/25 [==============================] - 5s 215ms/step - loss: 0.1577 - accuracy: 0.9294 - val_loss: 0.7841 - val_accuracy: 0.7442
#
# Epoch 00003: val_accuracy did not improve from 0.79070
# Epoch 4/60
# 25/25 [==============================] - 5s 211ms/step - loss: 0.3132 - accuracy: 0.8824 - val_loss: 0.7048 - val_accuracy: 0.7674
#
# Epoch 00004: val_accuracy did not improve from 0.79070
# Epoch 5/60
# 25/25 [==============================] - 5s 212ms/step - loss: 0.1091 - accuracy: 0.9529 - val_loss: 0.8783 - val_accuracy: 0.6977
#
# Epoch 00005: val_accuracy did not improve from 0.79070
# Epoch 6/60
# 25/25 [==============================] - 5s 212ms/step - loss: 0.1560 - accuracy: 0.9471 - val_loss: 0.7779 - val_accuracy: 0.7209
#
# Epoch 00006: val_accuracy did not improve from 0.79070
# Epoch 7/60
# 25/25 [==============================] - 5s 209ms/step - loss: 0.1576 - accuracy: 0.9471 - val_loss: 0.4447 - val_accuracy: 0.8140
#
# Epoch 00007: val_accuracy improved from 0.79070 to 0.81395, saving model to checkpoint/modelNone_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelNone_train_new.csv/assets
# Epoch 8/60
# 25/25 [==============================] - 5s 212ms/step - loss: 0.1099 - accuracy: 0.9647 - val_loss: 0.9200 - val_accuracy: 0.7674
#
# Epoch 00008: val_accuracy did not improve from 0.81395
# Epoch 9/60
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0556 - accuracy: 0.9765 - val_loss: 0.8086 - val_accuracy: 0.7209
#
# Epoch 00009: val_accuracy did not improve from 0.81395
# Epoch 10/60
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0767 - accuracy: 0.9765 - val_loss: 0.6751 - val_accuracy: 0.7442
#
# Epoch 00010: val_accuracy did not improve from 0.81395
# Epoch 11/60
# 25/25 [==============================] - 5s 212ms/step - loss: 0.0359 - accuracy: 0.9824 - val_loss: 0.6549 - val_accuracy: 0.7442
#
# Epoch 00011: val_accuracy did not improve from 0.81395
# Epoch 12/60
# 25/25 [==============================] - 5s 212ms/step - loss: 0.0265 - accuracy: 0.9882 - val_loss: 0.8952 - val_accuracy: 0.8140
#
# Epoch 00012: val_accuracy did not improve from 0.81395
# Epoch 13/60
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0664 - accuracy: 0.9765 - val_loss: 0.8001 - val_accuracy: 0.7674
#
# Epoch 00013: val_accuracy did not improve from 0.81395
# Epoch 14/60
# 25/25 [==============================] - 5s 213ms/step - loss: 0.0611 - accuracy: 0.9765 - val_loss: 0.7357 - val_accuracy: 0.7674
#
# Epoch 00014: val_accuracy did not improve from 0.81395
# Epoch 15/60
# 25/25 [==============================] - 5s 214ms/step - loss: 0.0367 - accuracy: 0.9882 - val_loss: 0.8646 - val_accuracy: 0.7907
#
# Epoch 00015: val_accuracy did not improve from 0.81395
# Epoch 16/60
# 25/25 [==============================] - 5s 213ms/step - loss: 0.0303 - accuracy: 0.9941 - val_loss: 0.9050 - val_accuracy: 0.7209
#
# Epoch 00016: val_accuracy did not improve from 0.81395
# Epoch 17/60
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0434 - accuracy: 0.9824 - val_loss: 0.7057 - val_accuracy: 0.7907
#
# Epoch 00017: val_accuracy did not improve from 0.81395
# Epoch 18/60
# 25/25 [==============================] - 5s 213ms/step - loss: 0.0083 - accuracy: 1.0000 - val_loss: 0.7622 - val_accuracy: 0.8372
#
# Epoch 00018: val_accuracy improved from 0.81395 to 0.83721, saving model to checkpoint/modelNone_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelNone_train_new.csv/assets
# Epoch 19/60
# 25/25 [==============================] - 5s 213ms/step - loss: 0.0812 - accuracy: 0.9824 - val_loss: 0.9785 - val_accuracy: 0.6977
#
# Epoch 00019: val_accuracy did not improve from 0.83721
# Epoch 20/60
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0886 - accuracy: 0.9706 - val_loss: 0.6273 - val_accuracy: 0.8140
#
# Epoch 00020: val_accuracy did not improve from 0.83721
# Epoch 21/60
# 25/25 [==============================] - 5s 210ms/step - loss: 0.0401 - accuracy: 0.9941 - val_loss: 0.5818 - val_accuracy: 0.7907
#
# Epoch 00021: val_accuracy did not improve from 0.83721
# Epoch 22/60
# 25/25 [==============================] - 5s 212ms/step - loss: 0.0136 - accuracy: 0.9941 - val_loss: 0.4542 - val_accuracy: 0.8372
#
# Epoch 00022: val_accuracy did not improve from 0.83721
# Epoch 23/60
# 25/25 [==============================] - 5s 214ms/step - loss: 0.0222 - accuracy: 0.9882 - val_loss: 0.5661 - val_accuracy: 0.8140
#
# Epoch 00023: val_accuracy did not improve from 0.83721
# Epoch 24/60
# 25/25 [==============================] - 5s 213ms/step - loss: 0.0085 - accuracy: 1.0000 - val_loss: 0.6983 - val_accuracy: 0.8605
#
# Epoch 00024: val_accuracy improved from 0.83721 to 0.86047, saving model to checkpoint/modelNone_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelNone_train_new.csv/assets
# Epoch 25/60
# 25/25 [==============================] - 5s 216ms/step - loss: 0.0141 - accuracy: 0.9882 - val_loss: 0.8067 - val_accuracy: 0.8372
#
# Epoch 00025: val_accuracy did not improve from 0.86047
# Epoch 26/60
# 25/25 [==============================] - 5s 214ms/step - loss: 0.0650 - accuracy: 0.9882 - val_loss: 0.5980 - val_accuracy: 0.8605
#
# Epoch 00026: val_accuracy did not improve from 0.86047
# Epoch 27/60
# 25/25 [==============================] - 5s 214ms/step - loss: 0.0272 - accuracy: 0.9824 - val_loss: 0.5015 - val_accuracy: 0.8372
#
# Epoch 00027: val_accuracy did not improve from 0.86047
# Epoch 28/60
# 25/25 [==============================] - 5s 212ms/step - loss: 0.0287 - accuracy: 0.9941 - val_loss: 0.6567 - val_accuracy: 0.7907
#
# Epoch 00028: val_accuracy did not improve from 0.86047
# Epoch 29/60
# 25/25 [==============================] - 5s 216ms/step - loss: 0.0442 - accuracy: 0.9882 - val_loss: 1.4056 - val_accuracy: 0.7674
#
# Epoch 00029: val_accuracy did not improve from 0.86047
# Epoch 30/60
# 25/25 [==============================] - 5s 213ms/step - loss: 0.0627 - accuracy: 0.9824 - val_loss: 0.9051 - val_accuracy: 0.7907
#
# Epoch 00030: val_accuracy did not improve from 0.86047
# Epoch 31/60
# 25/25 [==============================] - 5s 214ms/step - loss: 0.0234 - accuracy: 0.9882 - val_loss: 0.6213 - val_accuracy: 0.8372
#
# Epoch 00031: val_accuracy did not improve from 0.86047
# Epoch 32/60
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0060 - accuracy: 1.0000 - val_loss: 0.5616 - val_accuracy: 0.8140
#
# Epoch 00032: val_accuracy did not improve from 0.86047
# Epoch 33/60
# 25/25 [==============================] - 5s 214ms/step - loss: 0.0405 - accuracy: 0.9824 - val_loss: 0.8991 - val_accuracy: 0.8140
#
# Epoch 00033: val_accuracy did not improve from 0.86047
# Epoch 34/60
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0664 - accuracy: 0.9882 - val_loss: 0.4503 - val_accuracy: 0.8605
#
# Epoch 00034: val_accuracy did not improve from 0.86047
# Epoch 35/60
# 25/25 [==============================] - 5s 212ms/step - loss: 0.0721 - accuracy: 0.9882 - val_loss: 0.5373 - val_accuracy: 0.8837
#
# Epoch 00035: val_accuracy improved from 0.86047 to 0.88372, saving model to checkpoint/modelNone_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelNone_train_new.csv/assets
# Epoch 36/60
# 25/25 [==============================] - 5s 213ms/step - loss: 0.0246 - accuracy: 0.9882 - val_loss: 0.7420 - val_accuracy: 0.8372
#
# Epoch 00036: val_accuracy did not improve from 0.88372
# Epoch 37/60
# 25/25 [==============================] - 5s 212ms/step - loss: 0.0513 - accuracy: 0.9882 - val_loss: 0.4909 - val_accuracy: 0.8140
#
# Epoch 00037: val_accuracy did not improve from 0.88372
# Epoch 38/60
# 25/25 [==============================] - 5s 213ms/step - loss: 0.0100 - accuracy: 1.0000 - val_loss: 0.5394 - val_accuracy: 0.8372
#
# Epoch 00038: val_accuracy did not improve from 0.88372
# Epoch 39/60
# 25/25 [==============================] - 5s 216ms/step - loss: 0.0193 - accuracy: 0.9824 - val_loss: 0.4886 - val_accuracy: 0.8605
#
# Epoch 00039: val_accuracy did not improve from 0.88372
# Epoch 40/60
# 25/25 [==============================] - 5s 212ms/step - loss: 0.0340 - accuracy: 0.9882 - val_loss: 0.8714 - val_accuracy: 0.8372
#
# Epoch 00040: val_accuracy did not improve from 0.88372
# Epoch 41/60
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.6758 - val_accuracy: 0.8140
#
# Epoch 00041: val_accuracy did not improve from 0.88372
# Epoch 42/60
# 25/25 [==============================] - 5s 214ms/step - loss: 0.0531 - accuracy: 0.9824 - val_loss: 0.8885 - val_accuracy: 0.7674
#
# Epoch 00042: val_accuracy did not improve from 0.88372
# Epoch 43/60
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0366 - accuracy: 0.9882 - val_loss: 0.5561 - val_accuracy: 0.8372
#
# Epoch 00043: val_accuracy did not improve from 0.88372
# Epoch 44/60
# 25/25 [==============================] - 5s 214ms/step - loss: 0.0588 - accuracy: 0.9765 - val_loss: 0.7765 - val_accuracy: 0.7674
#
# Epoch 00044: val_accuracy did not improve from 0.88372
# Epoch 45/60
# 25/25 [==============================] - 5s 213ms/step - loss: 0.1093 - accuracy: 0.9706 - val_loss: 0.6092 - val_accuracy: 0.7907
#
# Epoch 00045: val_accuracy did not improve from 0.88372
# Epoch 46/60
# 25/25 [==============================] - 5s 213ms/step - loss: 0.0703 - accuracy: 0.9882 - val_loss: 0.3912 - val_accuracy: 0.8605
#
# Epoch 00046: val_accuracy did not improve from 0.88372
# Epoch 47/60
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0177 - accuracy: 0.9882 - val_loss: 0.5398 - val_accuracy: 0.8372
#
# Epoch 00047: val_accuracy did not improve from 0.88372
# Epoch 48/60
# 25/25 [==============================] - 5s 212ms/step - loss: 0.0050 - accuracy: 1.0000 - val_loss: 0.5377 - val_accuracy: 0.8605
#
# Epoch 00048: val_accuracy did not improve from 0.88372
# Epoch 49/60
# 25/25 [==============================] - 5s 210ms/step - loss: 0.0044 - accuracy: 1.0000 - val_loss: 0.5442 - val_accuracy: 0.8605
#
# Epoch 00049: val_accuracy did not improve from 0.88372
# Epoch 50/60
# 25/25 [==============================] - 5s 211ms/step - loss: 8.1986e-04 - accuracy: 1.0000 - val_loss: 0.5912 - val_accuracy: 0.8372
#
# Epoch 00050: val_accuracy did not improve from 0.88372
# Epoch 51/60
# 25/25 [==============================] - 5s 213ms/step - loss: 0.0054 - accuracy: 1.0000 - val_loss: 0.6218 - val_accuracy: 0.8605
#
# Epoch 00051: val_accuracy did not improve from 0.88372
# Epoch 52/60
# 25/25 [==============================] - 5s 214ms/step - loss: 0.0139 - accuracy: 0.9941 - val_loss: 0.4495 - val_accuracy: 0.9070
#
# Epoch 00052: val_accuracy improved from 0.88372 to 0.90698, saving model to checkpoint/modelNone_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/modelNone_train_new.csv/assets
# Epoch 53/60
# 25/25 [==============================] - 5s 214ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.3698 - val_accuracy: 0.8837
#
# Epoch 00053: val_accuracy did not improve from 0.90698
# Epoch 54/60
# 25/25 [==============================] - 5s 212ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.3790 - val_accuracy: 0.8837
#
# Epoch 00054: val_accuracy did not improve from 0.90698
# Epoch 55/60
# 25/25 [==============================] - 5s 212ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.4435 - val_accuracy: 0.8837
#
# Epoch 00055: val_accuracy did not improve from 0.90698
# Epoch 56/60
# 25/25 [==============================] - 5s 212ms/step - loss: 0.0035 - accuracy: 1.0000 - val_loss: 0.4739 - val_accuracy: 0.8837
#
# Epoch 00056: val_accuracy did not improve from 0.90698
# Epoch 57/60
# 25/25 [==============================] - 5s 213ms/step - loss: 0.0045 - accuracy: 1.0000 - val_loss: 0.5693 - val_accuracy: 0.8837
#
# Epoch 00057: val_accuracy did not improve from 0.90698
# Epoch 58/60
# 25/25 [==============================] - 5s 214ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.5910 - val_accuracy: 0.8837
#
# Epoch 00058: val_accuracy did not improve from 0.90698
# Epoch 59/60
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.5626 - val_accuracy: 0.8837
#
# Epoch 00059: val_accuracy did not improve from 0.90698
# Epoch 60/60
# 25/25 [==============================] - 5s 211ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.6785 - val_accuracy: 0.8837
#
# Epoch 00060: val_accuracy did not improve from 0.90698

# %%
train_loss=hist1.history['loss']
val_loss=hist1.history['val_loss']
train_acc=hist1.history['accuracy']

val_acc=hist1.history['val_accuracy']
bval_acc=hist2.history['val_accuracy']
cval_acc=hist3.history['val_accuracy']
eval_acc=hist5.history['val_accuracy']

epochs = range(len(train_acc))

pyplot.plot(epochs,train_loss,'r', label='train_loss')
pyplot.plot(epochs,val_loss,'b', label='val_loss')
pyplot.title('train_loss vs val_loss')
pyplot.legend()
pyplot.figure()

pyplot.plot(epochs,val_acc,'r', label='Normalisation')
pyplot.plot(epochs,bval_acc,'b', label='Centering')
pyplot.plot(epochs,cval_acc,'g', label='Whitening')
pyplot.plot(epochs,eval_acc,'m', label='None')
pyplot.title('Pre-processing methods')
pyplot.ylabel('Accuracy')
pyplot.xlabel('Epochs')
pyplot.legend()
pyplot.figure()
