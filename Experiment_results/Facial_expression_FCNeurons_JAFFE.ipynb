# %%
from google.colab import drive
import tarfile
import os, cv2
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
from keras.utils import np_utils
drive.mount('/content/drive'),
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).
# (None,)

# %%
data_path = '/content/drive/MyDrive/facial_expression/jaffe'
data_dir_list = os.listdir(data_path)

img_si=128
num_channel=1

num_epoch=10

img_data_list=[]


for dataset in data_dir_list:
    img_list=os.listdir(data_path+'/'+ dataset)
    print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
    for img in img_list:
        input_img=cv2.imread(data_path + '/'+ dataset + '/'+ img )
        #input_img=cv2.cvtColor(input_img, cv2.COLOR_BGR2GRAY)
        input_img_resize=cv2.resize(input_img,(img_si,img_si))
        img_data_list.append(input_img_resize)
        
img_data = np.array(img_data_list)
img_data = img_data.astype('float32')
img_data = img_data/255
img_data.shape
# Out:
# Loaded the images of dataset-ANGRY
#
# Loaded the images of dataset-DISGUST
#
# Loaded the images of dataset-FEAR
#
# Loaded the images of dataset-NEUTRAL
#
# Loaded the images of dataset-HAPPY
#
# Loaded the images of dataset-SAD
#
# Loaded the images of dataset-SURPRISE
# (213, 128, 128, 3)

# %%
num_classes = 7

num_of_samples = img_data.shape[0]
labels = np.ones((num_of_samples,),dtype='int64')

labels[0:29]=0 #30
labels[30:58]=1 #29
labels[59:90]=2 #32
labels[91:121]=3 #31
labels[122:151]=4 #30
labels[152:182]=5 #31
labels[183:]=6 #30

names = ['ANGRY','DISGUST','FEAR','HAPPY','NEUTRAL','SAD','SURPRISE']

def getLabel(id):
    return ['ANGRY','DISGUST','FEAR','HAPPY','NEUTRAL','SAD','SURPRISE'][id]

# %%
Y = np_utils.to_categorical(labels, num_classes)
#Shuffle the dataset
x,y = shuffle(img_data,Y, random_state=2)
# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)
x_test=X_test
#X_train=X_train.reshape(X_train.shape[0],128,128,1)
#X_test=X_test.reshape(X_test.shape[0],128,128,1)
x_test.shape
# Out:
# (43, 128, 128, 3)

# %%
from keras.models import Sequential
from keras.layers import Dense , Activation , Dropout ,Flatten, BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D, AveragePooling2D
from keras.metrics import categorical_accuracy
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
from keras.optimizers import *
from keras.layers.normalization import BatchNormalization

# %%
input_shape=(img_si,img_si,3)

model4 = Sequential()
model4.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model4.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model4.add(Dropout(0.25))
model4.add(MaxPooling2D(pool_size=(2, 2)))

model4.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model4.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model4.add(Dropout(0.25))
model4.add(MaxPooling2D(pool_size=(2, 2)))

model4.add(Flatten())
model4.add(Dense(4, activation = 'relu'))
model4.add(Dropout(0.5))
model4.add(Dense(7, activation = 'softmax'))

# %%
input_shape=(img_si,img_si,3)

model16 = Sequential()
model16.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model16.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model16.add(Dropout(0.25))
model16.add(MaxPooling2D(pool_size=(2, 2)))

model16.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model16.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model16.add(Dropout(0.25))
model16.add(MaxPooling2D(pool_size=(2, 2)))

model16.add(Flatten())
model16.add(Dense(16, activation = 'relu'))
model16.add(Dropout(0.5))
model16.add(Dense(7, activation = 'softmax'))

# %%
input_shape=(img_si,img_si,3)

model32 = Sequential()
model32.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model32.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model32.add(Dropout(0.25))
model32.add(MaxPooling2D(pool_size=(2, 2)))

model32.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model32.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model32.add(Dropout(0.25))
model32.add(MaxPooling2D(pool_size=(2, 2)))

model32.add(Flatten())
model32.add(Dense(32, activation = 'relu'))
model32.add(Dropout(0.5))
model32.add(Dense(7, activation = 'softmax'))

# %%
input_shape=(img_si,img_si,3)

model64 = Sequential()
model64.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model64.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model64.add(Dropout(0.25))
model64.add(MaxPooling2D(pool_size=(2, 2)))

model64.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model64.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model64.add(Dropout(0.25))
model64.add(MaxPooling2D(pool_size=(2, 2)))

model64.add(Flatten())
model64.add(Dense(64, activation = 'relu'))
model64.add(Dropout(0.5))
model64.add(Dense(7, activation = 'softmax'))

# %%
input_shape=(img_si,img_si,3)

model128 = Sequential()
model128.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model128.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model128.add(Dropout(0.25))
model128.add(MaxPooling2D(pool_size=(2, 2)))

model128.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model128.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model128.add(Dropout(0.25))
model128.add(MaxPooling2D(pool_size=(2, 2)))

model128.add(Flatten())
model128.add(Dense(128, activation = 'relu'))
model128.add(Dropout(0.5))
model128.add(Dense(7, activation = 'softmax'))

# %%
input_shape=(img_si,img_si,3)

model256 = Sequential()
model256.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model256.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model256.add(Dropout(0.25))
model256.add(MaxPooling2D(pool_size=(2, 2)))

model256.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model256.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model256.add(Dropout(0.25))
model256.add(MaxPooling2D(pool_size=(2, 2)))

model256.add(Flatten())
model256.add(Dense(256, activation = 'relu'))
model256.add(Dropout(0.5))
model256.add(Dense(7, activation = 'softmax'))

# %%
input_shape=(img_si,img_si,3)

model512 = Sequential()
model512.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model512.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model512.add(Dropout(0.25))
model512.add(MaxPooling2D(pool_size=(2, 2)))

model512.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model512.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model512.add(Dropout(0.25))
model512.add(MaxPooling2D(pool_size=(2, 2)))

model512.add(Flatten())
model512.add(Dense(512, activation = 'relu'))
model512.add(Dropout(0.5))
model512.add(Dense(7, activation = 'softmax'))

# %%
input_shape=(img_si,img_si,3)

model1024 = Sequential()
model1024.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model1024.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model1024.add(Dropout(0.25))
model1024.add(MaxPooling2D(pool_size=(2, 2)))

model1024.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model1024.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model1024.add(Dropout(0.25))
model1024.add(MaxPooling2D(pool_size=(2, 2)))

model1024.add(Flatten())
model1024.add(Dense(1024, activation = 'relu'))
model1024.add(Dropout(0.5))
model1024.add(Dense(7, activation = 'softmax'))

# %%
input_shape=(img_si,img_si,3)

model2048 = Sequential()
model2048.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model2048.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model2048.add(Dropout(0.25))
model2048.add(MaxPooling2D(pool_size=(2, 2)))

model2048.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model2048.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model2048.add(Dropout(0.25))
model2048.add(MaxPooling2D(pool_size=(2, 2)))

model2048.add(Flatten())
model2048.add(Dense(2048, activation = 'relu'))
model2048.add(Dropout(0.5))
model2048.add(Dense(7, activation = 'softmax'))

# %%
input_shape=(img_si,img_si,3)

model4096 = Sequential()
model4096.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model4096.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model4096.add(Dropout(0.25))
model4096.add(MaxPooling2D(pool_size=(2, 2)))

model4096.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model4096.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model4096.add(Dropout(0.25))
model4096.add(MaxPooling2D(pool_size=(2, 2)))

model4096.add(Flatten())
model4096.add(Dense(4096, activation = 'relu'))
model4096.add(Dropout(0.5))
model4096.add(Dense(7, activation = 'softmax'))

# %%
model4.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

# %%
model16.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

# %%
model32.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

# %%
model64.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

# %%
model128.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

# %%
model256.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

# %%
model512.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

# %%
model1024.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

# %%
model2048.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

# %%
model4096.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

# %%
from keras import callbacks
filename4='model4_train_new.csv'
filename16='model16_train_new.csv'
filename32='model32_train_new.csv'
filename64='model64_train_new.csv'
filename128='model128_train_new.csv'
filename256='model256_train_new.csv'
filename512='model512_train_new.csv'
filename1024='model1024_train_new.csv'
filename2048='model2048_train_new.csv'
filename4096='model4096_train_new.csv'

filepath4 = os.path.join('checkpoint', filename4)
filepath16 = os.path.join('checkpoint', filename16)
filepath32 = os.path.join('checkpoint', filename32)
filepath64 = os.path.join('checkpoint', filename64)
filepath128 = os.path.join('checkpoint', filename128)
filepath256 = os.path.join('checkpoint', filename256)
filepath512 = os.path.join('checkpoint', filename512)
filepath1024 = os.path.join('checkpoint', filename1024)
filepath2048 = os.path.join('checkpoint', filename2048)
filepath4096 = os.path.join('checkpoint', filename4096)

checkpoint4 = callbacks.ModelCheckpoint(filepath4, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint16 = callbacks.ModelCheckpoint(filepath16, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint32 = callbacks.ModelCheckpoint(filepath32, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint64 = callbacks.ModelCheckpoint(filepath64, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint128 = callbacks.ModelCheckpoint(filepath128, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint256 = callbacks.ModelCheckpoint(filepath256, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint512 = callbacks.ModelCheckpoint(filepath512, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint1024 = callbacks.ModelCheckpoint(filepath1024, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint2048 = callbacks.ModelCheckpoint(filepath2048, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint4096 = callbacks.ModelCheckpoint(filepath4096, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')

# %%
hist4 = model4.fit(X_train, y_train, batch_size=7, epochs=20, verbose=1, validation_data=(X_test, y_test),callbacks=checkpoint4)
# Out:
# Epoch 1/20
# 25/25 [==============================] - 2s 32ms/step - loss: 2.0327 - accuracy: 0.1444 - val_loss: 1.9470 - val_accuracy: 0.0465
#
# Epoch 00001: val_accuracy improved from -inf to 0.04651, saving model to checkpoint/model4_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model4_train_new.csv/assets
# Epoch 2/20
# 25/25 [==============================] - 0s 14ms/step - loss: 1.9452 - accuracy: 0.1992 - val_loss: 1.9482 - val_accuracy: 0.0465
#
# Epoch 00002: val_accuracy did not improve from 0.04651
# Epoch 3/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9457 - accuracy: 0.1461 - val_loss: 1.9492 - val_accuracy: 0.0465
#
# Epoch 00003: val_accuracy did not improve from 0.04651
# Epoch 4/20
# 25/25 [==============================] - 0s 11ms/step - loss: 1.9446 - accuracy: 0.1985 - val_loss: 1.9510 - val_accuracy: 0.0465
#
# Epoch 00004: val_accuracy did not improve from 0.04651
# Epoch 5/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9449 - accuracy: 0.1526 - val_loss: 1.9518 - val_accuracy: 0.0465
#
# Epoch 00005: val_accuracy did not improve from 0.04651
# Epoch 6/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9428 - accuracy: 0.2078 - val_loss: 1.9530 - val_accuracy: 0.0465
#
# Epoch 00006: val_accuracy did not improve from 0.04651
# Epoch 7/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9442 - accuracy: 0.1578 - val_loss: 1.9538 - val_accuracy: 0.0465
#
# Epoch 00007: val_accuracy did not improve from 0.04651
# Epoch 8/20
# 25/25 [==============================] - 0s 11ms/step - loss: 1.9413 - accuracy: 0.1827 - val_loss: 1.9546 - val_accuracy: 0.0465
#
# Epoch 00008: val_accuracy did not improve from 0.04651
# Epoch 9/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9455 - accuracy: 0.1492 - val_loss: 1.9553 - val_accuracy: 0.0465
#
# Epoch 00009: val_accuracy did not improve from 0.04651
# Epoch 10/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9452 - accuracy: 0.1548 - val_loss: 1.9562 - val_accuracy: 0.0465
#
# Epoch 00010: val_accuracy did not improve from 0.04651
# Epoch 11/20
# 25/25 [==============================] - 0s 11ms/step - loss: 1.9454 - accuracy: 0.1595 - val_loss: 1.9574 - val_accuracy: 0.0465
#
# Epoch 00011: val_accuracy did not improve from 0.04651
# Epoch 12/20
# 25/25 [==============================] - 0s 11ms/step - loss: 1.9468 - accuracy: 0.1560 - val_loss: 1.9579 - val_accuracy: 0.0465
#
# Epoch 00012: val_accuracy did not improve from 0.04651
# Epoch 13/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9417 - accuracy: 0.1553 - val_loss: 1.9592 - val_accuracy: 0.0465
#
# Epoch 00013: val_accuracy did not improve from 0.04651
# Epoch 14/20
# 25/25 [==============================] - 0s 11ms/step - loss: 1.9432 - accuracy: 0.1634 - val_loss: 1.9596 - val_accuracy: 0.0465
#
# Epoch 00014: val_accuracy did not improve from 0.04651
# Epoch 15/20
# 25/25 [==============================] - 0s 11ms/step - loss: 1.9448 - accuracy: 0.1099 - val_loss: 1.9601 - val_accuracy: 0.0465
#
# Epoch 00015: val_accuracy did not improve from 0.04651
# Epoch 16/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9436 - accuracy: 0.1824 - val_loss: 1.9605 - val_accuracy: 0.0465
#
# Epoch 00016: val_accuracy did not improve from 0.04651
# Epoch 17/20
# 25/25 [==============================] - 0s 11ms/step - loss: 1.9441 - accuracy: 0.1470 - val_loss: 1.9616 - val_accuracy: 0.0465
#
# Epoch 00017: val_accuracy did not improve from 0.04651
# Epoch 18/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9423 - accuracy: 0.1750 - val_loss: 1.9622 - val_accuracy: 0.0465
#
# Epoch 00018: val_accuracy did not improve from 0.04651
# Epoch 19/20
# 25/25 [==============================] - 0s 11ms/step - loss: 1.9400 - accuracy: 0.1776 - val_loss: 1.9626 - val_accuracy: 0.0465
#
# Epoch 00019: val_accuracy did not improve from 0.04651
# Epoch 20/20
# 25/25 [==============================] - 0s 11ms/step - loss: 1.9422 - accuracy: 0.1414 - val_loss: 1.9630 - val_accuracy: 0.0465
#
# Epoch 00020: val_accuracy did not improve from 0.04651

# %%
hist16 = model16.fit(X_train, y_train, batch_size=7, epochs=20, verbose=1, validation_data=(X_test, y_test),callbacks=checkpoint16)
# Out:
# Epoch 1/20
# 25/25 [==============================] - 2s 31ms/step - loss: 1.9605 - accuracy: 0.1240 - val_loss: 1.9530 - val_accuracy: 0.2093
#
# Epoch 00001: val_accuracy improved from -inf to 0.20930, saving model to checkpoint/model16_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model16_train_new.csv/assets
# Epoch 2/20
# 25/25 [==============================] - 0s 15ms/step - loss: 1.9550 - accuracy: 0.1499 - val_loss: 1.9474 - val_accuracy: 0.0465
#
# Epoch 00002: val_accuracy did not improve from 0.20930
# Epoch 3/20
# 25/25 [==============================] - 0s 11ms/step - loss: 1.9448 - accuracy: 0.1630 - val_loss: 1.9598 - val_accuracy: 0.2093
#
# Epoch 00003: val_accuracy did not improve from 0.20930
# Epoch 4/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9524 - accuracy: 0.1497 - val_loss: 1.9896 - val_accuracy: 0.0465
#
# Epoch 00004: val_accuracy did not improve from 0.20930
# Epoch 5/20
# 25/25 [==============================] - 0s 11ms/step - loss: 1.9342 - accuracy: 0.1661 - val_loss: 1.9472 - val_accuracy: 0.2093
#
# Epoch 00005: val_accuracy did not improve from 0.20930
# Epoch 6/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9455 - accuracy: 0.1740 - val_loss: 1.9464 - val_accuracy: 0.1628
#
# Epoch 00006: val_accuracy did not improve from 0.20930
# Epoch 7/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9357 - accuracy: 0.2483 - val_loss: 1.9344 - val_accuracy: 0.1860
#
# Epoch 00007: val_accuracy did not improve from 0.20930
# Epoch 8/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9044 - accuracy: 0.2864 - val_loss: 1.9289 - val_accuracy: 0.1860
#
# Epoch 00008: val_accuracy did not improve from 0.20930
# Epoch 9/20
# 25/25 [==============================] - 0s 11ms/step - loss: 1.8541 - accuracy: 0.2748 - val_loss: 1.9148 - val_accuracy: 0.2558
#
# Epoch 00009: val_accuracy improved from 0.20930 to 0.25581, saving model to checkpoint/model16_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model16_train_new.csv/assets
# Epoch 10/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.8732 - accuracy: 0.2527 - val_loss: 1.8642 - val_accuracy: 0.3256
#
# Epoch 00010: val_accuracy improved from 0.25581 to 0.32558, saving model to checkpoint/model16_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model16_train_new.csv/assets
# Epoch 11/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.7565 - accuracy: 0.2379 - val_loss: 1.7694 - val_accuracy: 0.2326
#
# Epoch 00011: val_accuracy did not improve from 0.32558
# Epoch 12/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.6920 - accuracy: 0.2850 - val_loss: 1.7318 - val_accuracy: 0.2326
#
# Epoch 00012: val_accuracy did not improve from 0.32558
# Epoch 13/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.7502 - accuracy: 0.1917 - val_loss: 1.7000 - val_accuracy: 0.2093
#
# Epoch 00013: val_accuracy did not improve from 0.32558
# Epoch 14/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.6311 - accuracy: 0.3060 - val_loss: 1.6482 - val_accuracy: 0.2558
#
# Epoch 00014: val_accuracy did not improve from 0.32558
# Epoch 15/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.5164 - accuracy: 0.3305 - val_loss: 1.6744 - val_accuracy: 0.3488
#
# Epoch 00015: val_accuracy improved from 0.32558 to 0.34884, saving model to checkpoint/model16_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model16_train_new.csv/assets
# Epoch 16/20
# 25/25 [==============================] - 0s 17ms/step - loss: 1.5883 - accuracy: 0.2635 - val_loss: 1.4888 - val_accuracy: 0.3488
#
# Epoch 00016: val_accuracy did not improve from 0.34884
# Epoch 17/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.4521 - accuracy: 0.3391 - val_loss: 1.5709 - val_accuracy: 0.3953
#
# Epoch 00017: val_accuracy improved from 0.34884 to 0.39535, saving model to checkpoint/model16_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model16_train_new.csv/assets
# Epoch 18/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.5600 - accuracy: 0.3267 - val_loss: 1.5529 - val_accuracy: 0.5116
#
# Epoch 00018: val_accuracy improved from 0.39535 to 0.51163, saving model to checkpoint/model16_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model16_train_new.csv/assets
# Epoch 19/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.4543 - accuracy: 0.3431 - val_loss: 1.6389 - val_accuracy: 0.4651
#
# Epoch 00019: val_accuracy did not improve from 0.51163
# Epoch 20/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.4100 - accuracy: 0.3470 - val_loss: 1.4413 - val_accuracy: 0.5116
#
# Epoch 00020: val_accuracy did not improve from 0.51163

# %%
hist32 = model32.fit(X_train, y_train, batch_size=7, epochs=20, verbose=1, validation_data=(X_test, y_test),callbacks=checkpoint32)
# Out:
# Epoch 1/20
# 25/25 [==============================] - 2s 29ms/step - loss: 2.3889 - accuracy: 0.0826 - val_loss: 1.9525 - val_accuracy: 0.0465
#
# Epoch 00001: val_accuracy improved from -inf to 0.04651, saving model to checkpoint/model32_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model32_train_new.csv/assets
# Epoch 2/20
# 25/25 [==============================] - 0s 15ms/step - loss: 1.9440 - accuracy: 0.1719 - val_loss: 2.0129 - val_accuracy: 0.0930
#
# Epoch 00002: val_accuracy improved from 0.04651 to 0.09302, saving model to checkpoint/model32_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model32_train_new.csv/assets
# Epoch 3/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9856 - accuracy: 0.1663 - val_loss: 1.9585 - val_accuracy: 0.0465
#
# Epoch 00003: val_accuracy did not improve from 0.09302
# Epoch 4/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9437 - accuracy: 0.1348 - val_loss: 1.9532 - val_accuracy: 0.0465
#
# Epoch 00004: val_accuracy did not improve from 0.09302
# Epoch 5/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9455 - accuracy: 0.1553 - val_loss: 1.9476 - val_accuracy: 0.0465
#
# Epoch 00005: val_accuracy did not improve from 0.09302
# Epoch 6/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9427 - accuracy: 0.1480 - val_loss: 1.9434 - val_accuracy: 0.0465
#
# Epoch 00006: val_accuracy did not improve from 0.09302
# Epoch 7/20
# 25/25 [==============================] - 0s 11ms/step - loss: 1.9169 - accuracy: 0.1807 - val_loss: 1.9478 - val_accuracy: 0.0465
#
# Epoch 00007: val_accuracy did not improve from 0.09302
# Epoch 8/20
# 25/25 [==============================] - 0s 11ms/step - loss: 1.9211 - accuracy: 0.2089 - val_loss: 1.9303 - val_accuracy: 0.0465
#
# Epoch 00008: val_accuracy did not improve from 0.09302
# Epoch 9/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.8623 - accuracy: 0.1845 - val_loss: 1.8145 - val_accuracy: 0.1860
#
# Epoch 00009: val_accuracy improved from 0.09302 to 0.18605, saving model to checkpoint/model32_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model32_train_new.csv/assets
# Epoch 10/20
# 25/25 [==============================] - 0s 15ms/step - loss: 1.6482 - accuracy: 0.3108 - val_loss: 1.6952 - val_accuracy: 0.2791
#
# Epoch 00010: val_accuracy improved from 0.18605 to 0.27907, saving model to checkpoint/model32_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model32_train_new.csv/assets
# Epoch 11/20
# 25/25 [==============================] - 0s 14ms/step - loss: 1.6624 - accuracy: 0.2768 - val_loss: 1.6239 - val_accuracy: 0.4419
#
# Epoch 00011: val_accuracy improved from 0.27907 to 0.44186, saving model to checkpoint/model32_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model32_train_new.csv/assets
# Epoch 12/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.5163 - accuracy: 0.3766 - val_loss: 1.6091 - val_accuracy: 0.3721
#
# Epoch 00012: val_accuracy did not improve from 0.44186
# Epoch 13/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.4624 - accuracy: 0.4344 - val_loss: 1.4939 - val_accuracy: 0.3721
#
# Epoch 00013: val_accuracy did not improve from 0.44186
# Epoch 14/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.4070 - accuracy: 0.3970 - val_loss: 1.5675 - val_accuracy: 0.4884
#
# Epoch 00014: val_accuracy improved from 0.44186 to 0.48837, saving model to checkpoint/model32_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model32_train_new.csv/assets
# Epoch 15/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.3631 - accuracy: 0.3855 - val_loss: 1.4841 - val_accuracy: 0.4651
#
# Epoch 00015: val_accuracy did not improve from 0.48837
# Epoch 16/20
# 25/25 [==============================] - 0s 14ms/step - loss: 1.2306 - accuracy: 0.5276 - val_loss: 1.4617 - val_accuracy: 0.5116
#
# Epoch 00016: val_accuracy improved from 0.48837 to 0.51163, saving model to checkpoint/model32_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model32_train_new.csv/assets
# Epoch 17/20
# 25/25 [==============================] - 0s 16ms/step - loss: 1.1215 - accuracy: 0.5254 - val_loss: 1.3805 - val_accuracy: 0.6512
#
# Epoch 00017: val_accuracy improved from 0.51163 to 0.65116, saving model to checkpoint/model32_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model32_train_new.csv/assets
# Epoch 18/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.1294 - accuracy: 0.4768 - val_loss: 1.3356 - val_accuracy: 0.5814
#
# Epoch 00018: val_accuracy did not improve from 0.65116
# Epoch 19/20
# 25/25 [==============================] - 0s 13ms/step - loss: 0.9929 - accuracy: 0.5557 - val_loss: 1.3464 - val_accuracy: 0.4884
#
# Epoch 00019: val_accuracy did not improve from 0.65116
# Epoch 20/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.0500 - accuracy: 0.5654 - val_loss: 1.2620 - val_accuracy: 0.6744
#
# Epoch 00020: val_accuracy improved from 0.65116 to 0.67442, saving model to checkpoint/model32_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model32_train_new.csv/assets

# %%
hist64 = model64.fit(X_train, y_train, batch_size=7, epochs=20, verbose=1, validation_data=(X_test, y_test),callbacks=checkpoint64)
# Out:
# Epoch 1/20
# 25/25 [==============================] - 2s 33ms/step - loss: 2.1832 - accuracy: 0.1259 - val_loss: 1.9478 - val_accuracy: 0.0465
#
# Epoch 00001: val_accuracy improved from -inf to 0.04651, saving model to checkpoint/model64_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model64_train_new.csv/assets
# Epoch 2/20
# 25/25 [==============================] - 0s 15ms/step - loss: 1.9457 - accuracy: 0.1279 - val_loss: 1.9487 - val_accuracy: 0.0465
#
# Epoch 00002: val_accuracy did not improve from 0.04651
# Epoch 3/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9446 - accuracy: 0.1667 - val_loss: 1.9500 - val_accuracy: 0.0465
#
# Epoch 00003: val_accuracy did not improve from 0.04651
# Epoch 4/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9419 - accuracy: 0.1672 - val_loss: 1.9524 - val_accuracy: 0.0465
#
# Epoch 00004: val_accuracy did not improve from 0.04651
# Epoch 5/20
# 25/25 [==============================] - 0s 14ms/step - loss: 1.9434 - accuracy: 0.1471 - val_loss: 1.9541 - val_accuracy: 0.1628
#
# Epoch 00005: val_accuracy improved from 0.04651 to 0.16279, saving model to checkpoint/model64_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model64_train_new.csv/assets
# Epoch 6/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9907 - accuracy: 0.1758 - val_loss: 1.9706 - val_accuracy: 0.0698
#
# Epoch 00006: val_accuracy did not improve from 0.16279
# Epoch 7/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9261 - accuracy: 0.1227 - val_loss: 1.9401 - val_accuracy: 0.1628
#
# Epoch 00007: val_accuracy did not improve from 0.16279
# Epoch 8/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.8917 - accuracy: 0.2544 - val_loss: 1.9312 - val_accuracy: 0.0930
#
# Epoch 00008: val_accuracy did not improve from 0.16279
# Epoch 9/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.8901 - accuracy: 0.2684 - val_loss: 1.8782 - val_accuracy: 0.0698
#
# Epoch 00009: val_accuracy did not improve from 0.16279
# Epoch 10/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.7724 - accuracy: 0.3076 - val_loss: 1.6730 - val_accuracy: 0.4186
#
# Epoch 00010: val_accuracy improved from 0.16279 to 0.41860, saving model to checkpoint/model64_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model64_train_new.csv/assets
# Epoch 11/20
# 25/25 [==============================] - 0s 14ms/step - loss: 1.6423 - accuracy: 0.3695 - val_loss: 1.7006 - val_accuracy: 0.3488
#
# Epoch 00011: val_accuracy did not improve from 0.41860
# Epoch 12/20
# 25/25 [==============================] - 0s 14ms/step - loss: 1.4870 - accuracy: 0.4684 - val_loss: 1.5366 - val_accuracy: 0.4651
#
# Epoch 00012: val_accuracy improved from 0.41860 to 0.46512, saving model to checkpoint/model64_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model64_train_new.csv/assets
# Epoch 13/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.3509 - accuracy: 0.5220 - val_loss: 1.3928 - val_accuracy: 0.5116
#
# Epoch 00013: val_accuracy improved from 0.46512 to 0.51163, saving model to checkpoint/model64_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model64_train_new.csv/assets
# Epoch 14/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.1553 - accuracy: 0.5105 - val_loss: 1.2333 - val_accuracy: 0.6279
#
# Epoch 00014: val_accuracy improved from 0.51163 to 0.62791, saving model to checkpoint/model64_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model64_train_new.csv/assets
# Epoch 15/20
# 25/25 [==============================] - 0s 15ms/step - loss: 0.9477 - accuracy: 0.7091 - val_loss: 1.1657 - val_accuracy: 0.6512
#
# Epoch 00015: val_accuracy improved from 0.62791 to 0.65116, saving model to checkpoint/model64_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model64_train_new.csv/assets
# Epoch 16/20
# 25/25 [==============================] - 0s 12ms/step - loss: 0.9251 - accuracy: 0.6356 - val_loss: 1.0186 - val_accuracy: 0.6047
#
# Epoch 00016: val_accuracy did not improve from 0.65116
# Epoch 17/20
# 25/25 [==============================] - 0s 12ms/step - loss: 0.7510 - accuracy: 0.6809 - val_loss: 1.0018 - val_accuracy: 0.6279
#
# Epoch 00017: val_accuracy did not improve from 0.65116
# Epoch 18/20
# 25/25 [==============================] - 0s 14ms/step - loss: 0.5966 - accuracy: 0.8145 - val_loss: 0.9244 - val_accuracy: 0.6744
#
# Epoch 00018: val_accuracy improved from 0.65116 to 0.67442, saving model to checkpoint/model64_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model64_train_new.csv/assets
# Epoch 19/20
# 25/25 [==============================] - 0s 12ms/step - loss: 0.5865 - accuracy: 0.7638 - val_loss: 0.8875 - val_accuracy: 0.7674
#
# Epoch 00019: val_accuracy improved from 0.67442 to 0.76744, saving model to checkpoint/model64_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model64_train_new.csv/assets
# Epoch 20/20
# 25/25 [==============================] - 0s 12ms/step - loss: 0.6035 - accuracy: 0.8242 - val_loss: 0.7444 - val_accuracy: 0.8140
#
# Epoch 00020: val_accuracy improved from 0.76744 to 0.81395, saving model to checkpoint/model64_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model64_train_new.csv/assets

# %%
hist128 = model128.fit(X_train, y_train, batch_size=7, epochs=20, verbose=1, validation_data=(X_test, y_test),callbacks=checkpoint128)
# Out:
# Epoch 1/20
# 25/25 [==============================] - 2s 31ms/step - loss: 2.6113 - accuracy: 0.1005 - val_loss: 1.9748 - val_accuracy: 0.0930
#
# Epoch 00001: val_accuracy improved from -inf to 0.09302, saving model to checkpoint/model128_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model128_train_new.csv/assets
# Epoch 2/20
# 25/25 [==============================] - 0s 16ms/step - loss: 1.9593 - accuracy: 0.1028 - val_loss: 1.9483 - val_accuracy: 0.1163
#
# Epoch 00002: val_accuracy improved from 0.09302 to 0.11628, saving model to checkpoint/model128_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model128_train_new.csv/assets
# Epoch 3/20
# 25/25 [==============================] - 0s 15ms/step - loss: 1.9442 - accuracy: 0.1522 - val_loss: 1.9529 - val_accuracy: 0.0465
#
# Epoch 00003: val_accuracy did not improve from 0.11628
# Epoch 4/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9440 - accuracy: 0.1348 - val_loss: 1.9533 - val_accuracy: 0.0465
#
# Epoch 00004: val_accuracy did not improve from 0.11628
# Epoch 5/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9422 - accuracy: 0.1299 - val_loss: 1.9582 - val_accuracy: 0.0930
#
# Epoch 00005: val_accuracy did not improve from 0.11628
# Epoch 6/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9364 - accuracy: 0.2390 - val_loss: 1.9610 - val_accuracy: 0.0698
#
# Epoch 00006: val_accuracy did not improve from 0.11628
# Epoch 7/20
# 25/25 [==============================] - 0s 15ms/step - loss: 1.9146 - accuracy: 0.2060 - val_loss: 1.8956 - val_accuracy: 0.3488
#
# Epoch 00007: val_accuracy improved from 0.11628 to 0.34884, saving model to checkpoint/model128_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model128_train_new.csv/assets
# Epoch 8/20
# 25/25 [==============================] - 0s 15ms/step - loss: 1.7626 - accuracy: 0.2905 - val_loss: 1.6914 - val_accuracy: 0.3721
#
# Epoch 00008: val_accuracy improved from 0.34884 to 0.37209, saving model to checkpoint/model128_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model128_train_new.csv/assets
# Epoch 9/20
# 25/25 [==============================] - 0s 15ms/step - loss: 1.5235 - accuracy: 0.4033 - val_loss: 1.6701 - val_accuracy: 0.4651
#
# Epoch 00009: val_accuracy improved from 0.37209 to 0.46512, saving model to checkpoint/model128_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model128_train_new.csv/assets
# Epoch 10/20
# 25/25 [==============================] - 0s 17ms/step - loss: 1.3642 - accuracy: 0.4744 - val_loss: 1.4910 - val_accuracy: 0.4419
#
# Epoch 00010: val_accuracy did not improve from 0.46512
# Epoch 11/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.3300 - accuracy: 0.5428 - val_loss: 1.4299 - val_accuracy: 0.4651
#
# Epoch 00011: val_accuracy did not improve from 0.46512
# Epoch 12/20
# 25/25 [==============================] - 0s 15ms/step - loss: 0.9218 - accuracy: 0.6321 - val_loss: 1.1314 - val_accuracy: 0.5349
#
# Epoch 00012: val_accuracy improved from 0.46512 to 0.53488, saving model to checkpoint/model128_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model128_train_new.csv/assets
# Epoch 13/20
# 25/25 [==============================] - 0s 15ms/step - loss: 0.8885 - accuracy: 0.6555 - val_loss: 1.0561 - val_accuracy: 0.6512
#
# Epoch 00013: val_accuracy improved from 0.53488 to 0.65116, saving model to checkpoint/model128_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model128_train_new.csv/assets
# Epoch 14/20
# 25/25 [==============================] - 0s 17ms/step - loss: 0.7414 - accuracy: 0.7619 - val_loss: 0.9115 - val_accuracy: 0.6047
#
# Epoch 00014: val_accuracy did not improve from 0.65116
# Epoch 15/20
# 25/25 [==============================] - 0s 14ms/step - loss: 0.4289 - accuracy: 0.8469 - val_loss: 1.0325 - val_accuracy: 0.6279
#
# Epoch 00015: val_accuracy did not improve from 0.65116
# Epoch 16/20
# 25/25 [==============================] - 0s 14ms/step - loss: 0.4695 - accuracy: 0.8622 - val_loss: 0.9334 - val_accuracy: 0.6744
#
# Epoch 00016: val_accuracy improved from 0.65116 to 0.67442, saving model to checkpoint/model128_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model128_train_new.csv/assets
# Epoch 17/20
# 25/25 [==============================] - 0s 15ms/step - loss: 0.4476 - accuracy: 0.8515 - val_loss: 0.9427 - val_accuracy: 0.6977
#
# Epoch 00017: val_accuracy improved from 0.67442 to 0.69767, saving model to checkpoint/model128_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model128_train_new.csv/assets
# Epoch 18/20
# 25/25 [==============================] - 0s 17ms/step - loss: 0.4852 - accuracy: 0.8246 - val_loss: 0.8414 - val_accuracy: 0.7674
#
# Epoch 00018: val_accuracy improved from 0.69767 to 0.76744, saving model to checkpoint/model128_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model128_train_new.csv/assets
# Epoch 19/20
# 25/25 [==============================] - 0s 14ms/step - loss: 0.4589 - accuracy: 0.8137 - val_loss: 0.9168 - val_accuracy: 0.6977
#
# Epoch 00019: val_accuracy did not improve from 0.76744
# Epoch 20/20
# 25/25 [==============================] - 0s 15ms/step - loss: 0.4478 - accuracy: 0.8653 - val_loss: 0.8650 - val_accuracy: 0.7442
#
# Epoch 00020: val_accuracy did not improve from 0.76744

# %%
hist256 = model256.fit(X_train, y_train, batch_size=7, epochs=20, verbose=1, validation_data=(X_test, y_test),callbacks=checkpoint256)
# Out:
# Epoch 1/20
# 25/25 [==============================] - 2s 34ms/step - loss: 2.3373 - accuracy: 0.1736 - val_loss: 1.9461 - val_accuracy: 0.0698
#
# Epoch 00001: val_accuracy improved from -inf to 0.06977, saving model to checkpoint/model256_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model256_train_new.csv/assets
# Epoch 2/20
# 25/25 [==============================] - 0s 18ms/step - loss: 1.9433 - accuracy: 0.2739 - val_loss: 1.9366 - val_accuracy: 0.2093
#
# Epoch 00002: val_accuracy improved from 0.06977 to 0.20930, saving model to checkpoint/model256_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model256_train_new.csv/assets
# Epoch 3/20
# 25/25 [==============================] - 0s 18ms/step - loss: 1.9068 - accuracy: 0.2170 - val_loss: 1.9090 - val_accuracy: 0.1628
#
# Epoch 00003: val_accuracy did not improve from 0.20930
# Epoch 4/20
# 25/25 [==============================] - 0s 15ms/step - loss: 1.7641 - accuracy: 0.3181 - val_loss: 1.7561 - val_accuracy: 0.2558
#
# Epoch 00004: val_accuracy improved from 0.20930 to 0.25581, saving model to checkpoint/model256_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model256_train_new.csv/assets
# Epoch 5/20
# 25/25 [==============================] - 0s 18ms/step - loss: 1.5052 - accuracy: 0.4379 - val_loss: 1.3550 - val_accuracy: 0.4419
#
# Epoch 00005: val_accuracy improved from 0.25581 to 0.44186, saving model to checkpoint/model256_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model256_train_new.csv/assets
# Epoch 6/20
# 25/25 [==============================] - 0s 19ms/step - loss: 1.2972 - accuracy: 0.5173 - val_loss: 1.1543 - val_accuracy: 0.4651
#
# Epoch 00006: val_accuracy improved from 0.44186 to 0.46512, saving model to checkpoint/model256_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model256_train_new.csv/assets
# Epoch 7/20
# 25/25 [==============================] - 0s 17ms/step - loss: 0.7987 - accuracy: 0.6906 - val_loss: 1.1086 - val_accuracy: 0.5581
#
# Epoch 00007: val_accuracy improved from 0.46512 to 0.55814, saving model to checkpoint/model256_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model256_train_new.csv/assets
# Epoch 8/20
# 25/25 [==============================] - 0s 19ms/step - loss: 0.7081 - accuracy: 0.7148 - val_loss: 0.7882 - val_accuracy: 0.7907
#
# Epoch 00008: val_accuracy improved from 0.55814 to 0.79070, saving model to checkpoint/model256_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model256_train_new.csv/assets
# Epoch 9/20
# 25/25 [==============================] - 0s 17ms/step - loss: 0.3805 - accuracy: 0.8546 - val_loss: 0.7313 - val_accuracy: 0.6279
#
# Epoch 00009: val_accuracy did not improve from 0.79070
# Epoch 10/20
# 25/25 [==============================] - 0s 16ms/step - loss: 0.4993 - accuracy: 0.8071 - val_loss: 0.9853 - val_accuracy: 0.6512
#
# Epoch 00010: val_accuracy did not improve from 0.79070
# Epoch 11/20
# 25/25 [==============================] - 0s 15ms/step - loss: 0.5206 - accuracy: 0.8833 - val_loss: 0.9210 - val_accuracy: 0.6744
#
# Epoch 00011: val_accuracy did not improve from 0.79070
# Epoch 12/20
# 25/25 [==============================] - 0s 15ms/step - loss: 0.3415 - accuracy: 0.9190 - val_loss: 0.7534 - val_accuracy: 0.7442
#
# Epoch 00012: val_accuracy did not improve from 0.79070
# Epoch 13/20
# 25/25 [==============================] - 0s 15ms/step - loss: 0.1817 - accuracy: 0.9272 - val_loss: 0.6000 - val_accuracy: 0.6977
#
# Epoch 00013: val_accuracy did not improve from 0.79070
# Epoch 14/20
# 25/25 [==============================] - 0s 15ms/step - loss: 0.2403 - accuracy: 0.9411 - val_loss: 0.6952 - val_accuracy: 0.7674
#
# Epoch 00014: val_accuracy did not improve from 0.79070
# Epoch 15/20
# 25/25 [==============================] - 0s 15ms/step - loss: 0.2445 - accuracy: 0.9002 - val_loss: 0.6945 - val_accuracy: 0.7442
#
# Epoch 00015: val_accuracy did not improve from 0.79070
# Epoch 16/20
# 25/25 [==============================] - 0s 16ms/step - loss: 0.1658 - accuracy: 0.9517 - val_loss: 0.7228 - val_accuracy: 0.6512
#
# Epoch 00016: val_accuracy did not improve from 0.79070
# Epoch 17/20
# 25/25 [==============================] - 0s 15ms/step - loss: 0.1738 - accuracy: 0.9457 - val_loss: 0.7074 - val_accuracy: 0.7209
#
# Epoch 00017: val_accuracy did not improve from 0.79070
# Epoch 18/20
# 25/25 [==============================] - 0s 15ms/step - loss: 0.1371 - accuracy: 0.9399 - val_loss: 0.6370 - val_accuracy: 0.7674
#
# Epoch 00018: val_accuracy did not improve from 0.79070
# Epoch 19/20
# 25/25 [==============================] - 0s 15ms/step - loss: 0.1296 - accuracy: 0.9500 - val_loss: 0.7608 - val_accuracy: 0.7674
#
# Epoch 00019: val_accuracy did not improve from 0.79070
# Epoch 20/20
# 25/25 [==============================] - 0s 17ms/step - loss: 0.0991 - accuracy: 0.9588 - val_loss: 0.6231 - val_accuracy: 0.7209
#
# Epoch 00020: val_accuracy did not improve from 0.79070

# %%
hist512 = model512.fit(X_train, y_train, batch_size=7, epochs=20, verbose=1, validation_data=(X_test, y_test),callbacks=checkpoint512)
# Out:
# Epoch 1/20
# 25/25 [==============================] - 2s 51ms/step - loss: 2.7838 - accuracy: 0.0804 - val_loss: 1.9483 - val_accuracy: 0.0465
#
# Epoch 00001: val_accuracy improved from -inf to 0.04651, saving model to checkpoint/model512_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model512_train_new.csv/assets
# Epoch 2/20
# 25/25 [==============================] - 1s 22ms/step - loss: 1.9444 - accuracy: 0.1735 - val_loss: 1.9420 - val_accuracy: 0.0698
#
# Epoch 00002: val_accuracy improved from 0.04651 to 0.06977, saving model to checkpoint/model512_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model512_train_new.csv/assets
# Epoch 3/20
# 25/25 [==============================] - 1s 22ms/step - loss: 1.9218 - accuracy: 0.2200 - val_loss: 1.9053 - val_accuracy: 0.2558
#
# Epoch 00003: val_accuracy improved from 0.06977 to 0.25581, saving model to checkpoint/model512_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model512_train_new.csv/assets
# Epoch 4/20
# 25/25 [==============================] - 1s 21ms/step - loss: 1.7633 - accuracy: 0.3439 - val_loss: 1.8340 - val_accuracy: 0.1860
#
# Epoch 00004: val_accuracy did not improve from 0.25581
# Epoch 5/20
# 25/25 [==============================] - 1s 20ms/step - loss: 1.7649 - accuracy: 0.3452 - val_loss: 1.6910 - val_accuracy: 0.3256
#
# Epoch 00005: val_accuracy improved from 0.25581 to 0.32558, saving model to checkpoint/model512_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model512_train_new.csv/assets
# Epoch 6/20
# 25/25 [==============================] - 1s 23ms/step - loss: 1.6154 - accuracy: 0.3799 - val_loss: 1.6697 - val_accuracy: 0.3256
#
# Epoch 00006: val_accuracy did not improve from 0.32558
# Epoch 7/20
# 25/25 [==============================] - 0s 19ms/step - loss: 1.5161 - accuracy: 0.4609 - val_loss: 1.4608 - val_accuracy: 0.4884
#
# Epoch 00007: val_accuracy improved from 0.32558 to 0.48837, saving model to checkpoint/model512_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model512_train_new.csv/assets
# Epoch 8/20
# 25/25 [==============================] - 1s 21ms/step - loss: 1.3440 - accuracy: 0.5102 - val_loss: 1.3147 - val_accuracy: 0.4419
#
# Epoch 00008: val_accuracy did not improve from 0.48837
# Epoch 9/20
# 25/25 [==============================] - 0s 19ms/step - loss: 0.9014 - accuracy: 0.6638 - val_loss: 1.2059 - val_accuracy: 0.5581
#
# Epoch 00009: val_accuracy improved from 0.48837 to 0.55814, saving model to checkpoint/model512_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model512_train_new.csv/assets
# Epoch 10/20
# 25/25 [==============================] - 1s 22ms/step - loss: 0.8525 - accuracy: 0.7269 - val_loss: 1.0947 - val_accuracy: 0.5814
#
# Epoch 00010: val_accuracy improved from 0.55814 to 0.58140, saving model to checkpoint/model512_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model512_train_new.csv/assets
# Epoch 11/20
# 25/25 [==============================] - 1s 21ms/step - loss: 0.6685 - accuracy: 0.7714 - val_loss: 0.9494 - val_accuracy: 0.6279
#
# Epoch 00011: val_accuracy improved from 0.58140 to 0.62791, saving model to checkpoint/model512_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model512_train_new.csv/assets
# Epoch 12/20
# 25/25 [==============================] - 1s 21ms/step - loss: 0.4611 - accuracy: 0.8448 - val_loss: 0.9820 - val_accuracy: 0.6512
#
# Epoch 00012: val_accuracy improved from 0.62791 to 0.65116, saving model to checkpoint/model512_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model512_train_new.csv/assets
# Epoch 13/20
# 25/25 [==============================] - 1s 22ms/step - loss: 0.3457 - accuracy: 0.8806 - val_loss: 0.7017 - val_accuracy: 0.7209
#
# Epoch 00013: val_accuracy improved from 0.65116 to 0.72093, saving model to checkpoint/model512_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model512_train_new.csv/assets
# Epoch 14/20
# 25/25 [==============================] - 1s 22ms/step - loss: 0.2977 - accuracy: 0.8937 - val_loss: 0.7248 - val_accuracy: 0.6744
#
# Epoch 00014: val_accuracy did not improve from 0.72093
# Epoch 15/20
# 25/25 [==============================] - 0s 19ms/step - loss: 0.3419 - accuracy: 0.8547 - val_loss: 0.6687 - val_accuracy: 0.6977
#
# Epoch 00015: val_accuracy did not improve from 0.72093
# Epoch 16/20
# 25/25 [==============================] - 1s 20ms/step - loss: 0.2331 - accuracy: 0.9411 - val_loss: 0.6891 - val_accuracy: 0.6977
#
# Epoch 00016: val_accuracy did not improve from 0.72093
# Epoch 17/20
# 25/25 [==============================] - 0s 19ms/step - loss: 0.1156 - accuracy: 0.9645 - val_loss: 0.7094 - val_accuracy: 0.7209
#
# Epoch 00017: val_accuracy did not improve from 0.72093
# Epoch 18/20
# 25/25 [==============================] - 0s 20ms/step - loss: 0.3158 - accuracy: 0.8828 - val_loss: 0.9339 - val_accuracy: 0.6279
#
# Epoch 00018: val_accuracy did not improve from 0.72093
# Epoch 19/20
# 25/25 [==============================] - 1s 21ms/step - loss: 0.1853 - accuracy: 0.9442 - val_loss: 0.6047 - val_accuracy: 0.7442
#
# Epoch 00019: val_accuracy improved from 0.72093 to 0.74419, saving model to checkpoint/model512_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model512_train_new.csv/assets
# Epoch 20/20
# 25/25 [==============================] - 1s 21ms/step - loss: 0.1850 - accuracy: 0.9160 - val_loss: 0.5937 - val_accuracy: 0.7442
#
# Epoch 00020: val_accuracy did not improve from 0.74419

# %%
hist1024 = model1024.fit(X_train, y_train, batch_size=7, epochs=20, verbose=1, validation_data=(X_test, y_test),callbacks=checkpoint1024)
# Out:
# Epoch 1/20
# 25/25 [==============================] - 2s 46ms/step - loss: 3.5575 - accuracy: 0.2088 - val_loss: 1.9483 - val_accuracy: 0.0698
#
# Epoch 00001: val_accuracy improved from -inf to 0.06977, saving model to checkpoint/model1024_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1024_train_new.csv/assets
# Epoch 2/20
# 25/25 [==============================] - 1s 28ms/step - loss: 1.9380 - accuracy: 0.2085 - val_loss: 1.9271 - val_accuracy: 0.3256
#
# Epoch 00002: val_accuracy improved from 0.06977 to 0.32558, saving model to checkpoint/model1024_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1024_train_new.csv/assets
# Epoch 3/20
# 25/25 [==============================] - 1s 28ms/step - loss: 1.8708 - accuracy: 0.2386 - val_loss: 1.8649 - val_accuracy: 0.1628
#
# Epoch 00003: val_accuracy did not improve from 0.32558
# Epoch 4/20
# 25/25 [==============================] - 1s 26ms/step - loss: 1.7673 - accuracy: 0.3153 - val_loss: 1.7681 - val_accuracy: 0.2791
#
# Epoch 00004: val_accuracy did not improve from 0.32558
# Epoch 5/20
# 25/25 [==============================] - 1s 26ms/step - loss: 1.5268 - accuracy: 0.3910 - val_loss: 1.7561 - val_accuracy: 0.2093
#
# Epoch 00005: val_accuracy did not improve from 0.32558
# Epoch 6/20
# 25/25 [==============================] - 1s 26ms/step - loss: 1.2961 - accuracy: 0.5454 - val_loss: 3.1476 - val_accuracy: 0.1628
#
# Epoch 00006: val_accuracy did not improve from 0.32558
# Epoch 7/20
# 25/25 [==============================] - 1s 27ms/step - loss: 1.5182 - accuracy: 0.5947 - val_loss: 1.4455 - val_accuracy: 0.4651
#
# Epoch 00007: val_accuracy improved from 0.32558 to 0.46512, saving model to checkpoint/model1024_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1024_train_new.csv/assets
# Epoch 8/20
# 25/25 [==============================] - 1s 28ms/step - loss: 1.0703 - accuracy: 0.6260 - val_loss: 1.1344 - val_accuracy: 0.4884
#
# Epoch 00008: val_accuracy improved from 0.46512 to 0.48837, saving model to checkpoint/model1024_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1024_train_new.csv/assets
# Epoch 9/20
# 25/25 [==============================] - 1s 29ms/step - loss: 0.6596 - accuracy: 0.7905 - val_loss: 1.2461 - val_accuracy: 0.5116
#
# Epoch 00009: val_accuracy improved from 0.48837 to 0.51163, saving model to checkpoint/model1024_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1024_train_new.csv/assets
# Epoch 10/20
# 25/25 [==============================] - 1s 28ms/step - loss: 0.5326 - accuracy: 0.8664 - val_loss: 1.0516 - val_accuracy: 0.5581
#
# Epoch 00010: val_accuracy improved from 0.51163 to 0.55814, saving model to checkpoint/model1024_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1024_train_new.csv/assets
# Epoch 11/20
# 25/25 [==============================] - 1s 27ms/step - loss: 0.3113 - accuracy: 0.8986 - val_loss: 0.8919 - val_accuracy: 0.6512
#
# Epoch 00011: val_accuracy improved from 0.55814 to 0.65116, saving model to checkpoint/model1024_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1024_train_new.csv/assets
# Epoch 12/20
# 25/25 [==============================] - 1s 28ms/step - loss: 0.2214 - accuracy: 0.9102 - val_loss: 0.7973 - val_accuracy: 0.7209
#
# Epoch 00012: val_accuracy improved from 0.65116 to 0.72093, saving model to checkpoint/model1024_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1024_train_new.csv/assets
# Epoch 13/20
# 25/25 [==============================] - 1s 28ms/step - loss: 0.3766 - accuracy: 0.8540 - val_loss: 0.7373 - val_accuracy: 0.7209
#
# Epoch 00013: val_accuracy did not improve from 0.72093
# Epoch 14/20
# 25/25 [==============================] - 1s 26ms/step - loss: 0.2400 - accuracy: 0.9117 - val_loss: 0.8332 - val_accuracy: 0.6279
#
# Epoch 00014: val_accuracy did not improve from 0.72093
# Epoch 15/20
# 25/25 [==============================] - 1s 26ms/step - loss: 0.1848 - accuracy: 0.9287 - val_loss: 0.8228 - val_accuracy: 0.6977
#
# Epoch 00015: val_accuracy did not improve from 0.72093
# Epoch 16/20
# 25/25 [==============================] - 1s 27ms/step - loss: 0.1843 - accuracy: 0.9704 - val_loss: 0.7785 - val_accuracy: 0.6279
#
# Epoch 00016: val_accuracy did not improve from 0.72093
# Epoch 17/20
# 25/25 [==============================] - 1s 26ms/step - loss: 0.0866 - accuracy: 0.9809 - val_loss: 0.8393 - val_accuracy: 0.6977
#
# Epoch 00017: val_accuracy did not improve from 0.72093
# Epoch 18/20
# 25/25 [==============================] - 1s 25ms/step - loss: 0.1025 - accuracy: 0.9794 - val_loss: 0.8219 - val_accuracy: 0.6744
#
# Epoch 00018: val_accuracy did not improve from 0.72093
# Epoch 19/20
# 25/25 [==============================] - 1s 26ms/step - loss: 0.0694 - accuracy: 0.9782 - val_loss: 0.8296 - val_accuracy: 0.6279
#
# Epoch 00019: val_accuracy did not improve from 0.72093
# Epoch 20/20
# 25/25 [==============================] - 1s 27ms/step - loss: 0.0905 - accuracy: 0.9776 - val_loss: 0.7799 - val_accuracy: 0.6512
#
# Epoch 00020: val_accuracy did not improve from 0.72093

# %%
hist2048 = model2048.fit(X_train, y_train, batch_size=7, epochs=20, verbose=1, validation_data=(X_test, y_test),callbacks=checkpoint2048)
# Out:
# Epoch 1/20
# 25/25 [==============================] - 2s 58ms/step - loss: 3.6913 - accuracy: 0.1009 - val_loss: 1.9653 - val_accuracy: 0.0465
#
# Epoch 00001: val_accuracy improved from -inf to 0.04651, saving model to checkpoint/model2048_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model2048_train_new.csv/assets
# Epoch 2/20
# 25/25 [==============================] - 1s 42ms/step - loss: 1.9418 - accuracy: 0.1840 - val_loss: 1.9429 - val_accuracy: 0.1163
#
# Epoch 00002: val_accuracy improved from 0.04651 to 0.11628, saving model to checkpoint/model2048_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model2048_train_new.csv/assets
# Epoch 3/20
# 25/25 [==============================] - 1s 41ms/step - loss: 1.9007 - accuracy: 0.2945 - val_loss: 1.9682 - val_accuracy: 0.1163
#
# Epoch 00003: val_accuracy did not improve from 0.11628
# Epoch 4/20
# 25/25 [==============================] - 1s 39ms/step - loss: 1.8601 - accuracy: 0.2198 - val_loss: 1.8975 - val_accuracy: 0.2558
#
# Epoch 00004: val_accuracy improved from 0.11628 to 0.25581, saving model to checkpoint/model2048_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model2048_train_new.csv/assets
# Epoch 5/20
# 25/25 [==============================] - 1s 43ms/step - loss: 1.7799 - accuracy: 0.3155 - val_loss: 1.7780 - val_accuracy: 0.2326
#
# Epoch 00005: val_accuracy did not improve from 0.25581
# Epoch 6/20
# 25/25 [==============================] - 1s 41ms/step - loss: 1.4062 - accuracy: 0.4894 - val_loss: 1.3621 - val_accuracy: 0.4186
#
# Epoch 00006: val_accuracy improved from 0.25581 to 0.41860, saving model to checkpoint/model2048_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model2048_train_new.csv/assets
# Epoch 7/20
# 25/25 [==============================] - 1s 43ms/step - loss: 0.9807 - accuracy: 0.6344 - val_loss: 1.1824 - val_accuracy: 0.5581
#
# Epoch 00007: val_accuracy improved from 0.41860 to 0.55814, saving model to checkpoint/model2048_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model2048_train_new.csv/assets
# Epoch 8/20
# 25/25 [==============================] - 1s 42ms/step - loss: 0.7592 - accuracy: 0.7513 - val_loss: 0.9850 - val_accuracy: 0.6279
#
# Epoch 00008: val_accuracy improved from 0.55814 to 0.62791, saving model to checkpoint/model2048_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model2048_train_new.csv/assets
# Epoch 9/20
# 25/25 [==============================] - 1s 42ms/step - loss: 0.5613 - accuracy: 0.7928 - val_loss: 0.8657 - val_accuracy: 0.6279
#
# Epoch 00009: val_accuracy did not improve from 0.62791
# Epoch 10/20
# 25/25 [==============================] - 1s 42ms/step - loss: 0.5166 - accuracy: 0.8500 - val_loss: 0.8466 - val_accuracy: 0.6744
#
# Epoch 00010: val_accuracy improved from 0.62791 to 0.67442, saving model to checkpoint/model2048_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model2048_train_new.csv/assets
# Epoch 11/20
# 25/25 [==============================] - 1s 42ms/step - loss: 0.2296 - accuracy: 0.9319 - val_loss: 0.8261 - val_accuracy: 0.6512
#
# Epoch 00011: val_accuracy did not improve from 0.67442
# Epoch 12/20
# 25/25 [==============================] - 1s 40ms/step - loss: 0.2518 - accuracy: 0.9155 - val_loss: 0.8295 - val_accuracy: 0.6512
#
# Epoch 00012: val_accuracy did not improve from 0.67442
# Epoch 13/20
# 25/25 [==============================] - 1s 39ms/step - loss: 0.0708 - accuracy: 0.9822 - val_loss: 0.7005 - val_accuracy: 0.7442
#
# Epoch 00013: val_accuracy improved from 0.67442 to 0.74419, saving model to checkpoint/model2048_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model2048_train_new.csv/assets
# Epoch 14/20
# 25/25 [==============================] - 1s 41ms/step - loss: 0.1729 - accuracy: 0.9784 - val_loss: 0.6895 - val_accuracy: 0.7674
#
# Epoch 00014: val_accuracy improved from 0.74419 to 0.76744, saving model to checkpoint/model2048_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model2048_train_new.csv/assets
# Epoch 15/20
# 25/25 [==============================] - 1s 42ms/step - loss: 0.0874 - accuracy: 0.9861 - val_loss: 0.6894 - val_accuracy: 0.7907
#
# Epoch 00015: val_accuracy improved from 0.76744 to 0.79070, saving model to checkpoint/model2048_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model2048_train_new.csv/assets
# Epoch 16/20
# 25/25 [==============================] - 1s 42ms/step - loss: 0.2603 - accuracy: 0.9514 - val_loss: 0.9120 - val_accuracy: 0.6512
#
# Epoch 00016: val_accuracy did not improve from 0.79070
# Epoch 17/20
# 25/25 [==============================] - 1s 42ms/step - loss: 0.1347 - accuracy: 0.9419 - val_loss: 0.8349 - val_accuracy: 0.6744
#
# Epoch 00017: val_accuracy did not improve from 0.79070
# Epoch 18/20
# 25/25 [==============================] - 1s 42ms/step - loss: 0.1333 - accuracy: 0.9492 - val_loss: 0.8124 - val_accuracy: 0.7209
#
# Epoch 00018: val_accuracy did not improve from 0.79070
# Epoch 19/20
# 25/25 [==============================] - 1s 40ms/step - loss: 0.0972 - accuracy: 0.9633 - val_loss: 0.7197 - val_accuracy: 0.7674
#
# Epoch 00019: val_accuracy did not improve from 0.79070
# Epoch 20/20
# 25/25 [==============================] - 1s 40ms/step - loss: 0.1085 - accuracy: 0.9563 - val_loss: 0.8361 - val_accuracy: 0.6279
#
# Epoch 00020: val_accuracy did not improve from 0.79070

# %%
hist4096 = model4096.fit(X_train, y_train, batch_size=7, epochs=20, verbose=1, validation_data=(X_test, y_test),callbacks=checkpoint4096)

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ['4', '16', '32', '64', '128', '256', '512', '1024', '2048', '4096']
accuracy = [np.amax(hist4.history['accuracy']),
             np.amax(hist16.history['accuracy']),
             np.amax(hist32.history['accuracy']),
             np.amax(hist64.history['accuracy']), 
             np.amax(hist128.history['accuracy']),
             np.amax(hist256.history['accuracy']),
             np.amax(hist512.history['accuracy']),
             np.amax(hist1024.history['accuracy']),
             np.amax(hist2048.history['accuracy']),
             np.amax(hist4096.history['accuracy'])]
                       
val_accuracy = [np.amax(hist4.history['val_accuracy']),
             np.amax(hist16.history['val_accuracy']),
             np.amax(hist32.history['val_accuracy']),
             np.amax(hist64.history['val_accuracy']), 
             np.amax(hist128.history['val_accuracy']),
             np.amax(hist256.history['val_accuracy']),
             np.amax(hist512.history['val_accuracy']),
             np.amax(hist1024.history['val_accuracy']),
             np.amax(hist2048.history['val_accuracy']),
             np.amax(hist4096.history['val_accuracy'])]

x = np.arange(len(labels))  # the label locations
width = 0.40  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, accuracy, width, label='accuracy')
rects2 = ax.bar(x + width/2, val_accuracy, width, label='val_accuracy')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy')
ax.set_title('Number of neurons in the FC layer in JAFFE dataset')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

fig.tight_layout()

plt.show()
