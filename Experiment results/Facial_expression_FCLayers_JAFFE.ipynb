# %%
from google.colab import drive
import tarfile
import os, cv2
import numpy as np
import pandas as pd
import tensorflow as tf
from matplotlib import pyplot
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.utils import shuffle
from keras.utils import np_utils
drive.mount('/content/drive'),
# Out:
# Mounted at /content/drive
# (None,)

# %%
data_path = '/content/drive/MyDrive/facial_expression/jaffe'
data_dir_list = os.listdir(data_path)

img_si=128
num_channel=1

num_epoch=10

img_data_list=[]


for dataset in data_dir_list:
    img_list=os.listdir(data_path+'/'+ dataset)
    print ('Loaded the images of dataset-'+'{}\n'.format(dataset))
    for img in img_list:
        input_img=cv2.imread(data_path + '/'+ dataset + '/'+ img )
        #input_img=cv2.cvtColor(input_img, cv2.COLOR_BGR2GRAY)
        input_img_resize=cv2.resize(input_img,(img_si,img_si))
        img_data_list.append(input_img_resize)
        
img_data = np.array(img_data_list)
img_data = img_data.astype('float32')
img_data = img_data/255
img_data.shape
# Out:
# Loaded the images of dataset-ANGRY
#
# Loaded the images of dataset-DISGUST
#
# Loaded the images of dataset-FEAR
#
# Loaded the images of dataset-NEUTRAL
#
# Loaded the images of dataset-HAPPY
#
# Loaded the images of dataset-SAD
#
# Loaded the images of dataset-SURPRISE
# (213, 128, 128, 3)

# %%
num_classes = 7

num_of_samples = img_data.shape[0]
labels = np.ones((num_of_samples,),dtype='int64')

labels[0:29]=0 #30
labels[30:58]=1 #29
labels[59:90]=2 #32
labels[91:121]=3 #31
labels[122:151]=4 #30
labels[152:182]=5 #31
labels[183:]=6 #30

names = ['ANGRY','DISGUST','FEAR','HAPPY','NEUTRAL','SAD','SURPRISE']

def getLabel(id):
    return ['ANGRY','DISGUST','FEAR','HAPPY','NEUTRAL','SAD','SURPRISE'][id]

# %%
Y = np_utils.to_categorical(labels, num_classes)
#Shuffle the dataset
x,y = shuffle(img_data,Y, random_state=2)
# Split the dataset
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=2)
x_test=X_test
#X_train=X_train.reshape(X_train.shape[0],128,128,1)
#X_test=X_test.reshape(X_test.shape[0],128,128,1)
x_test.shape
# Out:
# (43, 128, 128, 3)

# %%
from keras.models import Sequential
from keras.layers import Dense , Activation , Dropout ,Flatten, BatchNormalization
from keras.layers.convolutional import Conv2D
from keras.layers.convolutional import MaxPooling2D, AveragePooling2D
from keras.metrics import categorical_accuracy
from keras.models import model_from_json
from keras.callbacks import ModelCheckpoint
from keras.optimizers import *
from keras.layers.normalization import BatchNormalization

# %%
input_shape=(img_si,img_si,3)

model1 = Sequential()
model1.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model1.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model1.add(Dropout(0.25))
model1.add(MaxPooling2D(pool_size=(2, 2)))

model1.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model1.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model1.add(Dropout(0.25))
model1.add(MaxPooling2D(pool_size=(2, 2)))

model1.add(Flatten())
model1.add(Dense(64, activation = 'relu'))
model1.add(Dropout(0.5))
model1.add(Dense(7, activation = 'softmax'))

# %%
input_shape=(img_si,img_si,3)

model4 = Sequential()
model4.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model4.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model4.add(Dropout(0.25))
model4.add(MaxPooling2D(pool_size=(2, 2)))

model4.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model4.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model4.add(Dropout(0.25))
model4.add(MaxPooling2D(pool_size=(2, 2)))

model4.add(Flatten())
model4.add(Dense(64, activation = 'relu'))
model4.add(Dense(64, activation = 'relu'))
model4.add(Dropout(0.5))
model4.add(Dense(7, activation = 'softmax'))

# %%
input_shape=(img_si,img_si,3)

model16 = Sequential()
model16.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model16.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model16.add(Dropout(0.25))
model16.add(MaxPooling2D(pool_size=(2, 2)))

model16.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model16.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model16.add(Dropout(0.25))
model16.add(MaxPooling2D(pool_size=(2, 2)))

model16.add(Flatten())
model16.add(Dense(64, activation = 'relu'))
model16.add(Dense(64, activation = 'relu'))
model16.add(Dense(64, activation = 'relu'))
model16.add(Dropout(0.5))
model16.add(Dense(7, activation = 'softmax'))

# %%
input_shape=(img_si,img_si,3)

model32 = Sequential()
model32.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model32.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model32.add(Dropout(0.25))
model32.add(MaxPooling2D(pool_size=(2, 2)))

model32.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model32.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model32.add(Dropout(0.25))
model32.add(MaxPooling2D(pool_size=(2, 2)))

model32.add(Flatten())
model32.add(Dense(64, activation = 'relu'))
model32.add(Dense(64, activation = 'relu'))
model32.add(Dense(64, activation = 'relu'))
model32.add(Dense(64, activation = 'relu'))
model32.add(Dense(64, activation = 'relu'))
model32.add(Dropout(0.5))
model32.add(Dense(7, activation = 'softmax'))

# %%
input_shape=(img_si,img_si,3)

model64 = Sequential()
model64.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model64.add(Conv2D(32, (3, 3), input_shape=input_shape, padding='same', activation = 'relu'))
model64.add(Dropout(0.25))
model64.add(MaxPooling2D(pool_size=(2, 2)))

model64.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model64.add(Conv2D(64, (3, 3), padding='same', activation = 'relu'))
model64.add(Dropout(0.25))
model64.add(MaxPooling2D(pool_size=(2, 2)))

model64.add(Flatten())
model64.add(Dense(64, activation = 'relu'))
model64.add(Dense(64, activation = 'relu'))
model64.add(Dense(64, activation = 'relu'))
model64.add(Dense(64, activation = 'relu'))
model64.add(Dense(64, activation = 'relu'))
model64.add(Dense(64, activation = 'relu'))
model64.add(Dense(64, activation = 'relu'))
model64.add(Dense(64, activation = 'relu'))
model64.add(Dense(64, activation = 'relu'))
model64.add(Dense(64, activation = 'relu'))
model64.add(Dropout(0.5))
model64.add(Dense(7, activation = 'softmax'))

# %%
model1.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

# %%
model4.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

# %%
model16.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

# %%
model32.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

# %%
model64.compile(loss='categorical_crossentropy', optimizer=tf.keras.optimizers.Adam(learning_rate=0.001), metrics=["accuracy"])

# %%
from keras import callbacks
filename1='model1_train_new.csv'
filename4='model4_train_new.csv'
filename16='model16_train_new.csv'
filename32='model32_train_new.csv'
filename64='model64_train_new.csv'

filepath1 = os.path.join('checkpoint', filename1)
filepath4 = os.path.join('checkpoint', filename4)
filepath16 = os.path.join('checkpoint', filename16)
filepath32 = os.path.join('checkpoint', filename32)
filepath64 = os.path.join('checkpoint', filename64)

checkpoint1 = callbacks.ModelCheckpoint(filepath1, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint4 = callbacks.ModelCheckpoint(filepath4, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint16 = callbacks.ModelCheckpoint(filepath16, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint32 = callbacks.ModelCheckpoint(filepath32, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')
checkpoint64 = callbacks.ModelCheckpoint(filepath64, monitor='val_accuracy', verbose=1, save_best_only=True, save_weights_only=False, mode='max')

# %%
hist1 = model1.fit(X_train, y_train, batch_size=7, epochs=20, verbose=1, validation_data=(X_test, y_test),callbacks=checkpoint1)
# Out:
# Epoch 1/20
# 25/25 [==============================] - 46s 50ms/step - loss: 2.1472 - accuracy: 0.1193 - val_loss: 1.9477 - val_accuracy: 0.0930
#
# Epoch 00001: val_accuracy improved from -inf to 0.09302, saving model to checkpoint/model1_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1_train_new.csv/assets
# Epoch 2/20
# 25/25 [==============================] - 0s 15ms/step - loss: 1.9459 - accuracy: 0.1923 - val_loss: 1.9484 - val_accuracy: 0.0698
#
# Epoch 00002: val_accuracy did not improve from 0.09302
# Epoch 3/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9455 - accuracy: 0.1535 - val_loss: 1.9461 - val_accuracy: 0.0698
#
# Epoch 00003: val_accuracy did not improve from 0.09302
# Epoch 4/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9427 - accuracy: 0.2254 - val_loss: 1.9451 - val_accuracy: 0.1860
#
# Epoch 00004: val_accuracy improved from 0.09302 to 0.18605, saving model to checkpoint/model1_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1_train_new.csv/assets
# Epoch 5/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9305 - accuracy: 0.2070 - val_loss: 1.8625 - val_accuracy: 0.3256
#
# Epoch 00005: val_accuracy improved from 0.18605 to 0.32558, saving model to checkpoint/model1_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1_train_new.csv/assets
# Epoch 6/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.8752 - accuracy: 0.2083 - val_loss: 1.7717 - val_accuracy: 0.3256
#
# Epoch 00006: val_accuracy did not improve from 0.32558
# Epoch 7/20
# 25/25 [==============================] - 0s 14ms/step - loss: 1.7848 - accuracy: 0.3488 - val_loss: 1.5696 - val_accuracy: 0.4186
#
# Epoch 00007: val_accuracy improved from 0.32558 to 0.41860, saving model to checkpoint/model1_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1_train_new.csv/assets
# Epoch 8/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.4722 - accuracy: 0.4583 - val_loss: 1.3979 - val_accuracy: 0.3721
#
# Epoch 00008: val_accuracy did not improve from 0.41860
# Epoch 9/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.3175 - accuracy: 0.4464 - val_loss: 1.3064 - val_accuracy: 0.4419
#
# Epoch 00009: val_accuracy improved from 0.41860 to 0.44186, saving model to checkpoint/model1_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1_train_new.csv/assets
# Epoch 10/20
# 25/25 [==============================] - 0s 14ms/step - loss: 1.1633 - accuracy: 0.6082 - val_loss: 1.3285 - val_accuracy: 0.4186
#
# Epoch 00010: val_accuracy did not improve from 0.44186
# Epoch 11/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.1258 - accuracy: 0.5316 - val_loss: 1.0922 - val_accuracy: 0.5349
#
# Epoch 00011: val_accuracy improved from 0.44186 to 0.53488, saving model to checkpoint/model1_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1_train_new.csv/assets
# Epoch 12/20
# 25/25 [==============================] - 0s 12ms/step - loss: 0.9446 - accuracy: 0.5996 - val_loss: 1.0597 - val_accuracy: 0.4884
#
# Epoch 00012: val_accuracy did not improve from 0.53488
# Epoch 13/20
# 25/25 [==============================] - 0s 14ms/step - loss: 0.8494 - accuracy: 0.6981 - val_loss: 1.1217 - val_accuracy: 0.4884
#
# Epoch 00013: val_accuracy did not improve from 0.53488
# Epoch 14/20
# 25/25 [==============================] - 0s 14ms/step - loss: 0.8905 - accuracy: 0.6549 - val_loss: 0.9538 - val_accuracy: 0.6279
#
# Epoch 00014: val_accuracy improved from 0.53488 to 0.62791, saving model to checkpoint/model1_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1_train_new.csv/assets
# Epoch 15/20
# 25/25 [==============================] - 0s 13ms/step - loss: 0.6138 - accuracy: 0.7615 - val_loss: 0.8139 - val_accuracy: 0.6279
#
# Epoch 00015: val_accuracy did not improve from 0.62791
# Epoch 16/20
# 25/25 [==============================] - 0s 12ms/step - loss: 0.5975 - accuracy: 0.7834 - val_loss: 1.0024 - val_accuracy: 0.5581
#
# Epoch 00016: val_accuracy did not improve from 0.62791
# Epoch 17/20
# 25/25 [==============================] - 0s 12ms/step - loss: 0.5874 - accuracy: 0.7745 - val_loss: 0.9352 - val_accuracy: 0.6047
#
# Epoch 00017: val_accuracy did not improve from 0.62791
# Epoch 18/20
# 25/25 [==============================] - 0s 14ms/step - loss: 0.6698 - accuracy: 0.7781 - val_loss: 0.9536 - val_accuracy: 0.6512
#
# Epoch 00018: val_accuracy improved from 0.62791 to 0.65116, saving model to checkpoint/model1_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1_train_new.csv/assets
# Epoch 19/20
# 25/25 [==============================] - 0s 13ms/step - loss: 0.5660 - accuracy: 0.7931 - val_loss: 0.8497 - val_accuracy: 0.6744
#
# Epoch 00019: val_accuracy improved from 0.65116 to 0.67442, saving model to checkpoint/model1_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model1_train_new.csv/assets
# Epoch 20/20
# 25/25 [==============================] - 0s 13ms/step - loss: 0.4535 - accuracy: 0.8104 - val_loss: 0.8498 - val_accuracy: 0.6047
#
# Epoch 00020: val_accuracy did not improve from 0.67442

# %%
hist4 = model4.fit(X_train, y_train, batch_size=7, epochs=20, verbose=1, validation_data=(X_test, y_test),callbacks=checkpoint4)
# Out:
# Epoch 1/20
# 25/25 [==============================] - 2s 32ms/step - loss: 2.5731 - accuracy: 0.1310 - val_loss: 1.9508 - val_accuracy: 0.0465
#
# Epoch 00001: val_accuracy improved from -inf to 0.04651, saving model to checkpoint/model4_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model4_train_new.csv/assets
# Epoch 2/20
# 25/25 [==============================] - 0s 16ms/step - loss: 1.9467 - accuracy: 0.1306 - val_loss: 1.9499 - val_accuracy: 0.0465
#
# Epoch 00002: val_accuracy did not improve from 0.04651
# Epoch 3/20
# 25/25 [==============================] - 0s 11ms/step - loss: 1.9449 - accuracy: 0.1319 - val_loss: 1.9503 - val_accuracy: 0.0465
#
# Epoch 00003: val_accuracy did not improve from 0.04651
# Epoch 4/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9433 - accuracy: 0.1812 - val_loss: 1.9558 - val_accuracy: 0.0465
#
# Epoch 00004: val_accuracy did not improve from 0.04651
# Epoch 5/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9479 - accuracy: 0.1523 - val_loss: 1.9566 - val_accuracy: 0.0698
#
# Epoch 00005: val_accuracy improved from 0.04651 to 0.06977, saving model to checkpoint/model4_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model4_train_new.csv/assets
# Epoch 6/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9410 - accuracy: 0.1538 - val_loss: 1.9488 - val_accuracy: 0.0698
#
# Epoch 00006: val_accuracy did not improve from 0.06977
# Epoch 7/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9363 - accuracy: 0.0985 - val_loss: 1.9779 - val_accuracy: 0.0698
#
# Epoch 00007: val_accuracy did not improve from 0.06977
# Epoch 8/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9464 - accuracy: 0.2065 - val_loss: 1.8562 - val_accuracy: 0.1860
#
# Epoch 00008: val_accuracy improved from 0.06977 to 0.18605, saving model to checkpoint/model4_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model4_train_new.csv/assets
# Epoch 9/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.7904 - accuracy: 0.2733 - val_loss: 1.7972 - val_accuracy: 0.2326
#
# Epoch 00009: val_accuracy improved from 0.18605 to 0.23256, saving model to checkpoint/model4_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model4_train_new.csv/assets
# Epoch 10/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.5663 - accuracy: 0.4889 - val_loss: 1.5850 - val_accuracy: 0.2558
#
# Epoch 00010: val_accuracy improved from 0.23256 to 0.25581, saving model to checkpoint/model4_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model4_train_new.csv/assets
# Epoch 11/20
# 25/25 [==============================] - 0s 14ms/step - loss: 1.5055 - accuracy: 0.4626 - val_loss: 1.5870 - val_accuracy: 0.3256
#
# Epoch 00011: val_accuracy improved from 0.25581 to 0.32558, saving model to checkpoint/model4_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model4_train_new.csv/assets
# Epoch 12/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.2493 - accuracy: 0.5133 - val_loss: 1.2971 - val_accuracy: 0.3721
#
# Epoch 00012: val_accuracy improved from 0.32558 to 0.37209, saving model to checkpoint/model4_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model4_train_new.csv/assets
# Epoch 13/20
# 25/25 [==============================] - 0s 13ms/step - loss: 0.8354 - accuracy: 0.7339 - val_loss: 1.1442 - val_accuracy: 0.5349
#
# Epoch 00013: val_accuracy improved from 0.37209 to 0.53488, saving model to checkpoint/model4_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model4_train_new.csv/assets
# Epoch 14/20
# 25/25 [==============================] - 0s 13ms/step - loss: 0.9785 - accuracy: 0.6538 - val_loss: 1.0334 - val_accuracy: 0.6279
#
# Epoch 00014: val_accuracy improved from 0.53488 to 0.62791, saving model to checkpoint/model4_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model4_train_new.csv/assets
# Epoch 15/20
# 25/25 [==============================] - 0s 12ms/step - loss: 0.8032 - accuracy: 0.7051 - val_loss: 0.9803 - val_accuracy: 0.6744
#
# Epoch 00015: val_accuracy improved from 0.62791 to 0.67442, saving model to checkpoint/model4_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model4_train_new.csv/assets
# Epoch 16/20
# 25/25 [==============================] - 0s 14ms/step - loss: 0.6156 - accuracy: 0.8096 - val_loss: 0.9032 - val_accuracy: 0.6977
#
# Epoch 00016: val_accuracy improved from 0.67442 to 0.69767, saving model to checkpoint/model4_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model4_train_new.csv/assets
# Epoch 17/20
# 25/25 [==============================] - 0s 13ms/step - loss: 0.5751 - accuracy: 0.8010 - val_loss: 0.7361 - val_accuracy: 0.7209
#
# Epoch 00017: val_accuracy improved from 0.69767 to 0.72093, saving model to checkpoint/model4_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model4_train_new.csv/assets
# Epoch 18/20
# 25/25 [==============================] - 0s 17ms/step - loss: 0.3732 - accuracy: 0.8754 - val_loss: 0.7551 - val_accuracy: 0.7674
#
# Epoch 00018: val_accuracy improved from 0.72093 to 0.76744, saving model to checkpoint/model4_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model4_train_new.csv/assets
# Epoch 19/20
# 25/25 [==============================] - 0s 12ms/step - loss: 0.4144 - accuracy: 0.8571 - val_loss: 0.7000 - val_accuracy: 0.7442
#
# Epoch 00019: val_accuracy did not improve from 0.76744
# Epoch 20/20
# 25/25 [==============================] - 0s 12ms/step - loss: 0.3444 - accuracy: 0.8759 - val_loss: 0.6869 - val_accuracy: 0.7442
#
# Epoch 00020: val_accuracy did not improve from 0.76744

# %%
hist16 = model16.fit(X_train, y_train, batch_size=7, epochs=20, verbose=1, validation_data=(X_test, y_test),callbacks=checkpoint16)
# Out:
# Epoch 1/20
# 25/25 [==============================] - 2s 32ms/step - loss: 2.1898 - accuracy: 0.1407 - val_loss: 1.9483 - val_accuracy: 0.1163
#
# Epoch 00001: val_accuracy improved from -inf to 0.11628, saving model to checkpoint/model16_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model16_train_new.csv/assets
# Epoch 2/20
# 25/25 [==============================] - 0s 16ms/step - loss: 1.9467 - accuracy: 0.0909 - val_loss: 1.9502 - val_accuracy: 0.0930
#
# Epoch 00002: val_accuracy did not improve from 0.11628
# Epoch 3/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9441 - accuracy: 0.1416 - val_loss: 1.9533 - val_accuracy: 0.0930
#
# Epoch 00003: val_accuracy did not improve from 0.11628
# Epoch 4/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9474 - accuracy: 0.1397 - val_loss: 1.9542 - val_accuracy: 0.0930
#
# Epoch 00004: val_accuracy did not improve from 0.11628
# Epoch 5/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9455 - accuracy: 0.1308 - val_loss: 1.9575 - val_accuracy: 0.0465
#
# Epoch 00005: val_accuracy did not improve from 0.11628
# Epoch 6/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9426 - accuracy: 0.1171 - val_loss: 1.9602 - val_accuracy: 0.0465
#
# Epoch 00006: val_accuracy did not improve from 0.11628
# Epoch 7/20
# 25/25 [==============================] - 0s 14ms/step - loss: 1.9391 - accuracy: 0.1687 - val_loss: 1.9607 - val_accuracy: 0.0465
#
# Epoch 00007: val_accuracy did not improve from 0.11628
# Epoch 8/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9411 - accuracy: 0.1499 - val_loss: 1.9656 - val_accuracy: 0.0465
#
# Epoch 00008: val_accuracy did not improve from 0.11628
# Epoch 9/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9447 - accuracy: 0.1723 - val_loss: 1.9675 - val_accuracy: 0.0465
#
# Epoch 00009: val_accuracy did not improve from 0.11628
# Epoch 10/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9529 - accuracy: 0.1716 - val_loss: 1.9676 - val_accuracy: 0.0465
#
# Epoch 00010: val_accuracy did not improve from 0.11628
# Epoch 11/20
# 25/25 [==============================] - 0s 14ms/step - loss: 1.9484 - accuracy: 0.2310 - val_loss: 1.9660 - val_accuracy: 0.1163
#
# Epoch 00011: val_accuracy did not improve from 0.11628
# Epoch 12/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9473 - accuracy: 0.1357 - val_loss: 1.9702 - val_accuracy: 0.0465
#
# Epoch 00012: val_accuracy did not improve from 0.11628
# Epoch 13/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9476 - accuracy: 0.1747 - val_loss: 1.9675 - val_accuracy: 0.0930
#
# Epoch 00013: val_accuracy did not improve from 0.11628
# Epoch 14/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9291 - accuracy: 0.1953 - val_loss: 1.9574 - val_accuracy: 0.0698
#
# Epoch 00014: val_accuracy did not improve from 0.11628
# Epoch 15/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9084 - accuracy: 0.2399 - val_loss: 1.8558 - val_accuracy: 0.2558
#
# Epoch 00015: val_accuracy improved from 0.11628 to 0.25581, saving model to checkpoint/model16_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model16_train_new.csv/assets
# Epoch 16/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.7869 - accuracy: 0.2840 - val_loss: 1.6988 - val_accuracy: 0.2558
#
# Epoch 00016: val_accuracy did not improve from 0.25581
# Epoch 17/20
# 25/25 [==============================] - 0s 14ms/step - loss: 1.7052 - accuracy: 0.3271 - val_loss: 1.6933 - val_accuracy: 0.3023
#
# Epoch 00017: val_accuracy improved from 0.25581 to 0.30233, saving model to checkpoint/model16_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model16_train_new.csv/assets
# Epoch 18/20
# 25/25 [==============================] - 0s 16ms/step - loss: 1.5629 - accuracy: 0.3492 - val_loss: 1.5351 - val_accuracy: 0.3256
#
# Epoch 00018: val_accuracy improved from 0.30233 to 0.32558, saving model to checkpoint/model16_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model16_train_new.csv/assets
# Epoch 19/20
# 25/25 [==============================] - 0s 17ms/step - loss: 1.5207 - accuracy: 0.3820 - val_loss: 1.4557 - val_accuracy: 0.3953
#
# Epoch 00019: val_accuracy improved from 0.32558 to 0.39535, saving model to checkpoint/model16_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model16_train_new.csv/assets
# Epoch 20/20
# 25/25 [==============================] - 0s 17ms/step - loss: 1.3074 - accuracy: 0.4565 - val_loss: 1.3496 - val_accuracy: 0.4651
#
# Epoch 00020: val_accuracy improved from 0.39535 to 0.46512, saving model to checkpoint/model16_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model16_train_new.csv/assets

# %%
hist32 = model32.fit(X_train, y_train, batch_size=7, epochs=20, verbose=1, validation_data=(X_test, y_test),callbacks=checkpoint32)
# Out:
# Epoch 1/20
# 25/25 [==============================] - 2s 35ms/step - loss: 2.0256 - accuracy: 0.1534 - val_loss: 1.9480 - val_accuracy: 0.0930
#
# Epoch 00001: val_accuracy improved from -inf to 0.09302, saving model to checkpoint/model32_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model32_train_new.csv/assets
# Epoch 2/20
# 25/25 [==============================] - 0s 15ms/step - loss: 1.9457 - accuracy: 0.1260 - val_loss: 1.9477 - val_accuracy: 0.0930
#
# Epoch 00002: val_accuracy did not improve from 0.09302
# Epoch 3/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9482 - accuracy: 0.1001 - val_loss: 1.9523 - val_accuracy: 0.0698
#
# Epoch 00003: val_accuracy did not improve from 0.09302
# Epoch 4/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9465 - accuracy: 0.1647 - val_loss: 1.9550 - val_accuracy: 0.0465
#
# Epoch 00004: val_accuracy did not improve from 0.09302
# Epoch 5/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9456 - accuracy: 0.1344 - val_loss: 1.9575 - val_accuracy: 0.0465
#
# Epoch 00005: val_accuracy did not improve from 0.09302
# Epoch 6/20
# 25/25 [==============================] - 0s 14ms/step - loss: 1.9468 - accuracy: 0.1140 - val_loss: 1.9635 - val_accuracy: 0.0465
#
# Epoch 00006: val_accuracy did not improve from 0.09302
# Epoch 7/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9396 - accuracy: 0.1802 - val_loss: 1.9636 - val_accuracy: 0.0465
#
# Epoch 00007: val_accuracy did not improve from 0.09302
# Epoch 8/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9426 - accuracy: 0.1254 - val_loss: 1.9648 - val_accuracy: 0.0465
#
# Epoch 00008: val_accuracy did not improve from 0.09302
# Epoch 9/20
# 25/25 [==============================] - 0s 14ms/step - loss: 1.9384 - accuracy: 0.1886 - val_loss: 1.9599 - val_accuracy: 0.0465
#
# Epoch 00009: val_accuracy did not improve from 0.09302
# Epoch 10/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9306 - accuracy: 0.1678 - val_loss: 1.9672 - val_accuracy: 0.0465
#
# Epoch 00010: val_accuracy did not improve from 0.09302
# Epoch 11/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9056 - accuracy: 0.1664 - val_loss: 1.9445 - val_accuracy: 0.2093
#
# Epoch 00011: val_accuracy improved from 0.09302 to 0.20930, saving model to checkpoint/model32_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model32_train_new.csv/assets
# Epoch 12/20
# 25/25 [==============================] - 0s 16ms/step - loss: 1.8843 - accuracy: 0.2179 - val_loss: 1.9068 - val_accuracy: 0.1395
#
# Epoch 00012: val_accuracy did not improve from 0.20930
# Epoch 13/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.8280 - accuracy: 0.2138 - val_loss: 1.8634 - val_accuracy: 0.2326
#
# Epoch 00013: val_accuracy improved from 0.20930 to 0.23256, saving model to checkpoint/model32_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model32_train_new.csv/assets
# Epoch 14/20
# 25/25 [==============================] - 0s 15ms/step - loss: 1.7192 - accuracy: 0.3463 - val_loss: 1.7968 - val_accuracy: 0.2558
#
# Epoch 00014: val_accuracy improved from 0.23256 to 0.25581, saving model to checkpoint/model32_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model32_train_new.csv/assets
# Epoch 15/20
# 25/25 [==============================] - 0s 16ms/step - loss: 1.5735 - accuracy: 0.3833 - val_loss: 1.6485 - val_accuracy: 0.4419
#
# Epoch 00015: val_accuracy improved from 0.25581 to 0.44186, saving model to checkpoint/model32_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model32_train_new.csv/assets
# Epoch 16/20
# 25/25 [==============================] - 0s 15ms/step - loss: 1.2714 - accuracy: 0.5219 - val_loss: 1.4788 - val_accuracy: 0.4419
#
# Epoch 00016: val_accuracy did not improve from 0.44186
# Epoch 17/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.2825 - accuracy: 0.5457 - val_loss: 1.3707 - val_accuracy: 0.4884
#
# Epoch 00017: val_accuracy improved from 0.44186 to 0.48837, saving model to checkpoint/model32_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model32_train_new.csv/assets
# Epoch 18/20
# 25/25 [==============================] - 0s 17ms/step - loss: 1.1337 - accuracy: 0.5831 - val_loss: 1.4790 - val_accuracy: 0.4884
#
# Epoch 00018: val_accuracy did not improve from 0.48837
# Epoch 19/20
# 25/25 [==============================] - 0s 14ms/step - loss: 1.0806 - accuracy: 0.5814 - val_loss: 1.2071 - val_accuracy: 0.5116
#
# Epoch 00019: val_accuracy improved from 0.48837 to 0.51163, saving model to checkpoint/model32_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model32_train_new.csv/assets
# Epoch 20/20
# 25/25 [==============================] - 0s 16ms/step - loss: 0.7112 - accuracy: 0.7282 - val_loss: 1.1643 - val_accuracy: 0.5116
#
# Epoch 00020: val_accuracy did not improve from 0.51163

# %%
hist64 = model64.fit(X_train, y_train, batch_size=7, epochs=20, verbose=1, validation_data=(X_test, y_test),callbacks=checkpoint64)
# Out:
# Epoch 1/20
# 25/25 [==============================] - 2s 37ms/step - loss: 1.9561 - accuracy: 0.1543 - val_loss: 1.9539 - val_accuracy: 0.0465
#
# Epoch 00001: val_accuracy improved from -inf to 0.04651, saving model to checkpoint/model64_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model64_train_new.csv/assets
# Epoch 2/20
# 25/25 [==============================] - 0s 16ms/step - loss: 1.9466 - accuracy: 0.1748 - val_loss: 1.9571 - val_accuracy: 0.0465
#
# Epoch 00002: val_accuracy did not improve from 0.04651
# Epoch 3/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9410 - accuracy: 0.1513 - val_loss: 1.9739 - val_accuracy: 0.0465
#
# Epoch 00003: val_accuracy did not improve from 0.04651
# Epoch 4/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9382 - accuracy: 0.1661 - val_loss: 1.9682 - val_accuracy: 0.0465
#
# Epoch 00004: val_accuracy did not improve from 0.04651
# Epoch 5/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9413 - accuracy: 0.1751 - val_loss: 1.9696 - val_accuracy: 0.0930
#
# Epoch 00005: val_accuracy improved from 0.04651 to 0.09302, saving model to checkpoint/model64_train_new.csv
# INFO:tensorflow:Assets written to: checkpoint/model64_train_new.csv/assets
# Epoch 6/20
# 25/25 [==============================] - 0s 15ms/step - loss: 1.9440 - accuracy: 0.1558 - val_loss: 1.9732 - val_accuracy: 0.0465
#
# Epoch 00006: val_accuracy did not improve from 0.09302
# Epoch 7/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9409 - accuracy: 0.1776 - val_loss: 1.9819 - val_accuracy: 0.0465
#
# Epoch 00007: val_accuracy did not improve from 0.09302
# Epoch 8/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9456 - accuracy: 0.1411 - val_loss: 1.9812 - val_accuracy: 0.0465
#
# Epoch 00008: val_accuracy did not improve from 0.09302
# Epoch 9/20
# 25/25 [==============================] - 0s 14ms/step - loss: 1.9456 - accuracy: 0.1521 - val_loss: 1.9781 - val_accuracy: 0.0465
#
# Epoch 00009: val_accuracy did not improve from 0.09302
# Epoch 10/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9478 - accuracy: 0.1505 - val_loss: 1.9762 - val_accuracy: 0.0465
#
# Epoch 00010: val_accuracy did not improve from 0.09302
# Epoch 11/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9461 - accuracy: 0.1213 - val_loss: 1.9816 - val_accuracy: 0.0465
#
# Epoch 00011: val_accuracy did not improve from 0.09302
# Epoch 12/20
# 25/25 [==============================] - 0s 13ms/step - loss: 1.9442 - accuracy: 0.1379 - val_loss: 1.9767 - val_accuracy: 0.0465
#
# Epoch 00012: val_accuracy did not improve from 0.09302
# Epoch 13/20
# 25/25 [==============================] - 0s 14ms/step - loss: 1.9378 - accuracy: 0.2050 - val_loss: 1.9772 - val_accuracy: 0.0465
#
# Epoch 00013: val_accuracy did not improve from 0.09302
# Epoch 14/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9383 - accuracy: 0.1752 - val_loss: 1.9805 - val_accuracy: 0.0465
#
# Epoch 00014: val_accuracy did not improve from 0.09302
# Epoch 15/20
# 25/25 [==============================] - 0s 14ms/step - loss: 1.9367 - accuracy: 0.2020 - val_loss: 1.9842 - val_accuracy: 0.0465
#
# Epoch 00015: val_accuracy did not improve from 0.09302
# Epoch 16/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9435 - accuracy: 0.1717 - val_loss: 1.9865 - val_accuracy: 0.0465
#
# Epoch 00016: val_accuracy did not improve from 0.09302
# Epoch 17/20
# 25/25 [==============================] - 0s 14ms/step - loss: 1.9523 - accuracy: 0.1019 - val_loss: 1.9814 - val_accuracy: 0.0465
#
# Epoch 00017: val_accuracy did not improve from 0.09302
# Epoch 18/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9422 - accuracy: 0.1727 - val_loss: 1.9773 - val_accuracy: 0.0465
#
# Epoch 00018: val_accuracy did not improve from 0.09302
# Epoch 19/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9425 - accuracy: 0.1692 - val_loss: 1.9818 - val_accuracy: 0.0465
#
# Epoch 00019: val_accuracy did not improve from 0.09302
# Epoch 20/20
# 25/25 [==============================] - 0s 12ms/step - loss: 1.9480 - accuracy: 0.1550 - val_loss: 1.9796 - val_accuracy: 0.0465
#
# Epoch 00020: val_accuracy did not improve from 0.09302

# %%
import matplotlib.pyplot as plt
import numpy as np


labels = ['1','2', '3', '5', '10']
accuracy = [np.amax(hist1.history['accuracy']),
            np.amax(hist4.history['accuracy']),
             np.amax(hist16.history['accuracy']),
             np.amax(hist32.history['accuracy']),
             np.amax(hist64.history['accuracy'])]
                       
val_accuracy = [np.amax(hist1.history['val_accuracy']),
                np.amax(hist4.history['val_accuracy']),
             np.amax(hist16.history['val_accuracy']),
             np.amax(hist32.history['val_accuracy']),
             np.amax(hist64.history['val_accuracy'])]

x = np.arange(len(labels))  # the label locations
width = 0.40  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, accuracy, width, label='accuracy')
rects2 = ax.bar(x + width/2, val_accuracy, width, label='val_accuracy')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Accuracy')
ax.set_title('Number of FC layers (64 neurons each) in JAFFE dataset')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

fig.tight_layout()

plt.show()
